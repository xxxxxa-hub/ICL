# %% [markdown]
# # Main Experiment Runner for One Dataset Example

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from ICL_modules import data_loader, dataset_interface, s_random, experiment_basics, functions
from ICL_inference import inference
from ICL_calibrations import calibration_methods
from run import run_multiple_calibration_experiments_generic
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    LogitsProcessorList,
    LogitsProcessor
)
import random
import torch
import numpy as np
import pandas as pd
import itertools
import functools
import copy

# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# ---------------------------------------------
# Define the model identifier from HuggingFace Hub
# This should be the path or name of a pre-trained language model that supports causal (auto-regressive) generation.
MODEL_ID = "meta-llama/Llama-2-7b-chat-hf"
            

# Define the HuggingFace authentication token if the model is gated or requires private access.
HF_TOKEN = "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"

# ---------------------------------------------
# Load the tokenizer associated with the model.
# The tokenizer is responsible for converting raw text into token IDs (and vice versa).
# Authentication token is passed if required.
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_auth_token=HF_TOKEN)

# ---------------------------------------------
# Load the pre-trained causal language model.
# - device_map=\"auto\": Automatically places model components on available devices (GPU/CPU).
# - torch_dtype=torch.float16: Loads the model in half-precision for reduced memory usage and faster inference.
# - .eval(): Sets the model to evaluation mode (disabling any training-specific behavior).
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.float16,
    use_auth_token=HF_TOKEN
).eval()
# Out:
# /hpc/home/jd420/anaconda3/envs/CARE/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:897: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /hpc/home/jd420/anaconda3/envs/CARE/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# ---------------------------------------------
# Use data_loader class to upload data from cache
# As an example, AGNews is used
ag_news= data_loader.agnews(from_cache = True)
seed = 107
test_samples = 256
train_samples = len(ag_news) - test_samples
splitted_ag = dataset_interface.DatasetSplitter(ag_news, train_samples,test_samples,seed)

# %%
# --------------------------------------------------------
# param_dic: Hyperparameter config for LR calibration
# --------------------------------------------------------
# This dictionary defines cosine-threshold and invariance-strength values
# used during logistic regression calibration.

# Usage:
# param_dic can be either:
#
# (1) Generic (used for all datasets):
# ---------------------------------------------------
# param_dic = {
#     4: { 0: [15, 0.8], 1: [5.5, 0.8], ..., 3: [4.5, 0.8] },
#     8: { 0: [...], ..., 7: [...] }
# }
#
# (2) Dataset-specific:
# ---------------------------------------------------
# param_dic = {
#     "sst2": {
#         4: { 0: [15, 0.8], ..., 3: [4.5, 0.8] },
#         8: { 0: [...], ..., 7: [...] }
#     },
#     "agnews": {
#         4: { ... },
#         8: { ... }
#     }
# }

# Meaning of inner values:
# param_dic[k][i] = [cosine_factor, invariance_strength]
# Where:
#   - `k` is the total number of shots
#   - `i` is the current sub-shot index (0 ≤ i < k)
#   - `cosine_factor`: used as denominator in cos(π / cosine_factor) for threshold
#                      → higher values mean stricter similarity filter
#   - `invariance_strength`: regularization weight (typically 0–1)

#   Example:
#   cosine_threshold = cos(π / 4.5) ≈ 0.22
#   param_dic[4][3] = [4.5, 0.8]



# param_dic = {
#     4: {
#         0: [15, 0.8],
#         1: [5.5, 0.8],
#         2: [5, 0.7],
#         3: [4.5, 0.8]
#     }
# }

param_dic = {
  8: {
    0: [90, 10],
    1: [90, 10],
    2: [90, 10],
    3: [90, 10],
    4: [90, 10],
    5: [90, 10],
    6: [90, 10],
    7: [90, 10],
  }
}

# %%
from run_experiments import load_param_config
param_dic = load_param_config('/hpc/home/jd420/Projects/ICL/configs/Llama_8.json', 8)
# Out:
# Loading param_dic from /hpc/home/jd420/Projects/ICL/configs/Llama_8.json

# %%
# Run a calibration experiment using the Contextual Calibration (CC) method.
#
# Arguments:
# - model / tokenizer: HuggingFace-compatible model and tokenizer.
# - splitted_datasets: One or more dataset splits (train/test) ready for calibration.
# - seeds: List of seeds for random sampling of demonstration examples (for reproducibility).
# - k_values: List of values for k-shot learning (number of demonstrations in-context).
# - param_dic: Dictionary of hyperparameters (used mainly for LR).
# - methods_to_run: Specifies which calibration methods to run. Here, we use only 'LR'.
#
# Returns:
# - result: A dictionary containing performance metrics for each dataset, seed, and k.
# - The other two return values (ignored here) include:
#     - dfs: Calibration-specific dataframes (mostly used by LR).
#     - coefficients_dic: Calibration coefficients (also for LR).
#
# This call executes LR calibration on the provided model and dataset, printing progress logs as it runs.

result, _, _ = run_multiple_calibration_experiments_generic(
    model=model,
    tokenizer=tokenizer,
    splitted_datasets=splitted_ag,
    seeds=[2206632489],
    k_values=[8],
    param_dic=param_dic,
    methods_to_run=['CC','LR']
)
# Out:
# Starting experiments on dataset: AGNews
# No dataset-specific param_dic found for 'AGNews', using generic config.
#
# === Running experiment for AGNews | Seed 2206632489, k: 8 ===
# Running Contextual Calibration (CC)...
# [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: AGNews
# Running LR Calibration
# Training LR for 0-shot with index: [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# Optimization terminated successfully.
#          Current function value: 0.000010
#          Iterations: 33
#          Function evaluations: 245
#          Gradient evaluations: 35
# [SCIPY] Optimization terminated successfully.
# Training Elapsed time: 0.02 minutes
# Selecting demonstration set for LR...
# Testing LR, Seed 2206632489, k: 0, demo index: []
#
# Start testing the forward inference function on the dataset: AGNews
# Testing Elapsed time: 0.45 minutes
# Training LR for 1-shot with index: [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# Optimization terminated successfully.
#          Current function value: 24.965562
#          Iterations: 23
#          Function evaluations: 182
#          Gradient evaluations: 26
# [SCIPY] Optimization terminated successfully.
# Training Elapsed time: 0.11 minutes
# Selecting demonstration set for LR...
# Testing LR, Seed 2206632489, k: 1, demo index: [5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 1, demo index: [116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 1, demo index: [105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 1, demo index: [40092]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing Elapsed time: 2.03 minutes
# Averaging probabilities for LR-1
# 0.8046875
# Training LR for 2-shot with index: [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# Optimization terminated successfully.
#          Current function value: 55.103456
#          Iterations: 43
#          Function evaluations: 322
#          Gradient evaluations: 46
# [SCIPY] Optimization terminated successfully.
# Training Elapsed time: 0.76 minutes
# Selecting demonstration set for LR...
# Testing LR, Seed 2206632489, k: 2, demo index: [105958, 75871]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [5520, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [116599, 40092]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [75871, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [40092, 36867]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [40092, 5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [40092, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [5520, 40092]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [108187, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [116599, 108187]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [75871, 5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 2, demo index: [36867, 108187]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing Elapsed time: 6.67 minutes
# Averaging probabilities for LR-2
# 0.91015625
# Training LR for 3-shot with index: [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# Optimization terminated successfully.
#          Current function value: 192.565863
#          Iterations: 85
#          Function evaluations: 707
#          Gradient evaluations: 101
# [SCIPY] Optimization terminated successfully.
# Training Elapsed time: 5.21 minutes
# Selecting demonstration set for LR...
# Testing LR, Seed 2206632489, k: 3, demo index: [108187, 105958, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [5520, 39714, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [116599, 39714, 5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [39714, 40092, 36867]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [40092, 108187, 75871]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [40092, 75871, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [5520, 105958, 108187]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [5520, 40092, 75871]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [75871, 36867, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [5520, 116599, 36867]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [108187, 5520, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 3, demo index: [105958, 5520, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing Elapsed time: 9.53 minutes
# Averaging probabilities for LR-3
# 0.9140625
# Training LR for 4-shot with index: [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# /hpc/home/jd420/anaconda3/envs/CARE/lib/python3.11/site-packages/scipy/optimize/_minimize.py:705: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 657.960999
#          Iterations: 73
#          Function evaluations: 859
#          Gradient evaluations: 121
# [SCIPY] Desired error not necessarily achieved due to precision loss.
# Training Elapsed time: 23.61 minutes
# Selecting demonstration set for LR...
# Testing LR, Seed 2206632489, k: 4, demo index: [75871, 5520, 36867, 108187]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [5520, 116599, 105958, 75871]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [116599, 40092, 75871, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [108187, 5520, 36867, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [40092, 105958, 75871, 36867]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [40092, 39714, 75871, 5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [40092, 5520, 39714, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [5520, 39714, 105958, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [108187, 5520, 40092, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [116599, 108187, 75871, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [75871, 36867, 5520, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 4, demo index: [108187, 5520, 36867, 40092]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing Elapsed time: 11.41 minutes
# Averaging probabilities for LR-4
# 0.91015625
# Training LR for 5-shot with index: [116599, 5520, 40092, 39714, 36867, 105958, 75871, 108187]
# /hpc/home/jd420/anaconda3/envs/CARE/lib/python3.11/site-packages/scipy/optimize/_minimize.py:705: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#          Current function value: 2217.056438
#          Iterations: 59
#          Function evaluations: 616
#          Gradient evaluations: 88
# [SCIPY] Desired error not necessarily achieved due to precision loss.
# Training Elapsed time: 82.55 minutes
# Selecting demonstration set for LR...
# Testing LR, Seed 2206632489, k: 5, demo index: [75871, 5520, 36867, 108187, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [5520, 116599, 105958, 75871, 40092]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [116599, 40092, 75871, 39714, 5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [108187, 5520, 36867, 105958, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [40092, 105958, 75871, 36867, 5520]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [40092, 39714, 75871, 5520, 105958]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [40092, 5520, 39714, 105958, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [5520, 39714, 105958, 116599, 108187]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [108187, 5520, 40092, 105958, 39714]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [116599, 108187, 75871, 105958, 36867]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [75871, 36867, 5520, 116599, 108187]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing LR, Seed 2206632489, k: 5, demo index: [108187, 5520, 36867, 40092, 75871]
#
# Start testing the forward inference function on the dataset: AGNews
# Testing Elapsed time: 11.99 minutes
# Averaging probabilities for LR-5
# 0.90234375
# Final general average voting for LR

# %%
result
# Out:
# {'AGNews': {'seed_2206632489': {'8': {'CC': {'accuracy': 0.7734375,
#      'averaged_truelabel_likelihood': 0.6794060457737429,
#      'macro_F1': 0.6616333511016347,
#      'expected_calibration_error_1': 0.09861836961608951},
#     'LR-0': {'accuracy': 0.77734375,
#      'averaged_truelabel_likelihood': 0.7772035412572371,
#      'macro_F1': 0.7704264233424202,
#      'expected_calibration_error_1': 0.023293506361596356},
#     'LR-1-[5520]': {'accuracy': 0.75,
#      'averaged_truelabel_likelihood': 0.6819447164950956,
#      'macro_F1': 0.7013794023563733,
#      'expected_calibration_error_1': 0.05090517836975013},
#     'LR-1-[116599]': {'accuracy': 0.8203125,
#      'averaged_truelabel_likelihood': 0.7635070219513804,
#      'macro_F1': 0.8188427825910726,
#      'expected_calibration_error_1': 0.058311366716639106},
#     'LR-1-[105958]': {'accuracy': 0.6015625,
#      'averaged_truelabel_likelihood': 0.6112124095870373,
#      'macro_F1': 0.5899747433230508,
#      'expected_calibration_error_1': 0.240821269516759},
#     'LR-1-[40092]': {'accuracy': 0.62890625,
#      'averaged_truelabel_likelihood': 0.6268730696097521,
#      'macro_F1': 0.6225264632429575,
#      'expected_calibration_error_1': 0.21119194320488502},
#     'LR-1': {'accuracy': 0.7001953125,
#      'averaged_truelabel_likelihood': 0.6708843044108163,
#      'macro_F1': 0.6831808478783635,
#      'expected_calibration_error_1': 0.1403074394520083,
#      'roc_auc': None},
#     'LR-1-average_voting': {'accuracy': 0.8046875,
#      'averaged_truelabel_likelihood': 0.6708843044108166,
#      'macro_F1': 0.8040130519535554,
#      'expected_calibration_error_1': 0.11139834331111825},
#     'LR-2-[105958, 75871]': {'accuracy': 0.828125,
#      'averaged_truelabel_likelihood': 0.804344347996522,
#      'macro_F1': 0.8243161565529986,
#      'expected_calibration_error_1': 0.1200531556712869},
#     'LR-2-[5520, 116599]': {'accuracy': 0.921875,
#      'averaged_truelabel_likelihood': 0.9109773446077475,
#      'macro_F1': 0.9181211994475575,
#      'expected_calibration_error_1': 0.048762942042409496},
#     'LR-2-[116599, 40092]': {'accuracy': 0.8671875,
#      'averaged_truelabel_likelihood': 0.8597339283535795,
#      'macro_F1': 0.8639192471159685,
#      'expected_calibration_error_1': 0.097192044739358},
#     'LR-2-[75871, 105958]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8784832561046731,
#      'macro_F1': 0.8993921635923237,
#      'expected_calibration_error_1': 0.07045835518106064},
#     'LR-2-[40092, 36867]': {'accuracy': 0.87109375,
#      'averaged_truelabel_likelihood': 0.8483673542802556,
#      'macro_F1': 0.8665191096422582,
#      'expected_calibration_error_1': 0.08825531489536018},
#     'LR-2-[40092, 5520]': {'accuracy': 0.87109375,
#      'averaged_truelabel_likelihood': 0.8397140175508977,
#      'macro_F1': 0.8653692064205205,
#      'expected_calibration_error_1': 0.10743465713907538},
#     'LR-2-[40092, 116599]': {'accuracy': 0.81640625,
#      'averaged_truelabel_likelihood': 0.7963008123029509,
#      'macro_F1': 0.8143826271218738,
#      'expected_calibration_error_1': 0.134564161064409},
#     'LR-2-[5520, 40092]': {'accuracy': 0.9296875,
#      'averaged_truelabel_likelihood': 0.9111340414108089,
#      'macro_F1': 0.9273649555046115,
#      'expected_calibration_error_1': 0.05035851701533096},
#     'LR-2-[108187, 39714]': {'accuracy': 0.83984375,
#      'averaged_truelabel_likelihood': 0.8069796621778841,
#      'macro_F1': 0.8387541317495356,
#      'expected_calibration_error_1': 0.0937370581461672},
#     'LR-2-[116599, 108187]': {'accuracy': 0.8984375,
#      'averaged_truelabel_likelihood': 0.8824617397996187,
#      'macro_F1': 0.8986121803395312,
#      'expected_calibration_error_1': 0.07428956846362189},
#     'LR-2-[75871, 5520]': {'accuracy': 0.91796875,
#      'averaged_truelabel_likelihood': 0.8891825558146292,
#      'macro_F1': 0.9125310968395044,
#      'expected_calibration_error_1': 0.04541306621103529},
#     'LR-2-[36867, 108187]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8845699079731609,
#      'macro_F1': 0.8974085615182195,
#      'expected_calibration_error_1': 0.06021850942237479},
#     'LR-2': {'accuracy': 0.8805338541666666,
#      'averaged_truelabel_likelihood': 0.8593540806977273,
#      'macro_F1': 0.8772242196537419,
#      'expected_calibration_error_1': 0.08256144583262413,
#      'roc_auc': None},
#     'LR-2-average_voting': {'accuracy': 0.91015625,
#      'averaged_truelabel_likelihood': 0.8593540806977276,
#      'macro_F1': 0.9070813338255199,
#      'expected_calibration_error_1': 0.03570677969535252},
#     'LR-3-[108187, 105958, 39714]': {'accuracy': 0.90625,
#      'averaged_truelabel_likelihood': 0.8907720959621931,
#      'macro_F1': 0.904750750124538,
#      'expected_calibration_error_1': 0.05148545186913182},
#     'LR-3-[5520, 39714, 105958]': {'accuracy': 0.9140625,
#      'averaged_truelabel_likelihood': 0.9093299097059756,
#      'macro_F1': 0.9109936518899275,
#      'expected_calibration_error_1': 0.05922402176688464},
#     'LR-3-[116599, 39714, 5520]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8908902338190331,
#      'macro_F1': 0.895986209816654,
#      'expected_calibration_error_1': 0.06211911025946791},
#     'LR-3-[39714, 40092, 36867]': {'accuracy': 0.91015625,
#      'averaged_truelabel_likelihood': 0.9077904396966889,
#      'macro_F1': 0.9066564595038706,
#      'expected_calibration_error_1': 0.06923985802659066},
#     'LR-3-[40092, 108187, 75871]': {'accuracy': 0.8359375,
#      'averaged_truelabel_likelihood': 0.8077743136593332,
#      'macro_F1': 0.8319553093964859,
#      'expected_calibration_error_1': 0.10604091821052425},
#     'LR-3-[40092, 75871, 116599]': {'accuracy': 0.83984375,
#      'averaged_truelabel_likelihood': 0.833311112143625,
#      'macro_F1': 0.8349329275626942,
#      'expected_calibration_error_1': 0.1112035258303492},
#     'LR-3-[5520, 105958, 108187]': {'accuracy': 0.8984375,
#      'averaged_truelabel_likelihood': 0.88853898608538,
#      'macro_F1': 0.8965263877684687,
#      'expected_calibration_error_1': 0.05363440871547456},
#     'LR-3-[5520, 40092, 75871]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8932824968251423,
#      'macro_F1': 0.8980136285283344,
#      'expected_calibration_error_1': 0.05788946910537471},
#     'LR-3-[75871, 36867, 39714]': {'accuracy': 0.87890625,
#      'averaged_truelabel_likelihood': 0.8582695634102362,
#      'macro_F1': 0.8771929824561404,
#      'expected_calibration_error_1': 0.0459359660295164},
#     'LR-3-[5520, 116599, 36867]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.9053337476753387,
#      'macro_F1': 0.8943424915185713,
#      'expected_calibration_error_1': 0.06215288285186684},
#     'LR-3-[108187, 5520, 39714]': {'accuracy': 0.87109375,
#      'averaged_truelabel_likelihood': 0.8461769659345739,
#      'macro_F1': 0.861783649071731,
#      'expected_calibration_error_1': 0.0551538967671112},
#     'LR-3-[105958, 5520, 116599]': {'accuracy': 0.8203125,
#      'averaged_truelabel_likelihood': 0.8102106303524946,
#      'macro_F1': 0.8147662320057574,
#      'expected_calibration_error_1': 0.1475374908477303},
#     'LR-3': {'accuracy': 0.8818359375,
#      'averaged_truelabel_likelihood': 0.8701400412725012,
#      'macro_F1': 0.877325056636931,
#      'expected_calibration_error_1': 0.07346808335666855,
#      'roc_auc': None},
#     'LR-3-average_voting': {'accuracy': 0.9140625,
#      'averaged_truelabel_likelihood': 0.8701400412725013,
#      'macro_F1': 0.9105384210860884,
#      'expected_calibration_error_1': 0.019405715311950435},
#     'LR-4-[75871, 5520, 36867, 108187]': {'accuracy': 0.85546875,
#      'averaged_truelabel_likelihood': 0.8370731362687919,
#      'macro_F1': 0.8412850964285732,
#      'expected_calibration_error_1': 0.08093020847049662},
#     'LR-4-[5520, 116599, 105958, 75871]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8951941135481793,
#      'macro_F1': 0.8972559927301307,
#      'expected_calibration_error_1': 0.06760697808094038},
#     'LR-4-[116599, 40092, 75871, 39714]': {'accuracy': 0.875,
#      'averaged_truelabel_likelihood': 0.8639094699345785,
#      'macro_F1': 0.8700552376785369,
#      'expected_calibration_error_1': 0.09989753171364542},
#     'LR-4-[108187, 5520, 36867, 105958]': {'accuracy': 0.90625,
#      'averaged_truelabel_likelihood': 0.8929178448325449,
#      'macro_F1': 0.902207996888848,
#      'expected_calibration_error_1': 0.07349501607716587},
#     'LR-4-[40092, 105958, 75871, 36867]': {'accuracy': 0.8984375,
#      'averaged_truelabel_likelihood': 0.8894218142154765,
#      'macro_F1': 0.8940519915644859,
#      'expected_calibration_error_1': 0.06768596608689617},
#     'LR-4-[40092, 39714, 75871, 5520]': {'accuracy': 0.89453125,
#      'averaged_truelabel_likelihood': 0.8856468029067006,
#      'macro_F1': 0.889874363616205,
#      'expected_calibration_error_1': 0.09098340369321413},
#     'LR-4-[40092, 5520, 39714, 105958]': {'accuracy': 0.89453125,
#      'averaged_truelabel_likelihood': 0.8928251252279144,
#      'macro_F1': 0.8899396612158307,
#      'expected_calibration_error_1': 0.08449856413365044},
#     'LR-4-[5520, 39714, 105958, 116599]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8971429016398739,
#      'macro_F1': 0.8973827001348754,
#      'expected_calibration_error_1': 0.08445278534406725},
#     'LR-4-[108187, 5520, 40092, 105958]': {'accuracy': 0.890625,
#      'averaged_truelabel_likelihood': 0.879680106391848,
#      'macro_F1': 0.8884956002334282,
#      'expected_calibration_error_1': 0.06310698141238347},
#     'LR-4-[116599, 108187, 75871, 105958]': {'accuracy': 0.8515625,
#      'averaged_truelabel_likelihood': 0.8447514499319065,
#      'macro_F1': 0.8470866067447872,
#      'expected_calibration_error_1': 0.11575438634101327},
#     'LR-4-[75871, 36867, 5520, 116599]': {'accuracy': 0.890625,
#      'averaged_truelabel_likelihood': 0.8767886725840301,
#      'macro_F1': 0.887631445276616,
#      'expected_calibration_error_1': 0.05419794148349037},
#     'LR-4-[108187, 5520, 36867, 40092]': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.89152106528516,
#      'macro_F1': 0.8996113719353155,
#      'expected_calibration_error_1': 0.053276341903996445},
#     'LR-4': {'accuracy': 0.888671875,
#      'averaged_truelabel_likelihood': 0.8789060418972504,
#      'macro_F1': 0.8837398387039693,
#      'expected_calibration_error_1': 0.07799050872841332,
#      'roc_auc': None},
#     'LR-4-average_voting': {'accuracy': 0.91015625,
#      'averaged_truelabel_likelihood': 0.8789060418972501,
#      'macro_F1': 0.905969935037823,
#      'expected_calibration_error_1': 0.050314030305642764},
#     'LR-5-[75871, 5520, 36867, 108187, 39714]': {'accuracy': 0.8671875,
#      'averaged_truelabel_likelihood': 0.8438704149553143,
#      'macro_F1': 0.8580890707425661,
#      'expected_calibration_error_1': 0.07116875985387675},
#     'LR-5-[5520, 116599, 105958, 75871, 40092]': {'accuracy': 0.890625,
#      'averaged_truelabel_likelihood': 0.8898159770360725,
#      'macro_F1': 0.8849921997058207,
#      'expected_calibration_error_1': 0.07161993338752784},
#     'LR-5-[116599, 40092, 75871, 39714, 5520]': {'accuracy': 0.890625,
#      'averaged_truelabel_likelihood': 0.8828613191114202,
#      'macro_F1': 0.8849906001827255,
#      'expected_calibration_error_1': 0.08502343236263463},
#     'LR-5-[108187, 5520, 36867, 105958, 39714]': {'accuracy': 0.875,
#      'averaged_truelabel_likelihood': 0.8621630910296872,
#      'macro_F1': 0.8719538865262064,
#      'expected_calibration_error_1': 0.07537184592148681},
#     'LR-5-[40092, 105958, 75871, 36867, 5520]': {'accuracy': 0.875,
#      'averaged_truelabel_likelihood': 0.8573157605567516,
#      'macro_F1': 0.8695422793872127,
#      'expected_calibration_error_1': 0.09651277443173942},
#     'LR-5-[40092, 39714, 75871, 5520, 105958]': {'accuracy': 0.91015625,
#      'averaged_truelabel_likelihood': 0.901778463290505,
#      'macro_F1': 0.906415343915344,
#      'expected_calibration_error_1': 0.06722603844108993},
#     'LR-5-[40092, 5520, 39714, 105958, 116599]': {'accuracy': 0.8828125,
#      'averaged_truelabel_likelihood': 0.8736548836584093,
#      'macro_F1': 0.8791983016983016,
#      'expected_calibration_error_1': 0.0976562210294088},
#     'LR-5-[5520, 39714, 105958, 116599, 108187]': {'accuracy': 0.89453125,
#      'averaged_truelabel_likelihood': 0.882950052073784,
#      'macro_F1': 0.8891970864306931,
#      'expected_calibration_error_1': 0.08416871484744404},
#     'LR-5-[108187, 5520, 40092, 105958, 39714]': {'accuracy': 0.89453125,
#      'averaged_truelabel_likelihood': 0.8792778368461042,
#      'macro_F1': 0.8913032371896268,
#      'expected_calibration_error_1': 0.05810810864620933},
#     'LR-5-[116599, 108187, 75871, 105958, 36867]': {'accuracy': 0.890625,
#      'averaged_truelabel_likelihood': 0.8837709468550405,
#      'macro_F1': 0.884889977597722,
#      'expected_calibration_error_1': 0.08140165885529775},
#     'LR-5-[75871, 36867, 5520, 116599, 108187]': {'accuracy': 0.87109375,
#      'averaged_truelabel_likelihood': 0.8545806850382853,
#      'macro_F1': 0.8650551759829452,
#      'expected_calibration_error_1': 0.06247934491234167},
#     'LR-5-[108187, 5520, 36867, 40092, 75871]': {'accuracy': 0.8984375,
#      'averaged_truelabel_likelihood': 0.8760559731290687,
#      'macro_F1': 0.8944313784612292,
#      'expected_calibration_error_1': 0.062280598416439216},
#     'LR-5': {'accuracy': 0.88671875,
#      'averaged_truelabel_likelihood': 0.8740079502983703,
#      'macro_F1': 0.8816715448183662,
#      'expected_calibration_error_1': 0.076084785925458,
#      'roc_auc': None},
#     'LR-5-average_voting': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8740079502983701,
#      'macro_F1': 0.8978344660940369,
#      'expected_calibration_error_1': 0.03983960259255142},
#     'LR-average_voting': {'accuracy': 0.90234375,
#      'averaged_truelabel_likelihood': 0.8743306032249301,
#      'macro_F1': 0.8978344660940369,
#      'expected_calibration_error_1': 0.04587410905896197}}}}}

# %% [markdown]
# # Main Experiment Runner for All Datasets

# %%
import inspect

# Settings
test_samples = 512
seed = 107

# Auto-detect all dataset loader functions in data_loader (e.g., glue_sst2, agnews, yelp, etc.)
dataset_loaders = {
    name: func for name, func in inspect.getmembers(data_loader, inspect.isclass)
    if not name.startswith("_")  # skip private functions
}

# Now split and store them
all_splitted_datasets = []

for name, load_fn in dataset_loaders.items():
    try:
        print(f"Loading and splitting: {name}")
        dataset = load_fn(from_cache=True)
        train_samples = len(dataset) - test_samples
        splitted = dataset_interface.DatasetSplitter(dataset, train_samples, test_samples, seed)
        all_splitted_datasets.append(splitted)
    except Exception as e:
        print(f"Skipping {name} due to error: {e}")
# Out:
# Loading and splitting: agnews
# Loading and splitting: datasets_loader
# Skipping datasets_loader due to error: datasets_loader.__init__() got an unexpected keyword argument 'from_cache'
# Loading and splitting: financial_phrasebank
# Loading and splitting: glue_sst2
# Loading and splitting: rotten_tomatoes
# Loading and splitting: sst5
# Loading and splitting: subjective
# Loading and splitting: trec
# Loading and splitting: tweet_eval_emotion
# Loading and splitting: tweet_eval_hate

# %%
dataset_loaders.keys()
# Out:
# dict_keys(['agnews', 'datasets_loader', 'financial_phrasebank', 'glue_sst2', 'rotten_tomatoes', 'sst5', 'subjective', 'trec', 'tweet_eval_emotion', 'tweet_eval_hate'])

# %%
result, _, _ = run_multiple_calibration_experiments_generic(model=model,
                                                            tokenizer=tokenizer,
                                                            splitted_datasets=all_splitted_datasets,
                                                            seeds=[2206632489],
                                                            k_values=[4],
                                                            param_dic=param_dic,
                                                            methods_to_run=['CC','Baseline'])
# Out:
# Starting experiments on dataset: AGNews
# No dataset-specific param_dic found for 'AGNews', using generic config.
#
# === Running experiment for AGNews | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [105838, 40576, 116599, 39740]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: financial_phrasebank
# No dataset-specific param_dic found for 'financial_phrasebank', using generic config.
#
# === Running experiment for financial_phrasebank | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: financial_phrasebank
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [1553, 1016, 145, 653]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: financial_phrasebank
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: GLUE-SST2
# No dataset-specific param_dic found for 'GLUE-SST2', using generic config.
#
# === Running experiment for GLUE-SST2 | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: GLUE-SST2
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [56986, 8856, 22885, 66029]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: GLUE-SST2
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: rotten_tomatoes
# No dataset-specific param_dic found for 'rotten_tomatoes', using generic config.
#
# === Running experiment for rotten_tomatoes | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: rotten_tomatoes
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3930, 615, 2546, 7320]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: rotten_tomatoes
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: SST5
# No dataset-specific param_dic found for 'SST5', using generic config.
#
# === Running experiment for SST5 | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: SST5
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [4490, 3236, 515, 5994]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: SST5
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: Subjective
# No dataset-specific param_dic found for 'Subjective', using generic config.
#
# === Running experiment for Subjective | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: Subjective
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3887, 635, 2580, 7352]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: Subjective
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: TREC
# No dataset-specific param_dic found for 'TREC', using generic config.
#
# === Running experiment for TREC | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: TREC
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [2678, 5438, 260, 3123]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: TREC
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: tweet_eval_emotion
# No dataset-specific param_dic found for 'tweet_eval_emotion', using generic config.
#
# === Running experiment for tweet_eval_emotion | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: tweet_eval_emotion
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [2466, 1802, 2407, 4363]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: tweet_eval_emotion
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: tweet_eval_hate
# No dataset-specific param_dic found for 'tweet_eval_hate', using generic config.
#
# === Running experiment for tweet_eval_hate | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: tweet_eval_hate
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [2931, 1068, 6849, 2971]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: tweet_eval_hate
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
result
# Out:
# {'AGNews': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.8046875,
#      'averaged_truelabel_likelihood': 0.7641413473719553,
#      'macro_F1': 0.7536930728074809,
#      'expected_calibration_error_1': 0.06561180607939154},
#     'CC': {'accuracy': 0.810546875,
#      'averaged_truelabel_likelihood': 0.6937629945875696,
#      'macro_F1': 0.7599705119131871,
#      'expected_calibration_error_1': 0.09705838704801596}}}},
#  'financial_phrasebank': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.796875,
#      'averaged_truelabel_likelihood': 0.7263263075424782,
#      'macro_F1': 0.7163742559340863,
#      'expected_calibration_error_1': 0.03540531476133088},
#     'CC': {'accuracy': 0.861328125,
#      'averaged_truelabel_likelihood': 0.6850761934791803,
#      'macro_F1': 0.8255112659520267,
#      'expected_calibration_error_1': 0.1300423525579212}}}},
#  'GLUE-SST2': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.93359375,
#      'averaged_truelabel_likelihood': 0.8619928194188831,
#      'macro_F1': 0.9301298826400373,
#      'expected_calibration_error_1': 0.05651052021842182},
#     'CC': {'accuracy': 0.93359375,
#      'averaged_truelabel_likelihood': 0.8210293075836175,
#      'macro_F1': 0.9301298826400373,
#      'expected_calibration_error_1': 0.09653238843614527}}}},
#  'rotten_tomatoes': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.908203125,
#      'averaged_truelabel_likelihood': 0.807675301639974,
#      'macro_F1': 0.9080765366735044,
#      'expected_calibration_error_1': 0.058909147541725534},
#     'CC': {'accuracy': 0.91796875,
#      'averaged_truelabel_likelihood': 0.8129440646367029,
#      'macro_F1': 0.9179674982833601,
#      'expected_calibration_error_1': 0.0820531466890903}}}},
#  'SST5': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.240234375,
#      'averaged_truelabel_likelihood': 0.23642533736088003,
#      'macro_F1': 0.15314272118015623,
#      'expected_calibration_error_1': 0.4924660981695832},
#     'CC': {'accuracy': 0.533203125,
#      'averaged_truelabel_likelihood': 0.5212676706400284,
#      'macro_F1': 0.3470501159265204,
#      'expected_calibration_error_1': 0.43001305373386217}}}},
#  'Subjective': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.5,
#      'averaged_truelabel_likelihood': 0.5097503155522312,
#      'macro_F1': 0.3816425120772947,
#      'expected_calibration_error_1': 0.16306644064680775},
#     'CC': {'accuracy': 0.478515625,
#      'averaged_truelabel_likelihood': 0.4841026968742074,
#      'macro_F1': 0.3236459709379128,
#      'expected_calibration_error_1': 0.391533309428138}}}},
#  'TREC': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.68359375,
#      'averaged_truelabel_likelihood': 0.5834069296040577,
#      'macro_F1': 0.6300217225028663,
#      'expected_calibration_error_1': 0.06777041803421524},
#     'CC': {'accuracy': 0.4609375,
#      'averaged_truelabel_likelihood': 0.43243921865726137,
#      'macro_F1': 0.3565700572357575,
#      'expected_calibration_error_1': 0.44630069394772814}}}},
#  'tweet_eval_emotion': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.775390625,
#      'averaged_truelabel_likelihood': 0.6039369806792659,
#      'macro_F1': 0.7229759784186737,
#      'expected_calibration_error_1': 0.10472302067348808},
#     'CC': {'accuracy': 0.583984375,
#      'averaged_truelabel_likelihood': 0.5635857973284263,
#      'macro_F1': 0.35812921255959235,
#      'expected_calibration_error_1': 0.3236386425446882}}}},
#  'tweet_eval_hate': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.443359375,
#      'averaged_truelabel_likelihood': 0.48078746003306183,
#      'macro_F1': 0.3241910160754728,
#      'expected_calibration_error_1': 0.3028804316824659},
#     'CC': {'accuracy': 0.43359375,
#      'averaged_truelabel_likelihood': 0.46168216398153006,
#      'macro_F1': 0.3024523160762943,
#      'expected_calibration_error_1': 0.3549221061404084}}}}}

# %%
result.keys()
# Out:
# dict_keys(['AGNews', 'financial_phrasebank', 'GLUE-SST2', 'rotten_tomatoes', 'SST5', 'Subjective', 'TREC', 'tweet_eval_emotion', 'tweet_eval_hate'])

# %%
result['AGNews']
# Out:
# {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.8046875,
#     'averaged_truelabel_likelihood': 0.7641413473719553,
#     'macro_F1': 0.7536930728074809,
#     'expected_calibration_error_1': 0.06561180607939154},
#    'CC': {'accuracy': 0.810546875,
#     'averaged_truelabel_likelihood': 0.6937629945875696,
#     'macro_F1': 0.7599705119131871,
#     'expected_calibration_error_1': 0.09705838704801596}}}}
