# %% [markdown]
# # Main Experiment Runner for One Dataset Example

# %%
from ICL_modules import data_loader, dataset_interface, s_random, experiment_basics, functions
from ICL_inference import inference
from ICL_calibrations import calibration_methods
from run import run_multiple_calibration_experiments_generic
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    LogitsProcessorList,
    LogitsProcessor
)
import random
import torch
import numpy as np
import pandas as pd
import itertools
import functools
import copy

# %%
# ---------------------------------------------
# Define the model identifier from HuggingFace Hub
# This should be the path or name of a pre-trained language model that supports causal (auto-regressive) generation.
MODEL_ID = "<your-model-id>"

# Define the HuggingFace authentication token if the model is gated or requires private access.
HF_TOKEN = "<your-huggingface-access-token>"

# ---------------------------------------------
# Load the tokenizer associated with the model.
# The tokenizer is responsible for converting raw text into token IDs (and vice versa).
# Authentication token is passed if required.
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_auth_token=HF_TOKEN)

# ---------------------------------------------
# Load the pre-trained causal language model.
# - device_map=\"auto\": Automatically places model components on available devices (GPU/CPU).
# - torch_dtype=torch.float16: Loads the model in half-precision for reduced memory usage and faster inference.
# - .eval(): Sets the model to evaluation mode (disabling any training-specific behavior).
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map="auto",
    torch_dtype=torch.float16,
    use_auth_token=HF_TOKEN
).eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:862: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
# ---------------------------------------------
# Use data_loader class to upload data from cache
# As an example, AGNews is used
ag_news= data_loader.agnews(from_cache = True)
seed = 107
test_samples = 512
train_samples = len(ag_news) - test_samples
splitted_ag = dataset_interface.DatasetSplitter(ag_news, train_samples,test_samples,seed)

# %%
# --------------------------------------------------------
# param_dic: Hyperparameter config for LR calibration
# --------------------------------------------------------
# This dictionary defines cosine-threshold and invariance-strength values
# used during logistic regression calibration.

# Usage:
# param_dic can be either:
#
# (1) Generic (used for all datasets):
# ---------------------------------------------------
# param_dic = {
#     4: { 0: [15, 0.8], 1: [5.5, 0.8], ..., 3: [4.5, 0.8] },
#     8: { 0: [...], ..., 7: [...] }
# }
#
# (2) Dataset-specific:
# ---------------------------------------------------
# param_dic = {
#     "sst2": {
#         4: { 0: [15, 0.8], ..., 3: [4.5, 0.8] },
#         8: { 0: [...], ..., 7: [...] }
#     },
#     "agnews": {
#         4: { ... },
#         8: { ... }
#     }
# }

# Meaning of inner values:
# param_dic[k][i] = [cosine_factor, invariance_strength]
# Where:
#   - `k` is the total number of shots
#   - `i` is the current sub-shot index (0 ≤ i < k)
#   - `cosine_factor`: used as denominator in cos(π / cosine_factor) for threshold
#                      → higher values mean stricter similarity filter
#   - `invariance_strength`: regularization weight (typically 0–1)

#   Example:
#   cosine_threshold = cos(π / 4.5) ≈ 0.22
#   param_dic[4][3] = [4.5, 0.8]



param_dic = {
    4: {
        0: [15, 0.8],
        1: [5.5, 0.8],
        2: [5, 0.7],
        3: [4.5, 0.8]
    }
}

# %%
# Run a calibration experiment using the Contextual Calibration (CC) method.
#
# Arguments:
# - model / tokenizer: HuggingFace-compatible model and tokenizer.
# - splitted_datasets: One or more dataset splits (train/test) ready for calibration.
# - seeds: List of seeds for random sampling of demonstration examples (for reproducibility).
# - k_values: List of values for k-shot learning (number of demonstrations in-context).
# - param_dic: Dictionary of hyperparameters (used mainly for LR).
# - methods_to_run: Specifies which calibration methods to run. Here, we use only 'LR'.
#
# Returns:
# - result: A dictionary containing performance metrics for each dataset, seed, and k.
# - The other two return values (ignored here) include:
#     - dfs: Calibration-specific dataframes (mostly used by LR).
#     - coefficients_dic: Calibration coefficients (also for LR).
#
# This call executes LR calibration on the provided model and dataset, printing progress logs as it runs.

result, _, _ = run_multiple_calibration_experiments_generic(
    model=model,
    tokenizer=tokenizer,
    splitted_datasets=splitted_ag,
    seeds=[2206632489],
    k_values=[4],
    param_dic=param_dic,
    methods_to_run=['LR']
)
# Out:
# Starting experiments on dataset: AGNews
# No dataset-specific param_dic found for 'AGNews', using generic config.
#
# === Running experiment for AGNews | Seed 2206632489, k: 4 ===
# Running LR Calibration
# Training LR for 0-shot with index: [105838, 40576, 116599, 39740]
# [105838, 40576, 116599, 39740]
# Process: 100% [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 4/4
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:551: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# [SCIPY] Calibration Training Finished.
#
# Testing LR, Seed 2206632489, k: 0, demo index: []
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Training LR for 1-shot with index: [105838, 40576, 116599, 39740]
# [105838, 40576, 116599, 39740]
# Process: 100% [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 12/12
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:551: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:316: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(self.x - self.x_prev, self.g - self.g_prev)
# [SCIPY] Calibration Training Finished.
#
# Testing LR, Seed 2206632489, k: 1, demo index: [105838]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 1, demo index: [39740]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Averaging probabilities for LR-1
# 0.763671875
# Training LR for 2-shot with index: [105838, 40576, 116599, 39740]
# [105838, 40576, 116599, 39740]
# Process: 100% [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 24/24
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:551: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# [SCIPY] Calibration Training Finished.
#
# Testing LR, Seed 2206632489, k: 2, demo index: [39740, 40576]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 2, demo index: [105838, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 2, demo index: [105838, 40576]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 2, demo index: [40576, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 2, demo index: [40576, 105838]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 2, demo index: [39740, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Averaging probabilities for LR-2
# 0.810546875
# Training LR for 3-shot with index: [105838, 40576, 116599, 39740]
# [105838, 40576, 116599, 39740]
# Process: 100% [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 24/24
# /usr/local/lib/python3.11/dist-packages/scipy/optimize/_differentiable_functions.py:551: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# [SCIPY] Calibration Training Finished.
#
# Testing LR, Seed 2206632489, k: 3, demo index: [39740, 40576, 105838]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [105838, 116599, 39740]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [105838, 40576, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [40576, 116599, 105838]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [40576, 105838, 39740]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [39740, 105838, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [105838, 39740, 40576]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [39740, 116599, 105838]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [105838, 116599, 40576]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [40576, 116599, 39740]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [40576, 105838, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Testing LR, Seed 2206632489, k: 3, demo index: [39740, 40576, 116599]
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Averaging probabilities for LR-3
# 0.84375
# Final general average voting for LR

# %%
result
# Out:
# {'AGNews': {'seed_2206632489': {'4': {'LR-0': {'accuracy': 0.7421875,
#      'averaged_truelabel_likelihood': 0.7432745506910318,
#      'macro_F1': 0.7063868395123042,
#      'expected_calibration_error_1': 0.2365214109683676},
#     'LR-1-[105838]': {'accuracy': 0.724609375,
#      'averaged_truelabel_likelihood': 0.2500000188309639,
#      'macro_F1': 0.6172070137910985,
#      'expected_calibration_error_1': 0.4746093527636165},
#     'LR-1-[39740]': {'accuracy': 0.68359375,
#      'averaged_truelabel_likelihood': 0.2500000176435237,
#      'macro_F1': 0.5943106353454257,
#      'expected_calibration_error_1': 0.4335937255541975},
#     'LR-1': {'accuracy': np.float64(0.7041015625),
#      'averaged_truelabel_likelihood': np.float64(0.2500000182372438),
#      'macro_F1': np.float64(0.6057588245682621),
#      'expected_calibration_error_1': np.float64(0.454101539158907),
#      'roc_auc': None},
#     'LR-1-average_voting': {'accuracy': 0.763671875,
#      'averaged_truelabel_likelihood': 0.2500000182372439,
#      'macro_F1': 0.6546981030164247,
#      'expected_calibration_error_1': 0.5136718525164548},
#     'LR-2-[39740, 40576]': {'accuracy': 0.796875,
#      'averaged_truelabel_likelihood': 0.7793264919628832,
#      'macro_F1': 0.7360600531519432,
#      'expected_calibration_error_1': 0.16081397170456765},
#     'LR-2-[105838, 116599]': {'accuracy': 0.79296875,
#      'averaged_truelabel_likelihood': 0.7805003122968153,
#      'macro_F1': 0.7267263451005453,
#      'expected_calibration_error_1': 0.15317471227185128},
#     'LR-2-[105838, 40576]': {'accuracy': 0.814453125,
#      'averaged_truelabel_likelihood': 0.79853480962347,
#      'macro_F1': 0.7696382796398622,
#      'expected_calibration_error_1': 0.12575071330024154},
#     'LR-2-[40576, 116599]': {'accuracy': 0.82421875,
#      'averaged_truelabel_likelihood': 0.7885586289296732,
#      'macro_F1': 0.7909529403911426,
#      'expected_calibration_error_1': 0.13465189205138356},
#     'LR-2-[40576, 105838]': {'accuracy': 0.845703125,
#      'averaged_truelabel_likelihood': 0.8109178174963367,
#      'macro_F1': 0.8215068306651727,
#      'expected_calibration_error_1': 0.08522239282136893},
#     'LR-2-[39740, 116599]': {'accuracy': 0.75390625,
#      'averaged_truelabel_likelihood': 0.7426914868914309,
#      'macro_F1': 0.6651016704624234,
#      'expected_calibration_error_1': 0.19608925091636523},
#     'LR-2': {'accuracy': np.float64(0.8046875),
#      'averaged_truelabel_likelihood': np.float64(0.7834215912001016),
#      'macro_F1': np.float64(0.7516643532351815),
#      'expected_calibration_error_1': np.float64(0.14261715551096302),
#      'roc_auc': None},
#     'LR-2-average_voting': {'accuracy': 0.810546875,
#      'averaged_truelabel_likelihood': 0.7834215912001014,
#      'macro_F1': 0.7606509106418725,
#      'expected_calibration_error_1': 0.12994164703769961},
#     'LR-3-[39740, 40576, 105838]': {'accuracy': 0.845703125,
#      'averaged_truelabel_likelihood': 0.8186926186619822,
#      'macro_F1': 0.8168665881460297,
#      'expected_calibration_error_1': 0.08452843635461219},
#     'LR-3-[105838, 116599, 39740]': {'accuracy': 0.8203125,
#      'averaged_truelabel_likelihood': 0.8035097256421111,
#      'macro_F1': 0.7793388972936441,
#      'expected_calibration_error_1': 0.12157626877334503},
#     'LR-3-[105838, 40576, 116599]': {'accuracy': 0.83984375,
#      'averaged_truelabel_likelihood': 0.8171298995256099,
#      'macro_F1': 0.8133744333075094,
#      'expected_calibration_error_1': 0.08674024143639157},
#     'LR-3-[40576, 116599, 105838]': {'accuracy': 0.86328125,
#      'averaged_truelabel_likelihood': 0.824768513938771,
#      'macro_F1': 0.8508924888948842,
#      'expected_calibration_error_1': 0.04824355422062096},
#     'LR-3-[40576, 105838, 39740]': {'accuracy': 0.880859375,
#      'averaged_truelabel_likelihood': 0.8389395695801555,
#      'macro_F1': 0.8691624141155486,
#      'expected_calibration_error_1': 0.040316765037843774},
#     'LR-3-[39740, 105838, 116599]': {'accuracy': 0.79296875,
#      'averaged_truelabel_likelihood': 0.7756601702055241,
#      'macro_F1': 0.7252063842529096,
#      'expected_calibration_error_1': 0.13753988980378828},
#     'LR-3-[105838, 39740, 40576]': {'accuracy': 0.833984375,
#      'averaged_truelabel_likelihood': 0.818608186540374,
#      'macro_F1': 0.8044428546054914,
#      'expected_calibration_error_1': 0.09865966438274067},
#     'LR-3-[39740, 116599, 105838]': {'accuracy': 0.81640625,
#      'averaged_truelabel_likelihood': 0.7943228590982894,
#      'macro_F1': 0.76712323485412,
#      'expected_calibration_error_1': 0.11135665381015293},
#     'LR-3-[105838, 116599, 40576]': {'accuracy': 0.84375,
#      'averaged_truelabel_likelihood': 0.8178194777417582,
#      'macro_F1': 0.8182339608528146,
#      'expected_calibration_error_1': 0.09447465299913554},
#     'LR-3-[40576, 116599, 39740]': {'accuracy': 0.853515625,
#      'averaged_truelabel_likelihood': 0.8211370788662514,
#      'macro_F1': 0.8361150553566284,
#      'expected_calibration_error_1': 0.07019161427305601},
#     'LR-3-[40576, 105838, 116599]': {'accuracy': 0.85546875,
#      'averaged_truelabel_likelihood': 0.8268924499744482,
#      'macro_F1': 0.8392791259583543,
#      'expected_calibration_error_1': 0.07450796415252936},
#     'LR-3-[39740, 40576, 116599]': {'accuracy': 0.81640625,
#      'averaged_truelabel_likelihood': 0.7940162973724669,
#      'macro_F1': 0.7737540941600384,
#      'expected_calibration_error_1': 0.12939303527242918},
#     'LR-3': {'accuracy': np.float64(0.8385416666666666),
#      'averaged_truelabel_likelihood': np.float64(0.8126247372623118),
#      'macro_F1': np.float64(0.8078157943164977),
#      'expected_calibration_error_1': np.float64(0.09146072837638712),
#      'roc_auc': None},
#     'LR-3-average_voting': {'accuracy': 0.84375,
#      'averaged_truelabel_likelihood': 0.8126247372623109,
#      'macro_F1': 0.8171771877952225,
#      'expected_calibration_error_1': 0.07879690632744733},
#     'LR-average_voting': {'accuracy': 0.830078125,
#      'averaged_truelabel_likelihood': 0.6918470360110773,
#      'macro_F1': 0.7940666301944694,
#      'expected_calibration_error_1': 0.0645870403108537}}}}}

# %% [markdown]
# # Main Experiment Runner for All Datasets

# %%
import inspect

# Settings
test_samples = 512
seed = 107

# Auto-detect all dataset loader functions in data_loader (e.g., glue_sst2, agnews, yelp, etc.)
dataset_loaders = {
    name: func for name, func in inspect.getmembers(data_loader, inspect.isclass)
    if not name.startswith("_")  # skip private functions
}

# Now split and store them
all_splitted_datasets = []

for name, load_fn in dataset_loaders.items():
    try:
        print(f"Loading and splitting: {name}")
        dataset = load_fn(from_cache=True)
        train_samples = len(dataset) - test_samples
        splitted = dataset_interface.DatasetSplitter(dataset, train_samples, test_samples, seed)
        all_splitted_datasets.append(splitted)
    except Exception as e:
        print(f"Skipping {name} due to error: {e}")
# Out:
# Loading and splitting: agnews
# Loading and splitting: datasets_loader
# Skipping datasets_loader due to error: datasets_loader.__init__() got an unexpected keyword argument 'from_cache'
# Loading and splitting: financial_phrasebank
# Loading and splitting: glue_sst2
# Loading and splitting: rotten_tomatoes
# Loading and splitting: sst5
# Loading and splitting: subjective
# Loading and splitting: trec
# Loading and splitting: tweet_eval_emotion
# Loading and splitting: tweet_eval_hate

# %%
result, _, _ = run_multiple_calibration_experiments_generic(model=model,
                                                            tokenizer=tokenizer,
                                                            splitted_datasets=all_splitted_datasets,
                                                            seeds=seeds[:2],
                                                            k_values=[4],
                                                            param_dic=param_dic,
                                                            methods_to_run=['CC','Baseline']
                                                        )
# Out:
# Starting experiments on dataset: AGNews
# No dataset-specific param_dic found for 'AGNews', using generic config.
#
# === Running experiment for AGNews | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [105838, 40576, 116599, 39740]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for AGNews | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [29271, 88619, 11794, 23579]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: AGNews
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: financial_phrasebank
# No dataset-specific param_dic found for 'financial_phrasebank', using generic config.
#
# === Running experiment for financial_phrasebank | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: financial_phrasebank
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [1553, 1016, 145, 653]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: financial_phrasebank
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for financial_phrasebank | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: financial_phrasebank
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [600, 209, 932, 589]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: financial_phrasebank
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: GLUE-SST2
# No dataset-specific param_dic found for 'GLUE-SST2', using generic config.
#
# === Running experiment for GLUE-SST2 | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: GLUE-SST2
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [56986, 8856, 22885, 66029]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: GLUE-SST2
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for GLUE-SST2 | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: GLUE-SST2
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [13514, 6479, 55431, 34282]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: GLUE-SST2
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: rotten_tomatoes
# No dataset-specific param_dic found for 'rotten_tomatoes', using generic config.
#
# === Running experiment for rotten_tomatoes | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: rotten_tomatoes
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3930, 615, 2546, 7320]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: rotten_tomatoes
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for rotten_tomatoes | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: rotten_tomatoes
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3828, 1517, 2439, 7352]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: rotten_tomatoes
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: SST5
# No dataset-specific param_dic found for 'SST5', using generic config.
#
# === Running experiment for SST5 | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: SST5
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [4490, 3236, 515, 5994]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: SST5
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for SST5 | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: SST5
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3475, 1293, 1032, 6655]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: SST5
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: Subjective
# No dataset-specific param_dic found for 'Subjective', using generic config.
#
# === Running experiment for Subjective | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: Subjective
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3887, 635, 2580, 7352]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: Subjective
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for Subjective | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: Subjective
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [3773, 1525, 2463, 7325]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: Subjective
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: TREC
# No dataset-specific param_dic found for 'TREC', using generic config.
#
# === Running experiment for TREC | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: TREC
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [2678, 5438, 260, 3123]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: TREC
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for TREC | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: TREC
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [1958, 921, 652, 2551]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: TREC
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: tweet_eval_emotion
# No dataset-specific param_dic found for 'tweet_eval_emotion', using generic config.
#
# === Running experiment for tweet_eval_emotion | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: tweet_eval_emotion
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [2466, 1802, 2407, 4363]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: tweet_eval_emotion
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for tweet_eval_emotion | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: tweet_eval_emotion
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [1972, 3922, 675, 901]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: tweet_eval_emotion
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Starting experiments on dataset: tweet_eval_hate
# No dataset-specific param_dic found for 'tweet_eval_hate', using generic config.
#
# === Running experiment for tweet_eval_hate | Seed 2206632489, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: tweet_eval_hate
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [2931, 1068, 6849, 2971]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: tweet_eval_hate
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# === Running experiment for tweet_eval_hate | Seed 2481609806, k: 4 ===
# Running Baseline...
#
# Start testing the forward inference function on the dataset: tweet_eval_hate
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Running Contextual Calibration (CC)...
# [1783, 886, 6649, 4157]
# Process: 100%, 3 in 3 >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Calibration Training Finished.
#
#
# Start testing the forward inference function on the dataset: tweet_eval_hate
# Process: 100.0% |   512 / 512 | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
result
# Out:
# {'AGNews': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.806640625,
#      'averaged_truelabel_likelihood': np.float32(0.7641576),
#      'macro_F1': 0.7572663723666802,
#      'expected_calibration_error_1': np.float32(0.06762034)},
#     'CC': {'accuracy': 0.810546875,
#      'averaged_truelabel_likelihood': 0.6936887978744313,
#      'macro_F1': 0.7599705119131871,
#      'expected_calibration_error_1': 0.09593932651276135}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.751953125,
#      'averaged_truelabel_likelihood': np.float32(0.70814496),
#      'macro_F1': 0.6724641295584752,
#      'expected_calibration_error_1': np.float32(0.08280731)},
#     'CC': {'accuracy': 0.75,
#      'averaged_truelabel_likelihood': 0.6660673491577983,
#      'macro_F1': 0.6678602581822496,
#      'expected_calibration_error_1': 0.07627313297367812}}}},
#  'financial_phrasebank': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.796875,
#      'averaged_truelabel_likelihood': np.float32(0.72628176),
#      'macro_F1': 0.7163742559340863,
#      'expected_calibration_error_1': np.float32(0.039333306)},
#     'CC': {'accuracy': 0.865234375,
#      'averaged_truelabel_likelihood': 0.6851700364901209,
#      'macro_F1': 0.8328300266311958,
#      'expected_calibration_error_1': 0.1314115467607516}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.736328125,
#      'averaged_truelabel_likelihood': np.float32(0.7086205),
#      'macro_F1': 0.5545702747025608,
#      'expected_calibration_error_1': np.float32(0.100809656)},
#     'CC': {'accuracy': 0.8671875,
#      'averaged_truelabel_likelihood': 0.6413444372249284,
#      'macro_F1': 0.8227805063284772,
#      'expected_calibration_error_1': 0.1844503106633998}}}},
#  'GLUE-SST2': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.93359375,
#      'averaged_truelabel_likelihood': np.float32(0.8620064),
#      'macro_F1': 0.9301298826400373,
#      'expected_calibration_error_1': np.float32(0.05651637)},
#     'CC': {'accuracy': 0.93359375,
#      'averaged_truelabel_likelihood': 0.8210379214323493,
#      'macro_F1': 0.9301298826400373,
#      'expected_calibration_error_1': 0.09813897398014665}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.939453125,
#      'averaged_truelabel_likelihood': np.float32(0.86458415),
#      'macro_F1': 0.9378988430372912,
#      'expected_calibration_error_1': np.float32(0.04909074)},
#     'CC': {'accuracy': 0.951171875,
#      'averaged_truelabel_likelihood': 0.8511534024649128,
#      'macro_F1': 0.9495059074143475,
#      'expected_calibration_error_1': 0.07314475973992343}}}},
#  'rotten_tomatoes': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.90625,
#      'averaged_truelabel_likelihood': np.float32(0.8075279),
#      'macro_F1': 0.9061067302402348,
#      'expected_calibration_error_1': np.float32(0.057048753)},
#     'CC': {'accuracy': 0.91796875,
#      'averaged_truelabel_likelihood': 0.8128613392587124,
#      'macro_F1': 0.9179674982833601,
#      'expected_calibration_error_1': 0.0821283143792945}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.916015625,
#      'averaged_truelabel_likelihood': np.float32(0.8617775),
#      'macro_F1': 0.9159768417276346,
#      'expected_calibration_error_1': np.float32(0.025280528)},
#     'CC': {'accuracy': 0.923828125,
#      'averaged_truelabel_likelihood': 0.8205027041566487,
#      'macro_F1': 0.9238255097564232,
#      'expected_calibration_error_1': 0.0943942177719785}}}},
#  'SST5': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.240234375,
#      'averaged_truelabel_likelihood': np.float32(0.23642164),
#      'macro_F1': 0.15314272118015623,
#      'expected_calibration_error_1': np.float32(0.4924528)},
#     'CC': {'accuracy': 0.53515625,
#      'averaged_truelabel_likelihood': 0.5212699563235047,
#      'macro_F1': 0.34830735977632304,
#      'expected_calibration_error_1': 0.43427468584753115}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.240234375,
#      'averaged_truelabel_likelihood': np.float32(0.23839188),
#      'macro_F1': 0.15231491836278238,
#      'expected_calibration_error_1': np.float32(0.5254996)},
#     'CC': {'accuracy': 0.478515625,
#      'averaged_truelabel_likelihood': 0.4839017783760512,
#      'macro_F1': 0.32015034217026955,
#      'expected_calibration_error_1': 0.48823647549063326}}}},
#  'Subjective': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.5,
#      'averaged_truelabel_likelihood': np.float32(0.509827),
#      'macro_F1': 0.3816425120772947,
#      'expected_calibration_error_1': np.float32(0.16319776)},
#     'CC': {'accuracy': 0.478515625,
#      'averaged_truelabel_likelihood': 0.4840961620922319,
#      'macro_F1': 0.3236459709379128,
#      'expected_calibration_error_1': 0.3916861982415114}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.478515625,
#      'averaged_truelabel_likelihood': np.float32(0.5049592),
#      'macro_F1': 0.3236459709379128,
#      'expected_calibration_error_1': np.float32(0.2866721)},
#     'CC': {'accuracy': 0.478515625,
#      'averaged_truelabel_likelihood': 0.48453786565838114,
#      'macro_F1': 0.3236459709379128,
#      'expected_calibration_error_1': 0.3813696485669892}}}},
#  'TREC': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.68359375,
#      'averaged_truelabel_likelihood': np.float32(0.583407),
#      'macro_F1': 0.6300217225028663,
#      'expected_calibration_error_1': np.float32(0.067839384)},
#     'CC': {'accuracy': 0.4609375,
#      'averaged_truelabel_likelihood': 0.43227716914406994,
#      'macro_F1': 0.3565700572357575,
#      'expected_calibration_error_1': 0.4464317619724573}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.4140625,
#      'averaged_truelabel_likelihood': np.float32(0.39587018),
#      'macro_F1': 0.3065799309747373,
#      'expected_calibration_error_1': np.float32(0.4111458)},
#     'CC': {'accuracy': 0.33984375,
#      'averaged_truelabel_likelihood': 0.33242345838794674,
#      'macro_F1': 0.2210726734267224,
#      'expected_calibration_error_1': 0.17389505804810437}}}},
#  'tweet_eval_emotion': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.775390625,
#      'averaged_truelabel_likelihood': np.float32(0.6039853),
#      'macro_F1': 0.7229759784186737,
#      'expected_calibration_error_1': np.float32(0.105943374)},
#     'CC': {'accuracy': 0.583984375,
#      'averaged_truelabel_likelihood': 0.563459375453026,
#      'macro_F1': 0.35812921255959235,
#      'expected_calibration_error_1': 0.3234200416932904}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.71484375,
#      'averaged_truelabel_likelihood': np.float32(0.58044505),
#      'macro_F1': 0.6283976664104701,
#      'expected_calibration_error_1': np.float32(0.059433956)},
#     'CC': {'accuracy': 0.564453125,
#      'averaged_truelabel_likelihood': 0.5342125952941844,
#      'macro_F1': 0.3405755185509787,
#      'expected_calibration_error_1': 0.29640221838374936}}}},
#  'tweet_eval_hate': {'seed_2206632489': {'4': {'Baseline': {'accuracy': 0.443359375,
#      'averaged_truelabel_likelihood': np.float32(0.4807386),
#      'macro_F1': 0.3241910160754728,
#      'expected_calibration_error_1': np.float32(0.3033394)},
#     'CC': {'accuracy': 0.43359375,
#      'averaged_truelabel_likelihood': 0.4616541536113297,
#      'macro_F1': 0.3024523160762943,
#      'expected_calibration_error_1': 0.3551329847795741}}},
#   'seed_2481609806': {'4': {'Baseline': {'accuracy': 0.435546875,
#      'averaged_truelabel_likelihood': np.float32(0.463642),
#      'macro_F1': 0.30630136472529684,
#      'expected_calibration_error_1': np.float32(0.3673166)},
#     'CC': {'accuracy': 0.43359375,
#      'averaged_truelabel_likelihood': 0.4654318753181257,
#      'macro_F1': 0.3024523160762943,
#      'expected_calibration_error_1': 0.3266882567760322}}}}}
