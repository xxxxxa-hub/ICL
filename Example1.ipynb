# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/LLM_calib3
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/LLM_calib3

# %%
from ICL_modules import data_loader, dataset_interface, s_random, experiment_basics, functions
from ICL_inference import inference
from ICL_calibrations import calibration_methods,new_calib
from run import run_multiple_calibration_experiments_generic
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    LogitsProcessorList,
    LogitsProcessor
)
import random
import torch
import numpy as np
import pandas as pd
import itertools
import functools
import copy
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Intro to Package

# %%
# Load the SST-2 sentiment analysis dataset from the GLUE benchmark.
# 'from_cache=True' ensures faster loading by using a locally cached version if available.
sst_2 = data_loader.glue_sst2(from_cache=True)

# %%
# Retrieve the list of possible labels in the dataset.
# For SST-2, the labels represent sentiment: 'negative' or 'positive'.
sst_2.get_label_space()
# Out:
# ['negative', 'positive']

# %%
# Get the corresponding numerical index of each label.
# This is useful for training models where labels need to be in integer form.
sst_2.find_index_from_label('negative'),sst_2.find_index_from_label('positive')
# Out:
# (0, 1)

# %%
# Convert label indices back to their corresponding text labels.
# This is useful when interpreting model predictions or displaying results.
sst_2.label_index_to_text(0),sst_2.label_index_to_text(1)

# %%
# Retrieve the dataset in the form of a list of tuples: [([text], label_index)]
# Each item is a single data sample:
#   - [text]: a list containing the sentence
#   - label_index: 0 for 'negative', 1 for 'positive'
sst_2.get_dataset()
# Out:
# [(["can take credit for most of the movie 's success "], 1),
#  (['of the biggest names in japanese anime , with impressive results '], 1),
#  (['of interest '], 1),
#  (['mawkish self-parody '], 0),
#  (['she of the impossibly long limbs and sweetly conspiratorial smile '], 1),
#  (['one of those decades-spanning historical epics that strives to be intimate and socially encompassing but fails to do justice to either effort in three hours of screen time '],
#   0),
#  (["'s something to be said for a studio-produced film that never bothers to hand viewers a suitcase full of easy answers "],
#   1),
#  (['not remotely incisive enough '], 0),
#  (["of a film that 's rarely as entertaining as it could have been "], 0),
#  (['a marvelous performance by allison lohman as an identity-seeking foster child '],
#   1),
#  (['splashy and '], 1),
#  (['this painfully unfunny farce '], 0),
#  (['gives the lie to many clichés and '], 0),
#  (['turns a blind eye to the very history it pretends to teach . '], 0),
#  (['like a mix of cheech and chong '], 1),
#  (['major pleasures '], 1),
#  (['spiffy bluescreen technique '], 1),
#  (['a cheap thriller , a dumb comedy or '], 0),
#  (['increasingly diverse '], 0),
#  (['at once laughable '], 0),
#  (['the national lampoon film franchise , '], 1),
#  (["ai n't art , "], 0),
#  (['dull-witted and '], 0),
#  (['completely awful iranian drama '], 0),
#  (["which will please eastwood 's loyal fans -- and suits the story , wherein our hero must ride roughshod over incompetent cops to get his man "],
#   1),
#  (['is a remake by the numbers , linking a halfwit plot to a series of standup routines in which wilson and murphy show how funny they could have been in a more ambitious movie . '],
#   0),
#  (['the uninspired scripts , acting and direction '], 0),
#  (['anyone can relate '], 1),
#  (['saving '], 1),
#  (['could have -- should have -- been allowed '], 0),
#  (['in a tasteful , intelligent manner '], 1),
#  (['hardest '], 1),
#  (['admire this film for its harsh objectivity and refusal to seek our tears , our sympathies '],
#   1),
#  (['who sometimes feel more like literary conceits than flesh-and-blood humans '],
#   0),
#  (['what should have been a painless time-killer becomes instead a grating endurance test . '],
#   0),
#  (['in asia , where ms. shu is an institution '], 1),
#  (['a wet burlap sack '], 0),
#  (['out to be '], 1),
#  ([', impostor is as close as you can get to an imitation movie . '], 0),
#  (['laced with liberal doses of dark humor , gorgeous exterior photography , and a stable-full of solid performances , no such thing is a fascinating little tale . '],
#   1),
#  (['is doomed by its smallness '], 0),
#  (['also intriguing and honorable , '], 1),
#  (["that has something a little more special behind it : music that did n't sell many records but helped change a nation "],
#   1),
#  ([', showtime eventually folds under its own thinness . '], 0),
#  (['likely to have decades of life as a classic movie franchise '], 1),
#  (['what great cinema can really do '], 1),
#  (['of the best rock '], 1),
#  (['is , truly and thankfully , a one-of-a-kind work . '], 1),
#  (['wildly popular vin diesel '], 1),
#  (['to be a parody of gross-out flicks , college flicks , or even flicks in general '],
#   0),
#  (["for decades we 've marveled at disney 's rendering of water , snow , flames and shadows in a hand-drawn animated world . "],
#   1),
#  (['gem '], 1),
#  (['nicks refuses to let slackers be seen as just another teen movie , which means he can be forgiven for frequently pandering to fans of the gross-out comedy . '],
#   1),
#  (['draws you in '], 1),
#  (['old-world charm '], 1),
#  (['by no means a great movie , but it is a refreshingly forthright one . '],
#   1),
#  (['for purposes of bland hollywood romance '], 0),
#  (['lawrence unleashes his trademark misogyny -- er , comedy -- like a human volcano or an overflowing septic tank , '],
#   1),
#  (['always brooding '], 0),
#  (['choosing his roles with the precision of the insurance actuary '], 1),
#  (["captures the way young japanese live now , chafing against their culture 's manic mix of millennial brusqueness and undying , traditional politesse "],
#   1),
#  (['a masterfully '], 1),
#  (['attempts to fuse at least three dull plots into one good one . '], 0),
#  (['to recite bland police procedural details , fiennes wanders around in an attempt '],
#   0),
#  (['of heartfelt performances '], 1),
#  (['seems intimidated by both her subject matter and the period trappings of this debut venture into the heritage business . '],
#   1),
#  (["a rip-roaring comedy action fest that 'll put hairs on your chest . "], 1),
#  (['inane and '], 0),
#  (['a properly spooky film about the power of spirits to influence us whether we believe in them or not '],
#   1),
#  (['bigelow demonstrates a breadth of vision and an attention to detail that propels her into the upper echelons of the directing world . '],
#   1),
#  (['a loud , witless mess that '], 0),
#  (['otherwise dull '], 0),
#  (["imagine o. henry 's the gift of the magi relocated to the scuzzy underbelly of nyc 's drug scene . "],
#   0),
#  (['that gave people seizures '], 0),
#  (['is so different from the apple and so striking that it can only encourage us to see samira makhmalbaf as a very distinctive sensibility , working to develop her own film language with conspicuous success . '],
#   1),
#  (['a rock-solid little genre picture '], 1),
#  (['humor , verve and fun '], 1),
#  (['about either the nature of women or '], 1),
#  (['tiresomely simpleminded '], 0),
#  (['too erotic nor very thrilling '], 0),
#  (['toilet humor , '], 0),
#  (['offend everyone '], 0),
#  (['ideological '], 1),
#  (["lacks the visual panache , the comic touch , and perhaps the budget of sommers 's title-bout features . "],
#   0),
#  (['breathes more on the big screen '], 1),
#  (["the word that comes to mind , while watching eric rohmer 's tribute to a courageous scottish lady , is painterly . "],
#   1),
#  (['even more remarkable '], 1),
#  (['accepting him '], 1),
#  (['a beautifully '], 1),
#  (["'s little to recommend snow dogs , unless one considers cliched dialogue and perverse escapism a source of high hilarity . "],
#   0),
#  (['despite its sincere acting , signs is just another unoriginal run of the mill sci-fi film with a flimsy ending and lots of hype . '],
#   0),
#  (['becomes more and more frustrating '], 0),
#  (['touching , sophisticated film '], 1),
#  (["dave barry 's popular book of the same name "], 1),
#  (['humor , warmth '], 1),
#  (["an hour-and-a-half-long commercial for britney 's latest album "], 0),
#  (['a re-hash '], 0),
#  (["besides its terrific performances , is fontaine 's willingness to wander into the dark areas of parent-child relationships without flinching . "],
#   1),
#  (['brave and '], 1),
#  (['visually masterful work '], 1),
#  (['thinly sketched story '], 0),
#  (['no such thing is sort of a minimalist beauty and the beast , but in this case the beast should definitely get top billing . '],
#   1),
#  (['endearing and easy '], 1),
#  (['it has no affect on the kurds , but it wore me down '], 0),
#  (['one of the rare directors who feels acting is the heart and soul of cinema '],
#   1),
#  (['great material for a film -- rowdy , brawny and lyrical in the best irish sense '],
#   1),
#  (['some success with documentaries '], 1),
#  (['their quirky inner selves '], 1),
#  (['nazi politics and aesthetics '], 0),
#  (['jovial '], 1),
#  (['one of the funniest motion pictures of the year '], 1),
#  (['shot like a postcard and '], 0),
#  (['stuttering editing and pompous references to wittgenstein and kirkegaard '],
#   0),
#  (['faithful without being forceful , sad without being shrill , '], 1),
#  (['cutesy reliance '], 0),
#  (['itself is small and shriveled '], 0),
#  (['tired of the whole slo-mo , double-pistoled , ballistic-pyrotechnic hong kong action aesthetic '],
#   0),
#  (['captivates '], 1),
#  (['would require many sessions on the couch of dr. freud . '], 0),
#  (['uncle ralph '], 1),
#  (["what can be gleaned from this three-hour endurance test built around an hour 's worth of actual material "],
#   0),
#  (['complaints i might have '], 0),
#  (['into an ocean of trouble '], 0),
#  (['happy ending '], 1),
#  (['of those crass , contrived sequels that not only fails on its own , but makes you second-guess your affection for the original '],
#   0),
#  (["a sensitive , cultivated treatment of greene 's work as well as a remarkably faithful one . "],
#   1),
#  (['that embraces its old-fashioned themes and '], 1),
#  (['a nation whose songs spring directly from the lives of the people '], 1),
#  (['things going at a rapid pace , occasionally using an omniscient voice-over narrator in the manner of french new wave films '],
#   1),
#  (['quirky rip-off prison '], 0),
#  (["uzumaki 's interesting social parallel and defiant aesthetic seems a prostituted muse ... "],
#   0),
#  (['adds substantial depth to this shocking testament to anti-semitism and neo-fascism '],
#   1),
#  (['brings a youthful , out-to-change-the-world aggressiveness to the project , '],
#   1),
#  (['sparking '], 1),
#  (['would be an abridged edition '], 0),
#  (["is to sit through about 90 minutes of a so-called ` comedy ' and not laugh once "],
#   0),
#  (["a single man 's struggle to regain his life , his dignity and his music "],
#   1),
#  (['( no more racist portraits of indians , for instance ) '], 1),
#  (["form to examine the labyrinthine ways in which people 's lives cross and change "],
#   1),
#  (['masterfully '], 1),
#  (['surprises '], 1),
#  (["valiant effort to understand everyone 's point of view "], 1),
#  (['thoroughly enjoyed themselves '], 1),
#  (['a rare and lightly entertaining look behind the curtain that separates comics from the people laughing in the crowd . '],
#   1),
#  (['add up to a moving tragedy with some buoyant human moments . '], 1),
#  (["pay the full ticket price to see `` simone , '' and consider a dvd rental instead "],
#   0),
#  (['mesmerizing performance '], 1),
#  (['a good guy '], 1),
#  (['to distance it from the pack of paint-by-number romantic comedies '], 1),
#  (['enormously endearing '], 1),
#  (['sand to the fierce grandeur of its sweeping battle scenes '], 1),
#  (["an aimlessness that 's actually sort of amazing "], 1),
#  (["walter hill 's undisputed is like a 1940s warner bros. . "], 1),
#  (['viscerally exciting '], 1),
#  (['steers clear of the sensational and '], 1),
#  (["that 's peppered with false starts and populated by characters who are nearly impossible to care about "],
#   0),
#  (['a stand in favor of tradition and warmth '], 1),
#  (['fathom '], 0),
#  (['already mentioned '], 0),
#  (['hard ground '], 0),
#  (["'s so downbeat and nearly humorless "], 0),
#  (['a dramatic comedy as pleasantly dishonest and pat as any hollywood fluff . '],
#   0),
#  (['wastes its time '], 0),
#  (['most politically audacious films '], 1),
#  (['the movie bogs down in rhetoric and cliché . '], 0),
#  (['blessed with two fine , nuanced lead performances . '], 1),
#  (["this amiable picture talks tough , but it 's all bluster -- in the end it 's as sweet as greenfingers "],
#   1),
#  (['trouble '], 0),
#  (['ultimately vapid '], 0),
#  (['you see it in these harrowing surf shots '], 1),
#  (['be utterly entranced by its subject and '], 1),
#  ([', here comes the first lousy guy ritchie imitation . '], 0),
#  (['a triumph of emotionally and narratively complex filmmaking . '], 1),
#  (['bitterly '], 0),
#  (['the desperation of a very insecure man '], 0),
#  (['behold in its sparkling beauty '], 1),
#  (["this is no `` waterboy ! '' "], 0),
#  (['clean-cut '], 1),
#  (["it 's a smart , funny look at an arcane area of popular culture "], 1),
#  (['shiner '], 1),
#  (['demons '], 0),
#  (['deranged immediacy '], 1),
#  ([', but i suspect it might deliver again and again . '], 1),
#  (['a sobering meditation '], 1),
#  (['a hard time '], 0),
#  (["one of the year 's most weirdly engaging and unpredictable character pieces . "],
#   1),
#  (['still committed to growth in his ninth decade '], 1),
#  (['the acting is fine but the script is about as interesting as a recording of conversations at the wal-mart checkout line '],
#   0),
#  (["it 's never laugh-out-loud funny , but it is frequently amusing . "], 1),
#  (['drag an audience '], 0),
#  (['come away from his film overwhelmed , hopeful and , perhaps paradoxically , illuminated . '],
#   1),
#  (['the ideal casting of the masterful british actor ian holm '], 1),
#  (['control-alt-delete '], 0),
#  (['of young , black manhood that is funny , touching , smart and complicated '],
#   1),
#  (['flawless amounts '], 1),
#  (['awe and affection -- '], 1),
#  (['is one of the most repellent things to pop up in a cinematic year already littered with celluloid garbage . '],
#   0),
#  (['lagging near the finish line '], 0),
#  (['beyond all expectation '], 1),
#  (['may have expected to record with their mini dv '], 1),
#  (['some outrageously creative action in the transporter ... '], 1),
#  (['consumed by lust and love '], 1),
#  (["would n't make trouble every day any better "], 0),
#  (['a powerful and deeply moving example of melodramatic moviemaking '], 1),
#  (['up being both revelatory and narcissistic , achieving some honest insight into relationships that most high-concept films candy-coat with pat storylines , precious circumstances and beautiful stars '],
#   1),
#  (['in the process comes out looking like something wholly original '], 1),
#  (['accomplished and richly resonant work . '], 1),
#  (['hard to be mythic '], 0),
#  (['the obnoxious special effects , the obligatory outbursts of flatulence and the incessant , so-five-minutes-ago pop music on the soundtrack overwhelm what is left of the scruffy , dopey old hanna-barbera charm . '],
#   0),
#  (['though a morbid one '], 0),
#  (['seems to have dumped a whole lot of plot in favor of ... outrageous gags . '],
#   0),
#  (["ca n't accuse kung pow for misfiring , since it is exactly what it wants to be : an atrociously , mind-numbingly , indescribably bad movie "],
#   0),
#  (['a badly edited , 91-minute trailer '], 0),
#  (['lets things peter out midway '], 0),
#  (['in creating the layered richness of the imagery in this chiaroscuro of madness and light '],
#   1),
#  (['cinderella '], 1),
#  (['transcend its genre with a curiously stylized , quasi-shakespearean portrait of pure misogynist evil '],
#   1),
#  (['too painfully '], 0),
#  (['awesome work '], 1),
#  (["at least it 's a funny no-brainer "], 1),
#  (['than money why this distinguished actor would stoop so low '], 0),
#  (['its subject matter in a tasteful , intelligent manner '], 1),
#  (['brittle desperation '], 0),
#  (['a fragile framework '], 0),
#  (['comes across as a relic from a bygone era , and its convolutions ... feel silly rather than plausible '],
#   0),
#  (['to think about the ways we consume pop culture '], 1),
#  (['with indoctrinated prejudice '], 0),
#  (['plenty of laughs '], 1),
#  (["'re merely signposts marking the slow , lingering death of imagination . "],
#   0),
#  ([', he does all of this , and more , while remaining one of the most savagely hilarious social critics this side of jonathan swift . '],
#   1),
#  (['that you get when sitting around a campfire around midnight , telling creepy stories to give each other the willies '],
#   1),
#  (["one of the year 's best films "], 1),
#  (['its elbows sticking out where the knees should be '], 0),
#  (['to blue hilarity '], 1),
#  (['surprisingly charming and even witty match '], 1),
#  (['-- however canned -- '], 0),
#  (["'s the sweet cinderella story that `` pretty woman '' wanted to be . "],
#   1),
#  (['a seriocomic debut of extravagant promise by georgian-israeli director dover kosashvili . '],
#   1),
#  (["sandler does n't understand that the idea of exploiting molestation for laughs is funny , not actually exploiting it yourself . "],
#   0),
#  (['with morph , a cute alien creature who mimics everyone and everything around '],
#   1),
#  (['appreciates the art '], 1),
#  (["'s quite an achievement to set and shoot a movie at the cannes film festival and "],
#   1),
#  (['makes the banger sisters a fascinating character study with laughs to spare '],
#   1),
#  (['too long and bogs down in a surfeit of characters and unnecessary subplots '],
#   0),
#  (['loosely connected characters '], 0),
#  (['the most appealing movies ever made about an otherwise appalling , and downright creepy , subject -- a teenage boy in love with his stepmother '],
#   1),
#  (['luridly graphic and laughably unconvincing '], 0),
#  (['wonder of wonders -- '], 1),
#  (['far-fetched '], 0),
#  (["does a good job of establishing a time and place , and of telling a fascinating character 's story "],
#   1),
#  (['sign '], 1),
#  (['bolado credit for good intentions '], 1),
#  (["it 's hard to stop watching "], 1),
#  (['are in perfect balance '], 1),
#  (['supremely unfunny and unentertaining '], 0),
#  (["filmmakers david weissman and bill weber benefit enormously from the cockettes ' camera craziness -- not only did they film performances , "],
#   1),
#  (['carries you along '], 1),
#  (["to better understand why this did n't connect with me would require another viewing , and i wo n't be sitting through this one again ... that in itself is commentary enough "],
#   0),
#  (['marshall keeps the energy humming , '], 1),
#  (['re-voiced version '], 0),
#  (['can enjoy much of jonah simply , and gratefully , as laugh-out-loud lunacy with a pronounced monty pythonesque flavor '],
#   1),
#  (['dumb humor '], 0),
#  (['( n ) o matter how much good will the actors generate , showtime eventually folds under its own thinness . '],
#   0),
#  (['your seat a couple of times '], 1),
#  (['aimless for much of its running time , '], 0),
#  (['may puzzle his most ardent fans . '], 0),
#  (["shakespeare 's macbeth "], 1),
#  (['cold , gray , antiseptic and emotionally desiccated '], 0),
#  (["it made me feel unclean , and i 'm the guy who liked there 's something about mary and both american pie movies "],
#   0),
#  (['in its own direction '], 1),
#  (['the new thriller proves that director m. night shyamalan can weave an eerie spell and that mel gibson can gasp , shudder and even tremble without losing his machismo . '],
#   1),
#  (['vaporize from your memory minutes '], 0),
#  (['without much interest in the elizabethans '], 0),
#  (['every indulgent , indie trick in the book '], 0),
#  (['to entertain or inspire its viewers '], 1),
#  (['that takes too long to shake '], 0),
#  (['describes this film : honest '], 1),
#  (['compassionately '], 1),
#  (['uncompelling '], 0),
#  (['really get inside of them . '], 1),
#  (['smart little indie . '], 1),
#  (['a gently funny , sweetly adventurous film that makes you feel genuinely good , that is to say , entirely unconned by false sentiment or sharp , overmanipulative hollywood practices . '],
#   1),
#  (['while peppering the pages with memorable zingers '], 1),
#  (['with a core of decency '], 1),
#  (['help sustain it '], 1),
#  (["a few hours after you 've seen it , you forget you 've been to the movies . "],
#   0),
#  (['matches the page-turning frenzy '], 1),
#  (['everything that was right about blade is wrong in its sequel . '], 0),
#  (['the film lacks momentum and its position remains mostly undeterminable '],
#   0),
#  (["all about a young woman 's face , and by casting an actress whose face projects that woman 's doubts and yearnings "],
#   1),
#  (['are surprising in how much they engage and even touch us . '], 1),
#  (["i wo n't be sitting through this one again "], 0),
#  (['the unusual power '], 1),
#  (['emotionally manipulative and sadly imitative of innumerable '], 0),
#  (['warmth to go around , with music and laughter and the love of family '],
#   1),
#  (['is interesting to witness the conflict from the palestinian side '], 1),
#  (['keep this '], 1),
#  (["a miraculous movie , i 'm going home is so slight , "], 1),
#  (['naive '], 0),
#  (['has reached puberty actually finding the characters in slackers or their antics amusing , let alone funny '],
#   0),
#  (['most audacious , outrageous , '], 1),
#  (['for leonard '], 1),
#  (['start reading your scripts before signing that dotted line . '], 0),
#  (['the gallic ` tradition of quality '], 1),
#  (['predictable as the tides '], 0),
#  (['leaden '], 0),
#  (['transcend its genre '], 1),
#  (['deep inside righteousness can be found a tough beauty '], 1),
#  (['logic and misuse '], 0),
#  (['probe questions of attraction and interdependence '], 1),
#  (['payne has created a beautiful canvas '], 1),
#  (['provides a satisfyingly unsettling ride into the dark places of our national psyche . '],
#   1),
#  (['horrible '], 0),
#  (['enjoyed . '], 1),
#  (['consistently clever and suspenseful . '], 1),
#  (['whom the '], 1),
#  (['has flopped as surely as a soufflé gone wrong '], 0),
#  (['make it look as though they are having so much fun '], 1),
#  (['you reach the finale '], 1),
#  (['waldo salt screenwriting award '], 1),
#  (['that segment of the populace that made a walk to remember a niche hit '],
#   1),
#  (["it 's surprisingly decent , particularly for a tenth installment in a series . "],
#   1),
#  (["'s rare to find a film to which the adjective ` gentle ' applies "], 1),
#  (['the true impact of the day '], 1),
#  (['more dutiful than enchanting ... terribly episodic and lacking the spark of imagination that might have made it an exhilarating treat . '],
#   0),
#  (['with guardian hack nick davies '], 0),
#  (['a worthwhile documentary , '], 1),
#  (['to churn out one mediocre movie after another '], 0),
#  (["a compelling allegory about the last days of germany 's democratic weimar republic . "],
#   1),
#  (['love a disney pic with as little cleavage as this one has , and '], 1),
#  (['excites '], 1),
#  (['sappy '], 0),
#  (['when a movie has stuck around for this long '], 1),
#  (['the computer and '], 1),
#  (['cheesy commercialism '], 0),
#  (['has managed to marry science fiction with film noir and action flicks with philosophical inquiry . '],
#   1),
#  (['rouses us . '], 1),
#  (["there 's not a comedic moment in this romantic comedy . "], 0),
#  (['the funniest film '], 1),
#  (["to pamela 's emotional roller coaster life "], 1),
#  ([', film has little insight into the historical period and its artists , particularly in how sand developed a notorious reputation . '],
#   0),
#  (['under the skin of her characters '], 1),
#  (["so uncool the only thing missing is the `` gadzooks ! '' "], 0),
#  (['interview with the assassin is structured less as a documentary and more as a found relic , and '],
#   1),
#  (['crawl up your own *** '], 0),
#  (['most excruciating '], 0),
#  (['its one-sidedness ... flirts with propaganda . '], 0),
#  (["'ll probably love it . "], 1),
#  ([', discerning taste '], 1),
#  (['exhausted by documentarians '], 0),
#  (['worthy successor '], 1),
#  (['from a sharper , cleaner script '], 1),
#  (['pretentious mess '], 0),
#  (['sit through -- despite some first-rate performances by its lead '], 0),
#  (["'s just hard to believe that a life like this can sound so dull . "], 0),
#  (['of california '], 1),
#  (['is a monumental achievement '], 1),
#  (['derailed by bad writing '], 0),
#  (['gradually sneaks up on the audience '], 1),
#  (["hatfield and hicks make the oddest of couples , and in this sense the movie becomes a study of the gambles of the publishing world , offering a case study that exists apart from all the movie 's political ramifications . "],
#   1),
#  (['appeal '], 1),
#  (["originality in ` life ' to distance it from the pack of paint-by-number romantic comedies "],
#   1),
#  (['gross-out college comedy '], 0),
#  (['creepy and believable '], 1),
#  (["'s a movie that accomplishes so much that one viewing ca n't possibly be enough . "],
#   1),
#  (['( russell ) makes good b movies ( the mask , the blob ) , and the scorpion king more than ably meets those standards . '],
#   1),
#  (['another wholly unnecessary addition to the growing , moldering pile of , well , extreme stunt '],
#   0),
#  (['with formalist experimentation in cinematic art '], 1),
#  (['into a gut-wrenching examination of the way cultural differences and emotional expectations collide '],
#   1),
#  (['an engaging storyline '], 1),
#  (['we find ourselves surprised at how much we care about the story '], 1),
#  (['exciting and well-paced . '], 1),
#  (['even better '], 1),
#  (["like kissing jessica stein , amy 's orgasm has a key strength in its willingness to explore its principal characters with honesty , insight and humor . "],
#   1),
#  (['arrived for an incongruous summer playoff , demonstrating yet again that the era of the intelligent , well-made b movie is long gone '],
#   0),
#  (['a true star '], 1),
#  ([', meandering , and sometimes dry '], 0),
#  (['upstaged by an avalanche of more appealing holiday-season product '], 1),
#  (['a story worth caring about '], 1),
#  (['each scene drags , underscoring the obvious , '], 0),
#  (['it will gratify anyone who has ever suspected hollywood of being overrun by corrupt and hedonistic weasels . '],
#   1),
#  (['knows everything and answers all questions , is visually smart , cleverly written , and nicely realized '],
#   1),
#  (['jealousy '], 0),
#  (['there is a certain sense of experimentation and improvisation to this film that may not always work , but it is nevertheless compelling . '],
#   1),
#  (['ugly , pointless , stupid '], 0),
#  (["death to smoochy is often very funny , but what 's even more remarkable is the integrity of devito 's misanthropic vision "],
#   1),
#  (['is brilliant , really '], 1),
#  (['something really good '], 1),
#  (['could have been crisper and punchier , but '], 0),
#  (['rich and '], 1),
#  (["a muddled limp biscuit of a movie , a vampire soap opera that does n't make much "],
#   0),
#  (['probably should '], 1),
#  (['adorably ditsy but heartfelt '], 1),
#  (['laborious whine , the bellyaching of a paranoid and unlikable man . '], 0),
#  (['nothing more than four or five mild chuckles '], 0),
#  (['the leads are natural and lovely , the pace is serene , the humor wry and sprightly . '],
#   1),
#  (['lacking '], 0),
#  (['is one of the biggest disappointments of the year . '], 0),
#  (["hampered by taylor 's cartoonish performance and the film 's ill-considered notion that hitler 's destiny was shaped by the most random of chances "],
#   0),
#  (['a complete waste '], 0),
#  (['it may not be a huge cut of above the rest , but i enjoyed barbershop . '],
#   1),
#  (['suited to capture these musicians in full regalia '], 1),
#  (['the goodwill the first half of his movie generates by orchestrating a finale that is impenetrable and dull '],
#   0),
#  (['of too much kid-vid '], 0),
#  (["wilde 's droll whimsy "], 1),
#  (['carl '], 1),
#  (["you wish he 'd gone the way of don simpson "], 0),
#  (["'d probably turn it off "], 0),
#  (["is one film that 's truly deserving of its oscar nomination . "], 1),
#  (["dog soldiers does n't transcend genre -- it embraces it , energizes it and takes big bloody chomps out of it "],
#   1),
#  (["do anything as stomach-turning as the way adam sandler 's new movie rapes "],
#   0),
#  (['victim to sloppy plotting , '], 0),
#  (["there 's a delightfully quirky movie to be made from curling , but "], 1),
#  (['makes my big fat greek wedding look like an apartheid drama '], 0),
#  (['so sketchy it amounts to little more than preliminary notes for a science-fiction horror film '],
#   0),
#  (['a bit of a downer and a little '], 0),
#  (['a strong and confident work which works so well for the first 89 minutes , but ends so horrendously confusing '],
#   0),
#  (['a hokey piece of nonsense that tries too hard to be emotional . '], 0),
#  (["working from a surprisingly sensitive script co-written by gianni romoli ... ozpetek avoids most of the pitfalls you 'd expect in such a potentially sudsy set-up . "],
#   1),
#  (['eats , meddles , argues , laughs , kibbitzes and fights '], 1),
#  (['odd enjoyably '], 1),
#  (['deeply meditative '], 1),
#  (['in a dead-end existence '], 0),
#  (["is n't always coherent "], 0),
#  (['actually looks as if it belongs on the big screen '], 1),
#  (['a flat script and a low budget '], 0),
#  (['warmth '], 1),
#  (['is an interesting movie ! '], 1),
#  ([', relaxed in its perfect quiet pace and proud in its message . '], 1),
#  (['thoughtful , reverent portrait '], 1),
#  (['to truly care for its decrepit freaks beyond the promise of a reprieve from their incessant whining '],
#   0),
#  (['is not always the prettiest pictures that tell the best story '], 1),
#  (['one well-timed explosion in a movie can be a knockout , '], 1),
#  (['a waste of de niro , mcdormand and the other good actors in the cast '],
#   0),
#  (['of those films that started with a great premise and then just fell apart '],
#   0),
#  (['who would not likely be so stupid as to get '], 0),
#  (['bad and baffling from the get-go '], 0),
#  ([', runteldat is something of a triumph . '], 1),
#  (['the prospect of their own mortality '], 1),
#  (['unrecoverable '], 0),
#  (['it seems impossible that an epic four-hour indian musical about a cricket game could be this good '],
#   1),
#  (['downbeat , period-perfect biopic hammers home a heavy-handed moralistic message '],
#   0),
#  (["cinema 's directorial giants "], 1),
#  (["its own action is n't very effective "], 0),
#  (['shame americans , '], 0),
#  (['a really special walk '], 1),
#  (['a welcome step '], 1),
#  (["to the titular character 's paintings and in the process created a masterful work of art of their own "],
#   1),
#  ([", you ca n't help suspecting that it was improvised on a day-to-day basis during production . "],
#   0),
#  (['like the excruciating end of days , collateral damage presents schwarzenegger as a tragic figure , but sympathy really belongs with any viewer forced to watch him try out so many complicated facial expressions . '],
#   0),
#  (['of effecting change and inspiring hope '], 1),
#  (['appealingly '], 1),
#  (['worthy entry '], 1),
#  (['try to balance pointed , often incisive satire and unabashed sweetness , with results that are sometimes bracing , sometimes baffling and quite often , and in unexpected ways , touching '],
#   1),
#  (['after being snared in its own tangled plot '], 0),
#  (['it affords to watch jackson , who also served as executive producer , take his smooth , shrewd , powerful act abroad '],
#   1),
#  (['gaining much momentum '], 1),
#  (['hint '], 1),
#  (['so bad in a major movie '], 0),
#  (['the mediocre end of the pool '], 0),
#  (['inimitable scenes '], 1),
#  (["not only are the film 's sopranos gags incredibly dated and unfunny "], 0),
#  (['a fascinating glimpse into an insular world that gives the lie to many clichés and showcases a group of dedicated artists '],
#   1),
#  (['happens when something goes bump in the night and nobody cares ? '], 0),
#  (["a mischievous visual style and oodles of charm make ` cherish ' a very good ( but not great ) movie . "],
#   1),
#  (["swinging from the trees hooting it 's praises "], 1),
#  (['populates his movie with a wonderful ensemble cast of characters that bring the routine day to day struggles of the working class to life '],
#   1),
#  (['evokes the 19th century with a subtlety that is an object lesson in period filmmaking '],
#   1),
#  (['a vibrant , colorful , semimusical rendition '], 1),
#  ([', the movie sinks into an abyss of clichés , depression and bad alternative music . '],
#   0),
#  (['it pays earnest homage to turntablists and beat jugglers , old schoolers and current innovators '],
#   1),
#  (['replaced by goth goofiness '], 0),
#  (['light treat '], 1),
#  (["does n't so much phone in his performance as "], 0),
#  (['that made me want to scream '], 0),
#  (['the reassuring manner of a beautifully sung holiday carol '], 1),
#  (['rote drivel '], 0),
#  (['big selling point '], 1),
#  (['quirky movie '], 1),
#  (['a fascinating , bombshell documentary that should shame americans , regardless of whether or not ultimate blame finally lies with kissinger . '],
#   1),
#  (['some fine acting , but ultimately a movie with no reason for being . '],
#   0),
#  (['clumsy '], 0),
#  (['well-directed '], 1),
#  (['report that it is instead a cheap cliché '], 0),
#  (['with the kind of social texture and realism that would be foreign in american teen comedies '],
#   1),
#  (['in an entirely irony-free zone and bale reduced mainly to batting his sensitive eyelids '],
#   0),
#  (['high drama '], 1),
#  (['gripping performances by lane and gere '], 1),
#  (["if that does n't clue you in that something 's horribly wrong "], 0),
#  (['a lighthearted glow '], 1),
#  (['that serve no other purpose than to call attention to themselves '], 0),
#  (["give `` scratch '' a second look "], 1),
#  (['nothing overly original , mind you , but solidly entertaining . '], 1),
#  (['looking for a smart , nuanced look at de sade and what might have happened at picpus '],
#   1),
#  (['of a stylish psychological thriller '], 1),
#  (['through this summer that do not involve a dentist drill '], 0),
#  (['the film shatters you in waves . '], 1),
#  (["is murder by numbers , and as easy to be bored by as your abc 's , "], 0),
#  (['a subtlety that makes the silly , over-the-top coda especially disappointing '],
#   0),
#  (['compelling story '], 1),
#  (['is a masterpiece of elegant wit and artifice . '], 1),
#  (['vulgar '], 0),
#  (['offers piercing domestic drama with spikes of sly humor . '], 1),
#  (['and crude humor '], 0),
#  (['is doing something of a public service -- shedding light on a group of extremely talented musicians who might otherwise go unnoticed and underappreciated by music fans . '],
#   1),
#  (['a masterpiece '], 1),
#  (['though unfortunately all the story gives us is flashing red lights , a rattling noise , and a bump on the head '],
#   0),
#  (['another arnold vehicle that fails to make adequate use of his particular talents . '],
#   0),
#  (['marshall puts a suspenseful spin on standard horror flick formula . '], 1),
#  (["( t ) his slop does n't even have potential as a cult film , as it 's too loud to shout insults at the screen . "],
#   0),
#  (['below is well below expectations . '], 0),
#  (['it goes awry in the final 30 minutes '], 0),
#  (['serving sara should be served an eviction notice at every theater stuck with it . '],
#   0),
#  (["is a no-surprise series of explosions and violence while banderas looks like he 's not trying to laugh at how bad "],
#   0),
#  (['most of the problems with the film '], 0),
#  (['of nonsense '], 0),
#  (['find room for one more member of his little band , a professional screenwriter '],
#   0),
#  (['completely awful iranian drama ... as much fun as a grouchy ayatollah in a cold mosque '],
#   0),
#  (["the filmmaker 's characteristic style "], 1),
#  (["` true story ' "], 1),
#  (['the children of varying ages in my audience never coughed , fidgeted or romped up and down the aisles for bathroom breaks '],
#   1),
#  (["-- but it 's a rushed , slapdash , sequel-for-the-sake - of-a-sequel with less than half the plot and ingenuity "],
#   0),
#  (['whose portrait of a therapy-dependent flakeball '], 0),
#  (['while this one gets off with a good natured warning , future lizard endeavors will need to adhere more closely to the laws of laughter '],
#   0),
#  (["hardly an objective documentary , but it 's great cinematic polemic "], 1),
#  (['any art-house moviegoer is likely to find compelling '], 1),
#  (['manages not only to find a compelling dramatic means of addressing a complex situation '],
#   1),
#  (['were as claustrophic , suffocating and chilly as the attics to which they were inevitably consigned '],
#   0),
#  (["if you shoot something on crummy-looking videotape , it must be labeled ` hip ' , ` innovative ' and ` realistic ' "],
#   0),
#  (['trying to create something original '], 1),
#  (['has come to new york city to replace past tragedy with the american dream '],
#   1),
#  (["reminds at every turn of elizabeth berkley 's flopping dolphin-gasm "], 0),
#  (['from the guy-in-a-dress genre '], 0),
#  (["'s just too bad the screenwriters eventually shoot themselves in the feet with cop flick cliches like an oily arms dealer , squad car pile-ups and the requisite screaming captain "],
#   0),
#  (["` laugh therapy ' "], 1),
#  (['the expectation of laughter has been quashed by whatever obscenity is at hand '],
#   0),
#  (['a prolific director of music videos '], 1),
#  (['come close to the level of intelligence and visual splendor that can be seen in other films '],
#   0),
#  (['they are in this tepid genre offering '], 0),
#  (['peter out midway '], 0),
#  (['intentionally low '], 0),
#  (['awfully deadly '], 0),
#  (['off-beat and fanciful film '], 1),
#  (['is made fresh by an intelligent screenplay and gripping performances in this low-budget , video-shot , debut indie effort . '],
#   1),
#  (['first-time director denzel washington and a top-notch cast '], 1),
#  (['because he gives the story some soul '], 1),
#  (['with very little to add beyond the dark visions already relayed by superb recent predecessors like swimming with sharks and the player , this latest skewering '],
#   0),
#  (["horrendously amateurish filmmaking that is plainly dull and visually ugly when it is n't incomprehensible . "],
#   0),
#  (['of two fine actors , morgan freeman and ashley judd '], 1),
#  (['a romance this smart '], 1),
#  (['weirdo actor crispin glover '], 0),
#  (['piss on trees , b.s. one another '], 0),
#  (['heartily sick '], 0),
#  (['heart '], 1),
#  (['is a phlegmatic bore , so tedious it makes the silly spy vs. spy film the sum of all fears , starring ben affleck , seem downright hitchcockian . '],
#   0),
#  (['cobbled together out of older movies '], 0),
#  (['musical number '], 1),
#  (['dreamy and '], 1),
#  (["there are some movies that hit you from the first scene and you know it 's going to be a trip "],
#   1),
#  (['more interesting -- and '], 1),
#  (["schaeffer 's film never settles into the light-footed enchantment the material needs , and "],
#   0),
#  (['when you doze off thirty minutes into the film '], 0),
#  (['touches the heart and the funnybone thanks to the energetic and always surprising performance by rachel griffiths '],
#   1),
#  (['enjoyed it just '], 1),
#  (["that and it 's what makes their project so interesting "], 1),
#  (['relies on toilet humor , ethnic slurs . '], 0),
#  (['so downbeat '], 0),
#  (["third time 's the charm "], 1),
#  (['is delightful in the central role '], 1),
#  (['in that oh-so-important category , the four feathers comes up short '], 0),
#  (["dong never pushes for insights beyond the superficial tensions of the dynamic he 's dissecting "],
#   0),
#  (['open-mouthed before the screen , not screaming but yawning '], 0),
#  (['which nurses plot holes gaping enough to pilot an entire olympic swim team through '],
#   0),
#  (["works its magic with such exuberance and passion that the film 's length becomes a part of its fun "],
#   1),
#  (['an excruciating demonstration of the unsalvageability '], 0),
#  (["this is the best ` old neighborhood ' project since christopher walken kinda romanced cyndi lauper in the opportunists "],
#   1),
#  (['be captivated , as i was , by its moods , and by its subtly transformed star , '],
#   1),
#  (['an acting bond '], 1),
#  (['some episodes that rival vintage looney tunes for the most creative mayhem in a brief amount of time '],
#   1),
#  (['bust '], 0),
#  (['of balto '], 1),
#  (["russell lacks the visual panache , the comic touch , and perhaps the budget of sommers 's title-bout features . "],
#   0),
#  (['despite some first-rate performances '], 1),
#  (['was daniel day-lewis . '], 1),
#  (['a seriously bad film with seriously '], 0),
#  (["us to remember that life 's ultimately a gamble and last orders are to be embraced "],
#   1),
#  (['not smart '], 0),
#  (['the ensemble has something fascinating to do '], 1),
#  (['spy kids a surprising winner with both adults and younger audiences '], 1),
#  (['is no solace here , no entertainment value , merely a fierce lesson in where filmmaking can take us '],
#   0),
#  (['the cultural moat surrounding its ludicrous and contrived plot '], 0),
#  (['name-calling '], 0),
#  (['an entertaining mix '], 1),
#  (['is the equivalent of french hip-hop , which also seems to play on a 10-year delay '],
#   0),
#  (['the good-time shenanigans in welcome perspective '], 1),
#  (['the perfect face to play a handsome blank yearning to find himself '], 1),
#  (['about identity and alienation '], 0),
#  (['excellent job '], 1),
#  (['charming in comedies like american pie and '], 1),
#  (['have an honesty and dignity that breaks your heart '], 1),
#  (['the great films '], 1),
#  (['for pretentious arts majors '], 0),
#  (['terribly monotonous '], 0),
#  (["is so bad , that it 's almost worth seeing because it 's so bad . "], 0),
#  (['romp of a film . '], 1),
#  (['dopey dialogue and sometimes inadequate performances kill the effect '],
#   0),
#  (["costner 's warm-milk persona is just as ill-fitting as shadyac 's perfunctory directing chops , and some of the more overtly silly dialogue would sink laurence olivier "],
#   0),
#  (['was painful '], 0),
#  (['very dark and very funny '], 1),
#  (['its courage , ideas '], 1),
#  (['pass up '], 0),
#  (["that 's packed with just as much intelligence as action "], 1),
#  (['though it goes further than both , anyone who has seen the hunger or cat people will find little new here , but a tasty performance from vincent gallo lifts this tale of cannibal lust above the ordinary . '],
#   1),
#  (['appropriately cynical social commentary '], 1),
#  (['ballsy and '], 1),
#  (['demanding than it needs to be '], 0),
#  (['summons more spirit and bite than your average formulaic romantic quadrangle '],
#   1),
#  (['it forces you to ponder anew what a movie can be '], 1),
#  (['no wit , only '], 0),
#  (['if the director had released the outtakes theatrically and used the film as a bonus feature on the dvd '],
#   0),
#  (['strangers , which opens today in the new york metropolitan area , so distasteful '],
#   0),
#  (['natter '], 0),
#  (['is never quite able '], 0),
#  (['clever and '], 1),
#  (["is n't . "], 0),
#  (['stale and clichéd to a fault . '], 0),
#  (['is standard crime drama fare ... instantly forgettable and thoroughly dull '],
#   0),
#  (['and a terrible story '], 0),
#  (['is silly but strangely believable . '], 1),
#  (['of perversity , comedy and romance '], 1),
#  (['tedious as the chatter of parrots raised on oprah '], 0),
#  (['seem fresh again '], 1),
#  (['a deft , delightful mix of sulky teen drama and overcoming-obstacles sports-movie triumph . '],
#   1),
#  (['makes their project so interesting '], 1),
#  (['worse yet '], 0),
#  (['equally distasteful '], 0),
#  (['chore to sit through -- despite some first-rate performances by its lead '],
#   0),
#  (["... despite lagging near the finish line , the movie runs a good race , one that will have you at the edge of your seat for long stretches . ' "],
#   1),
#  (['thoroughly awful '], 0),
#  (['allows each character to confront their problems openly and honestly '],
#   1),
#  (['is a shaky , uncertain film that nevertheless touches a few raw nerves . '],
#   0),
#  (['its pathos-filled but ultimately life-affirming finale '], 1),
#  (["it 's not nearly as fresh or enjoyable as its predecessor , but there are enough high points to keep this from being a complete waste of time . "],
#   1),
#  (['nice , light treat '], 1),
#  (['a film -- full of life and small delights -- '], 1),
#  (["it 's not nearly as fresh or enjoyable as its predecessor "], 0),
#  (['lazy material '], 0),
#  (['change watching such a character , '], 0),
#  (['impossibly long limbs and sweetly conspiratorial '], 1),
#  (['soulless jumble '], 0),
#  (['too bad to be good and '], 0),
#  (['is clearly extraordinarily talented '], 1),
#  (['signature style '], 1),
#  (['supposed to feel funny and light '], 0),
#  (['works on no level whatsoever for me . '], 0),
#  (["do n't really care for the candidate "], 0),
#  (['a stab at soccer hooliganism , '], 1),
#  (['a delightful lark for history buffs '], 1),
#  (['is about as humorous as watching your favorite pet get buried alive '], 0),
#  (['simple title '], 1),
#  (['the depths to which the girls-behaving-badly film has fallen '], 0),
#  (['a canny crowd pleaser , and the last kiss ... '], 1),
#  (['a lousy script , '], 0),
#  (['french director anne fontaine delivers an inspired portrait of male-ridden angst and the emotional blockage that accompanies this human condition '],
#   1),
#  (['interesting matters '], 1),
#  (['are often more predictable than their consequences '], 0),
#  (['weighs down the tale with bogus profundities '], 0),
#  (['blustery movie '], 0),
#  (['superficial humor '], 0),
#  (['slightly pokey '], 0),
#  (['with honesty , insight and humor '], 1),
#  (['nearly every cliché '], 0),
#  (['quite tasty and inviting all the same '], 1),
#  (['benefited from a sharper , cleaner script '], 1),
#  (["the filmmaker 's extraordinary access to massoud "], 1),
#  (['loses all '], 0),
#  (["for a film that 's being advertised as a comedy , sweet home alabama is n't as funny as you 'd hoped . "],
#   0),
#  (['with humor and poignancy '], 1),
#  (['the more serious-minded concerns of other year-end movies '], 1),
#  (['the most inventive '], 1),
#  (['the most ravaging , '], 1),
#  (['as a director , paxton is surprisingly brilliant , deftly sewing together what could have been a confusing and horrifying vision into an intense and engrossing head-trip . '],
#   1),
#  (['is just such an achievement . '], 1),
#  (["it 's anchored by splendid performances from an honored screen veteran and a sparkling newcomer who instantly transform themselves into a believable mother/daughter pair . "],
#   1),
#  (["anyone could desire to the cheap , graceless , hackneyed sci-fi serials of the '30s and '40s "],
#   0),
#  (['deep intelligence '], 1),
#  (['well-done supernatural thriller with keen insights into parapsychological phenomena and the soulful nuances of the grieving process . '],
#   1),
#  (['his inescapable past and uncertain future in a very shapable but largely unfulfilling present '],
#   0),
#  (["if s&m seems like a strange route to true love , maybe it is , but it 's to this film 's ( and its makers ' ) credit that we believe that that 's exactly what these two people need to find each other -- and themselves "],
#   1),
#  (['coupled with pitch-perfect acting '], 1),
#  (['as a good old-fashioned adventure for kids , spirit : stallion of the cimarron is a winner . '],
#   1),
#  (['sadly '], 0),
#  (['could easily mistake it for a sketchy work-in-progress that was inexplicably rushed to the megaplexes before its time . '],
#   0),
#  ([', is extraordinary . '], 1),
#  (['based on theory , sleight-of-hand , and ill-wrought hypothesis '], 1),
#  (['far less '], 0),
#  (['that you can not believe anyone more central to the creation of bugsy than the caterer '],
#   0),
#  (['a gratingly unfunny groaner '], 0),
#  (['the always hilarious meara and levy '], 1),
#  (["it 's a pretty good execution of a story that 's a lot richer than the ones hollywood action screenwriters usually come up with on their own . "],
#   1),
#  (['questionable '], 0),
#  (['unadulterated thrills '], 1),
#  (['thought-provoking picture . '], 1),
#  (['touches the heart and the funnybone thanks '], 1),
#  (['delight your senses '], 1),
#  (["almost as offensive as `` freddy got fingered . '' "], 0),
#  (['it is ok for a movie to be something of a sitcom apparatus , if the lines work , the humor has point and the actors are humanly engaged '],
#   1),
#  (['but it works under the direction of kevin reynolds . '], 1),
#  (['may go down in cinema history as the only movie ever in which the rest of the cast was outshined by ll cool j. '],
#   0),
#  (['the film works in spite of it '], 1),
#  (['exactly assured in its execution '], 1),
#  (["rubbo runs through a remarkable amount of material in the film 's short 90 minutes . "],
#   1),
#  (['this utterly ridiculous shaggy dog story as one of the most creative , energetic and original comedies to hit the screen in years '],
#   1),
#  (['any of these three actresses , nor their characters , deserve '], 0),
#  (['as obvious as telling a country skunk '], 0),
#  (['the brutality '], 0),
#  (['jumbled '], 0),
#  (['fails to portray its literarily talented and notorious subject as anything much more than a dirty old man '],
#   0),
#  (['a convolution '], 0),
#  (['subtle and richly internalized performance '], 1),
#  (['has the capability of effecting change and inspiring hope . '], 1),
#  (['coming-of-age theme '], 1),
#  (['of his sweetness and vulnerability '], 1),
#  (['its own direction '], 1),
#  (['is the kathie lee gifford of film directors '], 0),
#  (['( and better '], 1),
#  (['stooping '], 0),
#  (['that shows what great cinema can really do '], 1),
#  (['it would be great to see this turd squashed under a truck , preferably a semi . '],
#   0),
#  (['whenever it threatens to get bogged down in earnest dramaturgy '], 0),
#  (['a film of quiet power . '], 1),
#  (['a mediocre tribute to films like them '], 0),
# ...
#   0),
#  (['with a certain degree of wit and dignity '], 1),
#  (['of modern life '], 1),
#  (['but utterly delightful . '], 1),
#  (["it 's refreshing to see a romance this smart . "], 1),
#  (['since it is exactly what it wants to be : an atrociously , mind-numbingly , indescribably bad movie '],
#   0),
#  (['fresh , '], 1),
#  (['terrible events '], 0),
#  (['mumbo jumbo '], 0),
#  (['-- like a rather unbelievable love interest and a meandering ending -- '],
#   0),
#  (['an enjoyably '], 1),
#  (['heartbreak '], 0),
#  (['the richness of characterization '], 1),
#  (['give it considerable punch '], 1),
#  (["it 's far tamer than advertised "], 0),
#  (['the small , human moments '], 1),
#  (['may scream low budget '], 0),
#  (['switch to a mix of the shining , the thing , and any naked teenagers horror flick from the 1980s '],
#   0),
#  (['is bad '], 0),
#  (['deeply out of place '], 0),
#  ([', long-suffering but cruel '], 0),
#  (['an honesty and dignity that breaks your heart '], 1),
#  ([', personal film '], 1),
#  (['painted on their largest-ever historical canvas '], 1),
#  (['vincent became more and more abhorrent '], 0),
#  (['the problem with all of this '], 0),
#  (['appeals to the storytelling instincts of a slightly more literate filmgoing audience '],
#   1),
#  (['astounds . '], 1),
#  (["from terry gilliam 's subconscious , pressed through kafka 's meat grinder and into buñuel 's casings "],
#   1),
#  (['feral and uncomfortable '], 0),
#  (['is too busy getting in its own way to be anything but frustrating , boring , and forgettable '],
#   0),
#  (['watch , giggle '], 1),
#  (['stylistically , the movie is a disaster . '], 0),
#  (["'s worse , routine "], 0),
#  (["realistically nuanced a robert de niro performance can be when he is not more lucratively engaged in the shameless self-caricature of ` analyze this ' ( 1999 ) and ` analyze that , ' promised ( or threatened ) for later this year "],
#   0),
#  (["lilo & stitch '' is n't the most edgy piece of disney animation to hit the silver screen "],
#   0),
#  (['a weird , arresting little ride '], 0),
#  (['offers a ray of hope to the refugees able to look ahead and resist living in a past '],
#   1),
#  (['for a reasonably intelligent person to get through the country bears '],
#   0),
#  (['little morality tale '], 1),
#  (['winds up looking like a bunch of talented thesps slumming it '], 0),
#  ([', treasure planet is truly gorgeous to behold . '], 1),
#  (['as history '], 1),
#  (["is n't much to it "], 0),
#  (['may sound like it was co-written by mattel executives and lobbyists for the tinsel industry . '],
#   0),
#  (['vivid , spicy footnote '], 1),
#  (['just about more stately than any contemporary movie this year ... a true study , a film with a questioning heart '],
#   1),
#  (['grueling '], 0),
#  (['its own style '], 1),
#  (['this is that rare drama that offers a thoughtful and rewarding glimpse into the sort of heartache everyone has felt , or will feel someday . '],
#   1),
#  (["victor rosa is leguizamo 's best movie work so far , a subtle and richly internalized performance . "],
#   1),
#  (['is achingly honest and delightfully cheeky . '], 1),
#  (['dramatized pbs program '], 0),
#  (["it 's a mystery how the movie could be released in this condition . "], 0),
#  (['a lush , swooning melodrama in the intermezzo strain '], 1),
#  (["forget the misleading title , what 's with the unexplained baboon cameo ? "],
#   0),
#  (['admirable energy , full-bodied characterizations and '], 1),
#  (['ransacked every old world war ii movie for overly familiar material '], 0),
#  (['lulls you '], 0),
#  (["( dong ) makes a valiant effort to understand everyone 's point of view , and he does such a good job of it that family fundamentals gets you riled up . "],
#   1),
#  (['substance and soul '], 1),
#  (['high-powered star pedigree '], 1),
#  (['unique and quirky '], 1),
#  (["'s better than the phantom menace "], 1),
#  (['drags '], 0),
#  (['like a blown-out vein '], 0),
#  (['to infuse the rocky path to sibling reconciliation with flashes of warmth and gentle humor '],
#   1),
#  (['keep people going in this crazy life '], 1),
#  (['an unusually surreal tone '], 1),
#  (['staggered from the theater '], 0),
#  (['a chilly , brooding but quietly '], 1),
#  (['an incredibly heavy-handed , manipulative dud that feels all too familiar '],
#   0),
#  (['shrewd '], 0),
#  (['interesting story '], 1),
#  (['spend 110 claustrophobic minutes '], 0),
#  (['are lukewarm and quick to pass . '], 0),
#  (['a smart , romantic drama '], 1),
#  (['is sympathetic without being gullible '], 1),
#  (['a cheap cliché '], 0),
#  (['something provocative , rich , and strange '], 1),
#  (['easily forgotten '], 0),
#  (['overflows with wisdom and emotion '], 1),
#  (['300 years of russian history and culture '], 1),
#  (["ca n't distract from the flawed support structure holding equilibrium up "],
#   0),
#  (['slap me , i saw this movie . '], 0),
#  (['rooted '], 1),
#  (['an improvement on the first blade '], 1),
#  (['an elegant work '], 1),
#  (['with or without the sex , a wonderful tale of love and destiny '], 1),
#  (['enriched '], 1),
#  (["does n't try to surprise us with plot twists , but rather seems to enjoy its own transparency . "],
#   1),
#  (['smart and alert , thirteen conversations about one thing is a small gem . '],
#   1),
#  (['squeeze the action and our emotions '], 1),
#  (['instead of building to a laugh riot we are left with a handful of disparate funny moments of no real consequence . '],
#   0),
#  (['will find it more than capable of rewarding them . '], 1),
#  (['delightful '], 1),
#  (['the capability of effecting change and inspiring hope '], 1),
#  (['an intriguing look '], 1),
#  (['a warm , moving message '], 1),
#  (['while bollywood/hollywood will undoubtedly provide its keenest pleasures to those familiar with bombay musicals '],
#   1),
#  ([', it does so without compromising that complexity . '], 1),
#  (['recommend `` '], 1),
#  (['a distinctly minor effort that will be seen to better advantage on cable , especially considering its barely '],
#   0),
#  (['the charisma '], 1),
#  (["reputedly `` unfilmable '' novels "], 0),
#  (['mr. deeds is sure to give you a lot of laughs in this simple , sweet and romantic comedy . '],
#   1),
#  (['the rest of us will be lulled into a coma . '], 0),
#  (['upbeat '], 1),
#  (['creative energy and wit to entertain all ages '], 1),
#  (['convoluted '], 0),
#  (['best indie of the year , so far . '], 1),
#  (['a strangely tempting bouquet of a movie '], 1),
#  (['skip this turd and '], 0),
#  (['are amiable and committed '], 1),
#  (["even when he 's not at his most critically insightful , godard can still be smarter than any 50 other filmmakers still at work . "],
#   1),
#  (['about their budding amours '], 1),
#  (['lot to do with the casting of juliette binoche as sand , who brings to the role her pale , dark beauty and characteristic warmth '],
#   1),
#  (['-- and far less crass '], 1),
#  (['shiri is a must for genre fans . '], 1),
#  (['the pretensions -- and disposable story -- sink the movie . '], 0),
#  (["is n't as compelling or as believable "], 0),
#  (['if you ever wondered what it would be like to be smack in the middle of a war zone armed with nothing but a camera '],
#   1),
#  (["'s good to see michael caine whipping out the dirty words and punching people in the stomach again . "],
#   1),
#  (['are worse '], 0),
#  (['bore . '], 0),
#  (['a smart , provocative drama '], 1),
#  (['is a lame kiddie flick '], 0),
#  (['down-to-earth bullock '], 1),
#  (['marks an encouraging new direction for la salle . '], 1),
#  (['one of the greatest films '], 1),
#  (['a weird and wonderful comedy '], 1),
#  (['this sad , compulsive life '], 0),
#  (['though harris is affecting at times , he can not overcome the sense that pumpkin is a mere plot pawn for two directors with far less endearing disabilities . '],
#   0),
#  (['makes you believe the cast and crew thoroughly enjoyed themselves and believed in their small-budget film . '],
#   1),
#  (['major-league '], 1),
#  (['of exploitative garbage '], 0),
#  (['littered with zero-dimensional , unlikable characters and hackneyed , threadbare comic setups . '],
#   0),
#  (['threatens '], 0),
#  (['is completely lacking in charm and charisma , and '], 0),
#  (['as far as mainstream matinee-style entertainment goes '], 0),
#  (['true to its title , it traps audiences in a series of relentlessly nasty situations that we would pay a considerable ransom not to be looking at . '],
#   0),
#  (['is heartening in the same way that each season marks a new start '], 1),
#  (["extreme ops '' exceeds expectations . "], 1),
#  (['lingerie models and bar dancers '], 0),
#  (['will enjoy seeing how both evolve '], 1),
#  (['much sucks , but has a funny moment or two . '], 0),
#  (["it 's a great performance and a reminder of dickens ' grandeur . "], 1),
#  (['politically audacious '], 1),
#  (['exasperatingly '], 0),
#  (['deviant behavior '], 0),
#  (['the funniest american comedy '], 1),
#  (['goofily endearing and well-lensed gorefest '], 1),
#  (['through the eyes of the idealistic kid who chooses to champion his ultimately losing cause '],
#   1),
#  (['which was shot two years ago '], 1),
#  (['ruined by amateurish writing and acting , '], 0),
#  (['the artsy and often pointless visuals '], 0),
#  (['much of what we see is horrible '], 0),
#  (['trying to be more complex than your average film '], 1),
#  (['that is able to visualize schizophrenia but is still confident enough to step back and look at the sick character with a sane eye '],
#   1),
#  (['dumplings '], 1),
#  (['cable channel '], 0),
#  (['this modern mob music drama never fails to fascinate . '], 1),
#  (['does leblanc make one spectacularly ugly-looking broad , but he appears miserable throughout as he swaggers through his scenes . '],
#   0),
#  (['undermines the possibility for an exploration of the thornier aspects of the nature/nurture argument in regards '],
#   0),
#  (['fill the hot chick , the latest gimmick from this unimaginative comedian '],
#   0),
#  (['a sense of dramatic urgency '], 1),
#  (['have brought back the value and respect for the term epic cinema '], 1),
#  (['lyrical tale probes the ambiguous welcome extended by iran to the afghani refugees who streamed across its borders , desperate for work and food '],
#   1),
#  (['victims '], 0),
#  (['fincher takes no apparent joy in making movies '], 0),
#  (['impenetrable and insufferable ball '], 0),
#  (['the upper echelons '], 1),
#  (['a breezy blend of art , history , esoteric musings and philosophy '], 1),
#  (['reign '], 1),
#  (["'s compelling "], 1),
#  (["'s not as single-minded as john carpenter 's original "], 0),
#  (['comfy '], 1),
#  (["if religious films are n't your bailiwick , stay away . "], 0),
#  (['moderately successful but '], 1),
#  (['is icily brilliant . '], 1),
#  (["as predictable as the outcome of a globetrotters-generals game , juwanna mann is even more ludicrous than you 'd expect from the guy-in-a-dress genre , and a personal low for everyone involved . "],
#   0),
#  (['like having two guys yelling in your face for two hours '], 0),
#  (['fresh , sometimes funny , and '], 1),
#  (['real pleasure '], 1),
#  (['from this choppy and sloppy affair '], 0),
#  (['dull exposition '], 0),
#  (['of liveliness '], 1),
#  (['the mothman prophecies , which is mostly a bore '], 0),
#  (['crime drama fare '], 1),
#  (["before you pay the full ticket price to see `` simone , '' and consider a dvd rental instead "],
#   0),
#  (["`` frailty '' offers chills much like those that you get when sitting around a campfire around midnight , telling creepy stories to give each other the willies . "],
#   1),
#  (['a little more intensity and a little less charm would have saved this film a world of hurt . '],
#   0),
#  (['it is a whole lot of fun and '], 1),
#  (["do anything as stomach-turning as the way adam sandler 's new movie rapes , pillages and "],
#   0),
#  (['obsessive love '], 1),
#  (['backbone '], 1),
#  (['the pure adrenalin '], 1),
#  (["suffer ' "], 0),
#  (['better hip-hop clips '], 1),
#  (['of a sleeper success '], 1),
#  (['no one involved , save dash , shows the slightest aptitude for acting , and '],
#   0),
#  (['makes all the difference . '], 1),
#  (['guts '], 1),
#  ([', consistently funny . '], 1),
#  (['but very pleasing at its best moments '], 1),
#  (['sucks you in and dares you not to believe it '], 1),
#  (['the rut dug by the last one '], 0),
#  (["it will do so in a way that does n't make you feel like a sucker "], 1),
#  (['dicey screen material '], 0),
#  ([', nutty , consistently funny . '], 1),
#  (['rises above superficiality . '], 1),
#  (['upon which to hang broad , mildly fleshed-out characters that seem to have been conjured up only 10 minutes prior to filming '],
#   0),
#  (['could hardly ask for more . '], 1),
#  (['laugh-out-loud lunacy '], 1),
#  (['it actually makes the heart soar '], 1),
#  (['bags '], 0),
#  (['an especially well-executed television movie '], 1),
#  (['sensation '], 1),
#  (['also seems to play on a 10-year delay '], 0),
#  (['start to drag as soon as the action speeds up '], 0),
#  (['acidic all-male '], 0),
#  (["terry is a sort of geriatric dirty harry , which will please eastwood 's loyal fans -- and suits the story , wherein our hero must ride roughshod over incompetent cops to get his man . "],
#   1),
#  (["it 's a tribute to the actress , and to her inventive director , that the journey is such a mesmerizing one "],
#   1),
#  (['the film sits with square conviction '], 1),
#  (['an evanescent , seamless and sumptuous stream '], 1),
#  (["it also happens to be the movie 's most admirable quality "], 1),
#  (['care less '], 0),
#  (['end it all by stuffing himself into an electric pencil sharpener '], 0),
#  (['is very choppy and monosyllabic despite the fact '], 0),
#  (["it 's far from a frothy piece , and the characters are complex , laden with plenty of baggage and tinged with tragic undertones . "],
#   1),
#  (['the histrionic muse still eludes madonna and , playing a charmless witch , she is merely a charmless witch . '],
#   0),
#  (['the movie is without intent . '], 0),
#  (['minor miracle '], 1),
#  (['murderous '], 0),
#  (['obscenely bad dark comedy '], 0),
#  (['is one of those rare pictures that you root for throughout '], 1),
#  (['is a winner '], 1),
#  (['enjoyable film '], 1),
#  (["proves a servicable world war ii drama that ca n't totally hide its contrivances "],
#   1),
#  (["alice 's adventure through the looking glass and into zombie-land ' is filled with strange and wonderful creatures . "],
#   1),
#  (["final verdict : you 've seen it all before . "], 0),
#  (['pitch-perfect holden '], 1),
#  (['is superficial '], 0),
#  (['thrillingly '], 1),
#  (["trailer trash cinema so uncool the only thing missing is the `` gadzooks ! '' "],
#   0),
#  (['comes from the brave , uninhibited performances by its lead actors '], 1),
#  (['get on television '], 1),
#  (["is one of those crazy , mixed-up films that does n't know what it wants to be when it grows up "],
#   0),
#  (['the corniest '], 0),
#  (['men in black ii achieves ultimate insignificance -- '], 0),
#  (['of the most creative , energetic and original comedies to hit the screen in years '],
#   1),
#  (['has a good ear for dialogue , and the characters sound like real people . '],
#   1),
#  (['on and on to the point of nausea '], 0),
#  (['incongruous '], 0),
#  (['of carefully choreographed atrocities , which become strangely impersonal and abstract '],
#   0),
#  ([', the movie will likely set the cause of woman warriors back decades . '],
#   0),
#  (['is at once intimate and universal cinema '], 1),
#  (['the affection of that moral favorite '], 1),
#  (["it would take a complete moron to foul up a screen adaptation of oscar wilde 's classic satire . "],
#   0),
#  (['is just as obvious as telling a country skunk that he has severe body odor '],
#   0),
#  (['is given passionate , if somewhat flawed , treatment . '], 1),
#  (['is without doubt an artist of uncompromising vision , but that vision is beginning to feel , if not morally bankrupt , at least terribly monotonous . '],
#   0),
#  (['is difficult to fathom '], 0),
#  (["juvenile delinquent ' paperbacks "], 0),
#  (['relentlessly folksy '], 0),
#  (["tian 's meticulous talent "], 1),
#  (['too many chefs fussing over too weak a recipe '], 0),
#  (['eyes '], 1),
#  ...]

# %%
# Access the 4th data example in the dataset.
# get_input_text(3): returns the text of the 4th sample
# get_label(3): returns the label index (e.g., 0 or 1) of the 4th sample
sst_2.get_input_text(3), sst_2.get_label(3)
# Out:
# (['mawkish self-parody '], 'negative')

# %%
# Define the number of test samples and calculate the number of demonstration samples accordingly
test_samples = 512
dem_samples = len(sst_2) - test_samples  # Total dataset size minus test size

# Define the number of ICL examples (i.e k-shot)
k = 4
seed= 107
# Initialize a DatasetSplitter instance to handle train/test splits and k-shot setting
splitted_sst2 = dataset_interface.DatasetSplitter(sst_2, dem_samples, test_samples, seed)

# %%
# This is the *demonstration set* used for k-shot in-context learning (ICL).
# For example, if k=4, we randomly sample 4 examples (text + label) from the dataset.
# These 4 examples will be shown to the model as demonstrations, mimicking a few-shot learning setup.
# Important: After sampling these, we will no longer use or access this portion of the data.
# So we effectively only have 4 training examples in the ICL context.
splitted_sst2.demonstration.get_dataset()
# Out:
# [(['the simple fact '], 1),
#  (["all in all , it 's a pretty good execution of a story that 's a lot richer than the ones hollywood action screenwriters usually come up with on their own . "],
#   1),
#  (['acting that could be any flatter '], 0),
#  (['to crack a smile at '], 1),
#  (['which they have been patiently waiting for '], 1),
#  (["brash , intelligent and erotically perplexing , haneke 's portrait of an upper class austrian society and the suppression of its tucked away demons "],
#   1),
#  ([", hoffman 's quirks and mannerisms , particularly his penchant for tearing up on cue -- things that seem so real in small doses -- become annoying and artificial . "],
#   0),
#  (['earthy '], 1),
#  (['thoroughly winning flight of revisionist fancy . '], 1),
#  (['more timely in its despairing vision of corruption '], 1),
#  (['disarmingly '], 1),
#  (['is that her confidence in her material is merited . '], 1),
#  (['wedding sequence '], 1),
#  (['a slam-bang extravaganza that is all about a wild-and-woolly , wall-to-wall good time . '],
#   1),
#  (['no amount of earnest textbook psychologizing can bridge '], 0),
#  (['the story is bogus '], 0),
#  (['friends '], 1),
#  (["the adjective ` gentle ' applies "], 1),
#  (["... this is n't even a movie we can enjoy as mild escapism ; it is one in which fear and frustration are provoked to intolerable levels . "],
#   0),
#  (['capitalizes on this concept and opts for the breezy and amateurish feel of an after school special on the subject of tolerance . '],
#   0),
#  (["scherfig 's light-hearted profile of emotional desperation is achingly honest and delightfully cheeky . "],
#   1),
#  (['some unnecessary parts '], 0),
#  (['a mediocre exercise in target demographics '], 0),
#  (['become a household name '], 1),
#  (['it will make you think twice about what might be going on inside each trailer park you drive past -- even if it chiefly inspires you to drive a little faster . '],
#   1),
#  (['has elements of romance , tragedy and even silent-movie comedy '], 1),
#  (['like a blown-out vein '], 0),
#  (['displays with somber earnestness in the new adaptation of the cherry orchard '],
#   1),
#  (['malaise '], 0),
#  (['screwing '], 0),
#  ([', dramatically satisfying heroine '], 1),
#  (['can actually feel good '], 1),
#  (['its screwed-up characters '], 0),
#  (['silly comedy '], 1),
#  (['all the complexity and '], 1),
#  (['seems intimidated by both her subject matter and the period trappings of this debut venture into the heritage business '],
#   0),
#  (['any true emotional connection or identification frustratingly '], 0),
#  (['everything else about it is straight from the saturday morning cartoons -- a retread story , bad writing , and the same old silliness '],
#   0),
#  (['engaging storyline '], 1),
#  (['smart , steamy mix '], 1),
#  (['succeeds through sincerity '], 1),
#  (['moving moments and an intelligent subtlety '], 1),
#  (['journalistic or historical '], 1),
#  (['a jaw-droppingly beautiful work that upends nearly every cliché of japanese animation while delivering a more than satisfactory amount of carnage . '],
#   1),
#  (["is felt ; not the craven of ' a nightmare on elm street ' or ` the hills have eyes , ' but the sad schlock merchant of ` deadly friend . "],
#   0),
#  (['helps keep the proceedings as funny for grown-ups as for rugrats '], 1),
#  (['road '], 0),
#  (["it 's been 13 months and 295 preview screenings since i last walked out on a movie , but resident evil really earned my indignant , preemptive departure "],
#   0),
#  (['cinematic postcard '], 1),
#  (["you 're looking for an intelligent movie in which you can release your pent up anger "],
#   1),
#  (['like a travel-agency video '], 0),
#  (['mindless and boring martial arts and gunplay with too little excitement and zero compelling storyline . '],
#   0),
#  (["does n't completely survive its tonal transformation from dark comedy to suspense thriller "],
#   0),
#  (['melancholic '], 0),
#  (['a journey that is as difficult for the audience to take as it is for the protagonist '],
#   0),
#  (['paid in full is remarkably engaging despite being noticeably derivative of goodfellas and at least a half dozen other trouble-in-the-ghetto flicks . '],
#   1),
#  (['has some quietly moving moments and an intelligent subtlety '], 1),
#  (['the heart as well as '], 1),
#  (['the dialogue is cumbersome , the simpering soundtrack and editing more so . '],
#   0),
#  (['without having much dramatic impact '], 0),
#  (['hoping the nifty premise will create enough interest to make up for an unfocused screenplay '],
#   0),
#  ([', hilarious '], 1),
#  (['includes too much obvious padding . '], 0),
#  (['this intricately structured and well-realized drama '], 1),
#  (['because australia is a weirdly beautiful place '], 1),
#  (['a scrooge or two '], 0),
#  (['sees it as a chance to revitalize what is and always has been remarkable about clung-to traditions '],
#   1),
#  (['e.t. is still a cinematic touchstone . '], 1),
#  (['many pleasures '], 1),
#  (['heartfelt comedy '], 1),
#  (['to match the ordeal of sitting through it '], 0),
#  (["notwithstanding my problem with the movie 's final half hour "], 0),
#  (['like the english patient and the unbearable lightness of being '], 1),
#  (['sheer audacity and openness '], 1),
#  (['thinking man '], 1),
#  (['killing time '], 0),
#  (['the pristine camerawork '], 1),
#  (["the densest distillation of roberts ' movies "], 0),
#  (['an eye-boggling blend '], 1),
#  (['lightweight but appealing '], 1),
#  (['exasperatingly '], 0),
#  ([', by the time the credits roll across the pat ending , a warm , fuzzy feeling prevails '],
#   1),
#  (['horror '], 0),
#  (['well-done film '], 1),
#  (['maguire makes it a comic book with soul '], 1),
#  (['resorting to camp '], 0),
#  ([', it eventually works its way up to merely bad rather than painfully awful . '],
#   0),
#  (['smoother or more confident '], 1),
#  (['only a genius '], 0),
#  (['being wickedly funny and just plain wicked '], 1),
#  (['a fascinating examination '], 1),
#  ([', it sounds like a cruel deception carried out by men of marginal intelligence , with reactionary ideas about women and a total lack of empathy . '],
#   0),
#  (["wo n't be an ) "], 0),
#  (['this is a monumental achievement in practically every facet of inept filmmaking : joyless , idiotic , annoying , heavy-handed , visually atrocious , and often downright creepy . '],
#   0),
#  (['has the potential for touched by an angel simplicity and '], 1),
#  (['a part of us that can not help be entertained by the sight of someone getting away with something '],
#   1),
#  (['achieves near virtuosity in its crapulence '], 0),
#  ([', they are pitted against shimmering cinematography that lends the setting the ethereal beauty of an asian landscape painting . '],
#   1),
#  (['a beautiful , timeless and universal tale of heated passions -- jealousy , betrayal , forgiveness and murder . '],
#   1),
#  (['it required viewing in university computer science departments for years to come '],
#   1),
#  (['a brutal and funny '], 1),
#  (['glory '], 1),
#  (['laced with liberal doses of dark humor , gorgeous exterior photography , and a stable-full of solid performances , no such thing is a fascinating little tale . '],
#   1),
#  (['maudlin ending '], 0),
#  (['an elegant and sly deadpan '], 1),
#  (["without shakespeare 's eloquent language , the update is dreary and sluggish . "],
#   0),
#  (['is that rare combination of bad writing , bad direction and bad acting -- the trifecta of badness . '],
#   0),
#  (["so it 's not a brilliant piece of filmmaking , but it is a funny ( sometimes hilarious ) comedy with a deft sense of humor about itself , a playful spirit and a game cast . "],
#   1),
#  (['whose achievements -- and complexities -- reached far beyond the end zone '],
#   1),
#  (['demonstrated a knack for mixing action and idiosyncratic humor in his charming 2000 debut shanghai noon '],
#   1),
#  (['visual charm '], 1),
#  (['a bored cage '], 0),
#  (['the grace to call for prevention rather than to place blame , making it one of the best war movies ever made '],
#   1),
#  (["'s really little more than a particularly slanted , gay s/m fantasy , enervating and deadeningly drawn-out . "],
#   0),
#  (['the most creative , energetic and original comedies to hit the screen in years '],
#   1),
#  (['there is nothing in it to engage children emotionally '], 0),
#  (['a dashing and resourceful hero ; a lisping , reptilian villain ; '], 1),
#  (['vile '], 0),
#  (["is expressly for idiots who do n't care what kind of sewage they shovel into their mental gullets to simulate sustenance . "],
#   0),
#  (['you may just end up trying to drown yourself in a lake afterwards . '], 0),
#  (["time literally stops on a dime in the tries-so-hard-to-be-cool `` clockstoppers , '' "],
#   0),
#  (["toback 's ) fondness for fancy split-screen , stuttering editing and pompous references to wittgenstein and kirkegaard "],
#   0),
#  (['genuinely witty '], 1),
#  (['dramatized '], 1),
#  (["of what 's wrong with this increasingly pervasive aspect of gay culture "],
#   0),
#  (['mediocre exercise '], 0),
#  (["gets too cloying thanks to the actors ' perfect comic timing and sweet , genuine chemistry . "],
#   1),
#  (['is painterly . '], 1),
#  (['is a fun and funky look into an artificial creation in a world that thrives on artificiality . '],
#   1),
#  (['spent watching this waste of time '], 0),
#  (['there are few things more frustrating to a film buff than seeing an otherwise good movie marred beyond redemption by a disastrous ending . '],
#   0),
#  (["you 're not a fan "], 0),
#  (['a gently funny , sweetly adventurous film that makes you feel genuinely good '],
#   1),
#  (['rotten in the state of california '], 0),
#  (['another boorish movie '], 0),
#  (["with each of her three protagonists , miller eloquently captures the moment when a woman 's life , out of a deep-seated , emotional need , is about to turn onto a different path . "],
#   1),
#  (["translation : ` we do n't need to try very hard . "], 0),
#  (['that might have made it an exhilarating '], 1),
#  (['and , through it all , human '], 1),
#  (["'d prefer a simple misfire "], 0),
#  (['the players it brings to the fore for the gifted but no-nonsense human beings they are and for the still-inestimable contribution they have made to our shared history '],
#   1),
#  (['find little of interest '], 0),
#  (['not smart or barbed enough for older viewers '], 0),
#  (['only because the cast is so engagingly messing around like slob city reductions of damon runyon crooks '],
#   0),
#  (["'s something vital about the movie . "], 1),
#  (['muted '], 0),
#  (['to protect your community from the dullest science fiction '], 0),
#  (['you reach the finale '], 1),
#  (["too polite to scale the lunatic heights of joe dante 's similarly styled gremlins "],
#   0),
#  (['tasty performance '], 1),
#  (['an enjoyable film '], 1),
#  (['it dull , lifeless , and irritating '], 0),
#  (['a poetic '], 1),
#  (['compelling dramatic '], 1),
#  (['plays like an unbalanced mixture of graphic combat footage and almost saccharine domestic interludes that are pure hollywood . '],
#   0),
#  (['juvenile '], 0),
#  (['thriller junk '], 0),
#  ([', hard-hitting documentary . '], 1),
#  (['a massive infusion '], 0),
#  (["get to the closing bout ... by which time it 's impossible to care who wins "],
#   0),
#  (["a sour taste in one 's mouth "], 0),
#  (["are n't likely to leave a lasting impression . "], 0),
#  (['coen brothers '], 1),
#  (['of gags that rely on the strength of their own cleverness '], 1),
#  (['... a delightfully unpredictable , hilarious comedy with wonderful performances that tug at your heart in ways that utterly transcend gender labels . '],
#   1),
#  (['look at the backstage angst of the stand-up comic . '], 1),
#  (["viewers of barney 's crushingly self-indulgent spectacle "], 0),
#  (['their time ( including mine ) on something very inconsequential '], 0),
#  (['neatly and effectively captures the debilitating grief '], 1),
#  (['red dragon rates as an exceptional thriller . '], 1),
#  (['document '], 1),
#  (['with the emphasis on self-empowering schmaltz and big-wave surfing that gives pic its title an afterthought '],
#   0),
#  (['superbly '], 1),
#  (['acquire the fast-paced contemporary society '], 1),
#  (['never settles into the light-footed enchantment the material needs '], 0),
#  (['fruitful '], 1),
#  (['vivid performances '], 1),
#  (['with its own solemn insights '], 1),
#  (['rooting for the film '], 1),
#  (["dickens ' words "], 1),
#  (['there is an accuracy of observation in the work of the director , frank novak , that keeps the film grounded in an undeniable social realism . '],
#   1),
#  (['less for its story of actorly existential despair than for its boundary-hopping formal innovations and glimpse into another kind of chinese '],
#   1),
#  (["the libretto directs , ideally capturing the opera 's drama and lyricism "],
#   1),
#  (['easily marketable '], 1),
#  (['that effortlessly draws you in '], 1),
#  (["dong never pushes for insights beyond the superficial tensions of the dynamic he 's dissecting , and "],
#   0),
#  (["everything about girls ca n't swim , even its passages of sensitive observation , feels secondhand , familiar -- and not in a good way . "],
#   0),
#  (['some of the computer animation is handsome , and '], 1),
#  (["japan 's wildest filmmaker gives us a crime fighter carrying more emotional baggage than batman ... "],
#   0),
#  (['charming , banter-filled comedy '], 1),
#  (['devoid of objectivity and full of nostalgic comments from the now middle-aged participants '],
#   0),
#  (['witty , vibrant , and intelligent '], 1),
#  (['will make you laugh '], 1),
#  (['will have an intermittently good time '], 1),
#  (['is one word that best describes this film : honest '], 1),
#  (["'re just a couple of cops in copmovieland , these two "], 0),
#  (["it 's not really funny "], 0),
#  (['one-hour mark '], 1),
#  (['if tragic ) '], 0),
#  (['establishes a wonderfully creepy mood '], 1),
#  (['star-studded '], 1),
#  (['a cinematic fluidity and sense '], 1),
#  (['satire and childhood awakening '], 1),
#  (['of the situation in a well-balanced fashion '], 1),
#  (['waterlogged script '], 0),
#  (['had more fun watching spy than i had with most of the big summer movies . '],
#   1),
#  (['aching '], 0),
#  (['about otherwise dull subjects '], 0),
#  (['headline-fresh thriller '], 1),
#  (["the ethos of the chelsea hotel may shape hawke 's artistic aspirations , but he has n't yet coordinated his own dv poetry with the beat he hears in his soul . "],
#   0),
#  (['call me a cynic , '], 0),
#  (['the working '], 1),
#  (['the gloss '], 1),
#  (['saucy '], 1),
#  (['when the right movie comes along , especially if it begins with the name of star wars '],
#   1),
#  (['that try too hard to be mythic '], 0),
#  (['crafted , and well executed '], 1),
#  (["if you have n't seen the film lately , you may be surprised at the variety of tones in spielberg 's work . "],
#   1),
#  (['walked away from this new version of e.t. '], 0),
#  (['dashing '], 1),
#  (['seen as hip , winking social commentary '], 1),
#  (["tries too hard to be funny in a way that 's too loud , too goofy and too short of an attention span . "],
#   0),
#  (['a whole heap '], 0),
#  (['a jaw-droppingly beautiful work that upends nearly every cliché of japanese animation while delivering a more than satisfactory amount of carnage '],
#   1),
#  (['shows crushingly little curiosity about , or is ill-equipped to examine , the interior lives of the characters in his film , much less incorporate them into his narrative . '],
#   0),
#  (['portrays their cartoon counterparts well ... '], 1),
#  ([', double-pistoled , ballistic-pyrotechnic hong kong action '], 1),
#  (['this rich , bittersweet israeli documentary '], 1),
#  (['for that sense of openness , the little surprises '], 1),
#  (['an amusing and unexpectedly insightful examination '], 1),
#  (['starts as an intense political and psychological thriller but is sabotaged by ticking time bombs and other hollywood-action cliches . '],
#   0),
#  (["`` the adventures of pluto nash '' is a big time stinker . "], 0),
#  (['think is supposed to be an attempt at hardass american but sometimes just lapses into unhidden british '],
#   0),
#  (["'s the cute frissons of discovery and humor between chaplin and kidman that keep this nicely wound clock not just ticking , but humming "],
#   1),
#  (['it is also beautifully acted . '], 1),
#  (["it 's still a comic book , but maguire makes it a comic book with soul "],
#   1),
#  (['a tendency to slip into hokum '], 0),
#  (['a standout performance '], 1),
#  (["miyazaki 's nonstop images are so stunning , and his imagination so vivid , "],
#   1),
#  (['my great pleasure '], 1),
#  (["that he 's the best brush in the business "], 1),
#  (['pizazz '], 1),
#  (["dover kosashvili 's outstanding feature debut so potent "], 1),
#  (['targeted to the tiniest segment of an already obscure demographic '], 0),
#  (['terrifically '], 1),
#  (['bland actors '], 0),
#  (['portrayals '], 0),
#  (['lowered your entertainment standards '], 0),
#  (['which , as you watch them clumsily mugging their way through snow dogs , seems inconceivable '],
#   0),
#  (['happens to be good '], 1),
#  (['familiar and predictable , and 4/5ths of it '], 0),
#  (['all credibility flies out the window . '], 0),
#  (["'s a lot of tooth in roger dodger "], 1),
#  (['evil '], 0),
#  (["the movie 's major and most devastating flaw "], 0),
#  (['delicious dialogue '], 1),
#  (['boring despite the scenery '], 0),
#  (['the film has in kieran culkin a pitch-perfect holden . '], 1),
#  (["mamet 's airless cinematic shell games . "], 1),
#  (['looking for a return ticket '], 0),
#  (['from the flawed support structure holding equilibrium up '], 0),
#  (['the end that extravagantly redeems it '], 1),
#  (['the most unpleasant things '], 0),
#  (['unfortunate title '], 0),
#  (['more tiring than anything '], 0),
#  (['the condescending stereotypes '], 0),
#  (['an infinitely wittier version of the home alone formula '], 1),
#  (['trailer-trash '], 0),
#  (["see how many times they can work the words `` radical '' or `` suck '' into a sentence "],
#   0),
#  (['recite some of this laughable dialogue '], 0),
#  (["'s as entertaining "], 1),
#  (['is clever and funny , is amused by its special effects '], 1),
#  (['with virtuoso throat-singing '], 1),
#  (['admire it and yet can not recommend it , because it overstays its natural running time . '],
#   0),
#  (['a bracing , unblinking work that serves as a painful elegy and sobering cautionary tale '],
#   1),
#  (['motivated by something more than franchise possibilities '], 1),
#  (['pretty good little movie . '], 1),
#  (['arrives at its heart , as simple self-reflection meditation '], 1),
#  (["'s the butt of its own joke "], 0),
#  (['badly edited , often awkwardly directed and suffers from the addition of a wholly unnecessary pre-credit sequence designed to give some of the characters a ` back story '],
#   0),
#  (['is heartening in the same way that each season marks a new start '], 1),
#  (['feel like time fillers between surf shots '], 0),
#  (['break up '], 0),
#  (['magnificent directorial career '], 1),
#  (["cacoyannis ' vision is far less mature , interpreting the play as a call for pity and sympathy for anachronistic phantasms haunting the imagined glory of their own pasts . "],
#   0),
#  (['warm and well-told tale '], 1),
#  (['more like the pilot episode of a tv series '], 0),
#  (['luminous interviews '], 1),
#  (['echoes the by now intolerable morbidity of so many recent movies '], 0),
#  (["foreman 's barking-mad taylor to thewlis 's smoothly sinister freddie and bettany/mcdowell 's hard-eyed gangster "],
#   1),
#  (['truly '], 1),
#  (['to seem as long as the two year affair which is its subject '], 0),
#  (['cheesier '], 0),
#  (['ruthlessly pained '], 0),
#  (["several survivors , whose riveting memories are rendered with such clarity that it 's as if it all happened only yesterday "],
#   1),
#  (['is definitely meaningless , vapid and devoid '], 0),
#  (["what 's worse , routine "], 0),
#  (['very lively dream '], 1),
#  (['a rote exercise in both animation and storytelling . '], 0),
#  (['an unwieldy cast '], 0),
#  (['appreciates the art and '], 1),
#  (['gunfight '], 0),
#  (['guide a loose , poorly structured film through the pitfalls of incoherence and redundancy '],
#   0),
#  (['see a better thriller '], 0),
#  (['terrifically entertaining '], 1),
#  (["'s a fun adventure movie for kids ( of all ages ) that like adventure "],
#   1),
#  (["is the best ` old neighborhood ' project since christopher walken kinda romanced cyndi lauper in the opportunists "],
#   1),
#  (['conspicuous '], 0),
#  (['the idea of exploiting molestation for laughs is funny , not actually exploiting it yourself '],
#   0),
#  (['screenplay to die for '], 1),
#  (['its script and execution '], 1),
#  (['while american adobo has its heart ( and its palate ) in the right place '],
#   1),
#  (['i had a dream that a smart comedy would come along to rescue me from a summer of teen-driven , toilet-humor codswallop , and its name was earnest . '],
#   1),
#  (["'s tv sitcom material at best "], 1),
#  (['an astonishingly witless script '], 0),
#  (['ecstasy '], 1),
#  (['it does cathartic truth telling '], 1),
#  (['enhanced by a surplus of vintage archive footage '], 1),
#  (['moment '], 1),
#  (['possesses its own languorous charm . '], 1),
#  (['is so warm and fuzzy you might be able to forgive its mean-spirited second half '],
#   1),
#  (['after the first 10 minutes , which is worth seeing , the movie sinks into an abyss of clichés , depression and bad alternative music . '],
#   0),
#  (['slightly naughty , just-above-average off - broadway play '], 1),
#  (["in addition to hoffman 's powerful acting clinic , this is that rare drama that offers a thoughtful and rewarding glimpse into the sort of heartache everyone has felt , or will feel someday . "],
#   1),
#  (['is a refreshingly smart and newfangled variation on several themes derived from far less sophisticated and knowing horror films '],
#   1),
#  (['be as simultaneously funny , offbeat and heartwarming ( without a thick shmear of the goo , at least ) '],
#   1),
#  (['that made spy kids a surprising winner with both adults and younger audiences '],
#   1),
#  (['erotic or sensuous charge '], 1),
#  (['what a concept , what an idea , what a thrill ride . '], 1),
#  (['have a fun , no-frills ride '], 1),
#  (['provides an invaluable service by sparking debate and encouraging thought '],
#   1),
#  (['the scenes of torture and self-mutilation '], 0),
#  (['could hardly '], 0),
#  (['flick that scalds like acid '], 0),
#  (['its courageousness , '], 1),
#  (['no palpable chemistry '], 0),
#  (['oddly compelling . '], 1),
#  (['what enlivens this film '], 1),
#  (["co-writer/director jonathan parker 's attempts to fashion a brazil-like , hyper-real satire fall dreadfully short . "],
#   0),
#  (['a key strength in its willingness to explore its principal characters with honesty , insight and humor '],
#   1),
#  (['dreamed up such blatant and sickening product placement in a movie '], 0),
#  (['charisma and '], 1),
#  (['fluid , no-nonsense authority '], 1),
#  (["'s a pale imitation . "], 0),
#  (['mind : so why is this so boring ? '], 0),
#  (['little action , almost no suspense or believable tension , one-dimensional characters up '],
#   0),
#  (['like some sort of martha stewart decorating program run amok '], 0),
#  (['of too many chefs fussing over too weak a recipe '], 0),
#  (["do n't feel much for damon/bourne or his predicament "], 0),
#  (['cruel , misanthropic stuff with only weak claims to surrealism and black comedy '],
#   0),
#  (['tolerable-to-adults lark of a movie '], 0),
#  (['unusually surreal '], 1),
#  (['so that , by the time the credits roll across the pat ending , a warm , fuzzy feeling prevails '],
#   1),
#  ([", despite downplaying her good looks , carries a little too much ai n't - she-cute baggage into her lead role as a troubled and determined homicide cop to quite pull off the heavy stuff . "],
#   0),
#  (['is ok for a movie to be something of a sitcom apparatus '], 1),
#  (['ambiguous enough to be engaging and '], 1),
#  (['for in drama , suspense , revenge , and romance '], 1),
#  (['is compelling enough '], 1),
#  (['create characters who are sweet and believable , and are defeated by a screenplay that forces them into bizarre , implausible behavior '],
#   0),
#  (['great performances , stylish cinematography and a gritty feel help '], 1),
#  (["that it 's a crime movie made by someone who obviously knows nothing about crime "],
#   0),
#  (['dumb story '], 0),
#  (['to the always hilarious meara and levy '], 1),
#  (['sometimes exceptional film '], 1),
#  (['profoundly stupid '], 0),
#  (['emotional evolution '], 1),
#  (['hill looks to be going through the motions , beginning with the pale script . '],
#   0),
#  (['of a good vampire tale '], 1),
#  (['that constantly defies expectation '], 1),
#  (["`` gory mayhem '' is your idea of a good time "], 1),
#  (["it 's a long way from orwell 's dark , intelligent warning cry ( 1984 ) to the empty stud knockabout of equilibrium , and what once was conviction is now affectation . "],
#   0),
#  (['humorous and touching . '], 1),
#  (['a documentary fails to live up to -- or offer any new insight into -- its chosen topic '],
#   0),
#  (['the rock on a wal-mart budget '], 0),
#  (["the opera 's drama and lyricism "], 1),
#  ([', you might have fun in this cinematic sandbox '], 1),
#  ([", we 'd prefer a simple misfire . "], 0),
#  (["just ca n't tear himself away from the characters "], 1),
#  (['an awkwardly garish showcase that diverges from anything '], 0),
#  (['manages to insult the intelligence of everyone in the audience '], 0),
#  (["recommended -- as visually bland as a dentist 's waiting room , "], 0),
#  (['a maker of softheaded metaphysical claptrap '], 0),
#  (['as splendid-looking as this particular film '], 1),
#  (['some surprises '], 1),
#  (["enjoyably dumb , sweet , and intermittently hilarious -- if you 've a taste for the quirky , steal a glimpse . "],
#   1),
#  (['displacement '], 0),
#  (['winning performances and some effecting moments '], 1),
#  (['wrong hands '], 0),
#  (['that have all but ruined his career '], 0),
#  (['that ultimately defeated the film ... it was the unfulfilling , incongruous , `` wait a second '],
#   0),
#  (['may have expected to record with their mini dv '], 1),
#  (['mediocre '], 0),
#  (['recite some of this laughable dialogue with a straight face '], 1),
#  (["accomplishes so much that one viewing ca n't possibly be enough "], 1),
#  (['real characters '], 1),
#  (['an intimate feeling , '], 1),
#  (["the actors ' perfect comic timing and sweet , genuine chemistry "], 1),
#  (['is too steeped in fairy tales and other childish things '], 0),
#  (['wasting away inside unnecessary films '], 0),
#  (['graces '], 1),
#  (['too weak '], 0),
#  (['visually sloppy '], 0),
#  (["this `` un-bear-able '' project "], 0),
#  ([', she is merely a charmless witch . '], 0),
#  (['is that it progresses in such a low-key manner that it risks monotony '],
#   0),
#  (['its exquisite acting '], 1),
#  (['lacks depth . '], 0),
#  (["zone '' episode "], 1),
#  (['the kind of quirkily appealing minor movie she might not make for a while '],
#   1),
#  (['of dazzling pop entertainment '], 1),
#  (['quite endearing . '], 1),
#  (['a cohesive story '], 1),
#  (['every scrap is of the darkest variety '], 1),
#  (['add much-needed levity to the otherwise bleak tale '], 1),
#  (['tabloid '], 0),
#  (['more and more frustrating '], 0),
#  (['the film is a verbal duel between two gifted performers . '], 1),
#  (['its cast , its cuisine and its quirky tunes '], 1),
#  (['such clarity '], 1),
#  (['with complicated plotting and banal dialogue '], 0),
#  (['murderous maids pulls no punches in its depiction of the lives of the papin sister and the events that led to their notorious rise to infamy ... '],
#   1),
#  ([', stealing harvard is a smorgasbord of soliloquies about nothing delivered by the former mr. drew barrymore . '],
#   0),
#  (['horrid little propaganda film with fascinating connections not only to the serbs themselves but also to a network of american right-wing extremists . '],
#   1),
#  (['can be viewed as pure composition and form -- film as music '], 1),
#  (['an auspicious feature debut '], 1),
#  (['the film is essentially juiceless . '], 0),
#  (['an emotionally satisfying exploration of the very human need '], 1),
#  (['family dynamics '], 1),
#  (['how good it all was , and started doing nothing but reacting to it - feeling a part of its grand locations , thinking urgently as the protagonists struggled , feeling at the mercy of its inventiveness , gasping at its visual delights '],
#   1),
#  (['takes every potential laugh '], 1),
#  (['a superlative b movie -- funny , sexy , and rousing '], 1),
#  (['give credit to affleck '], 1),
#  (['emphasizing the disappointingly generic nature of the entire effort '], 0),
#  (['about a superficial midlife crisis '], 0),
#  (['as it explores the awful complications of one terrifying day '], 0),
#  (['bibbidy-bobbidi-bland '], 0),
#  (["the cat 's meow marks a return to form for director peter bogdanovich ... "],
#   1),
#  (['sharp movie '], 1),
#  (['the journey feel like a party '], 1),
#  (['has created a film that one can honestly describe as looking , sounding and simply feeling like no other film in recent history '],
#   1),
#  (['writer/director alexander payne ( election ) and his co-writer jim taylor brilliantly employ their quirky and fearless ability to look american angst in the eye and end up laughing . '],
#   1),
#  (['the wake of saving private ryan '], 1),
#  (['screenwriter dan schneider and director shawn levy '], 1),
#  ([", the movie runs a good race , one that will have you at the edge of your seat for long stretches . ' "],
#   1),
#  (['are ... '], 1),
#  (['worst sin '], 0),
#  ([', but miss wonton floats beyond reality with a certain degree of wit and dignity . '],
#   1),
#  (['a female friendship that is more complex and honest than anything represented in a hollywood film '],
#   1),
#  ([", madonna 's cameo does n't suck ! "], 1),
#  (['is a fast , frenetic , funny , even punny 6 -- aimed specifically at a grade-school audience '],
#   1),
#  (['lines , the impressive stagings of hardware '], 1),
#  (["plods along methodically , somehow under the assumption that its `` dead wife communicating from beyond the grave '' framework is even remotely new or interesting "],
#   0),
#  (['above-average thriller '], 1),
#  (['wonderful , sobering , heart-felt drama '], 1),
#  (["which fly by so fast there 's no time to think about them anyway "], 0),
#  (["it 's a very sincere work "], 1),
#  (['rich historical subject '], 1),
#  (["like a fish that 's lived too long , austin powers in goldmember has some unnecessary parts and is kinda wrong in places . "],
#   0),
#  (['far less sophisticated and '], 0),
#  (['there was ever a movie where the upbeat ending feels like a copout '], 0),
#  (['arrest development in a dead-end existence '], 0),
#  (['a work of extraordinary journalism , but it is also a work of deft and subtle poetry . '],
#   1),
#  (['its poignant and uplifting story '], 1),
#  (["'s good enough . "], 1),
#  (['is a genuinely bone-chilling tale '], 1),
#  (['is a poster movie , a mediocre tribute to films like them '], 0),
#  (['is a big , juicy role '], 1),
#  (['in a giant pile of elephant feces '], 0),
#  (['to have dumped a whole lot of plot in favor of ... outrageous gags '], 0),
#  (['can make interesting a subject you thought would leave you cold '], 1),
#  (["threw loads of money at an idea that should 've been so much more even if it was only made for teenage boys and wrestling fans "],
#   0),
#  (['extraordinary faith '], 1),
#  (['is more interested in entertaining itself than in amusing us '], 0),
#  (['tom tykwer , director of the resonant and sense-spinning run lola run , has turned out to be a one-trick pony '],
#   0),
#  (['an extra-dry office comedy that seems twice as long as its 83 minutes '],
#   0),
#  (['have poignancy jostling against farce , thoughtful dialogue elbowed aside by one-liners , and a visual style that incorporates rotoscope animation for no apparent reason except , maybe , that it looks neat . '],
#   0),
#  (['inspired portrait '], 1),
#  (["putting the primitive murderer inside a high-tech space station unleashes a pandora 's box of special effects that run the gamut from cheesy to cheesier to cheesiest . "],
#   0),
#  (["'s unfortunate that wallace , who wrote gibson 's braveheart as well as the recent pearl harbor , has such an irrepressible passion for sappy situations and dialogue "],
#   0),
#  (["the old mib label stands for milder is n't better . "], 0),
#  ([', sordid universe '], 0),
#  (["'s plotless , shapeless "], 0),
#  (['to make absurdist observations '], 0),
#  (["for cryin ' "], 1),
#  (["that it 's actually watchable "], 1),
#  (['threw medical equipment at a window ; not because it was particularly funny '],
#   0),
#  (['irresistible '], 1),
#  (['its target audience talked all the way through it '], 0),
#  (["some special qualities and the soulful gravity of crudup 's anchoring performance "],
#   1),
#  (['entirely suspenseful , '], 1),
#  (['puts a human face on derrida , and makes one of the great minds of our times interesting and accessible '],
#   1),
#  (['is surely one of the most frantic , virulent and foul-natured christmas season pics ever delivered by a hollywood studio '],
#   0),
#  (['such a dungpile '], 0),
#  (['as a catalyst for the struggle of black manhood in restrictive and chaotic america ... sketchy but nevertheless gripping portrait of jim brown , a celebrated wonder in the spotlight '],
#   1),
#  (['the gift of tears '], 1),
#  (['abandon all hope of a good movie ye who enter here '], 0),
#  (['the final effect is like having two guys yelling in your face for two hours . '],
#   0),
#  (['birthday girl walks a tricky tightrope between being wickedly funny and just plain wicked . '],
#   1),
#  (["come closer than anyone could desire to the cheap , graceless , hackneyed sci-fi serials of the '30s and '40s "],
#   0),
#  (['the observations '], 1),
#  (["'s a film that affirms the nourishing aspects of love and companionship . "],
#   1),
#  (['a play that only ever walked the delicate tightrope between farcical and loathsome '],
#   0),
#  (['who welcomes a dash of the avant-garde fused with their humor '], 1),
#  (['hard-hitting documentary '], 1),
#  (['interesting developments '], 1),
#  (['jokester highway patrolmen '], 1),
#  (['orgasm '], 1),
#  (['bring '], 1),
#  (["by way of what can be gleaned from this three-hour endurance test built around an hour 's worth of actual material "],
#   0),
#  (['a haunted house , '], 0),
#  (['numbingly dull-witted and disquietingly creepy '], 0),
#  (['like the guys '], 1),
#  (['land beyond time '], 1),
#  (['finely crafted , finely written , exquisitely performed '], 1),
#  (['whiny '], 0),
#  (['best date movie '], 1),
#  (['earns extra points '], 1),
#  (['lacking in charm and charisma '], 0),
#  (['a bad , bad , bad movie '], 0),
#  (['slick and sprightly cgi feature '], 1),
#  (['is , in a word , brilliant as the conflicted daniel . '], 1),
#  (['about discovering your destination in life '], 1),
#  (['terrorists are more evil than ever ! '], 0),
#  (['to get bogged down in earnest dramaturgy '], 0),
#  (['few cheap shocks '], 0),
#  (["abandon '' will leave you wanting to abandon the theater . "], 0),
#  (['rape and '], 0),
#  (['with grace and panache '], 1),
#  (["'s fun "], 1),
#  (['the adventures of pluto nash is a whole lot of nada . '], 0),
#  (['runs on the pure adrenalin '], 1),
#  (['endearing . '], 1),
#  (['left me behind '], 0),
#  (['sports extravaganza '], 1),
#  (['a sleeper success '], 1),
#  (['the stale material '], 0),
#  (['her confidence in her material '], 1),
#  (['tired , '], 0),
#  (['deeply spiritual film taps into the meaning and consolation in afterlife communications . '],
#   1),
#  (['imagine ( if possible ) a pasolini film without passion or politics '], 0),
#  (['odd , rapt spell '], 0),
#  (['is downright movie penance '], 1),
#  (['it is formula filmmaking '], 0),
#  (['the film boasts dry humor and jarring shocks , plus moments of breathtaking mystery . '],
#   1),
#  (['never becomes claustrophobic '], 1),
#  (['confuses its message with an ultimate desire to please , and contorting itself into an idea of expectation '],
#   0),
#  (["'m sure the filmmaker would disagree , but , honestly , i do n't see the point "],
#   0),
#  (['surprise us with plot twists '], 1),
#  (['a calculating fiend or '], 0),
#  ([', but far more witty '], 1),
#  (['somewhat flawed , '], 0),
#  (['sweet-tempered '], 1),
#  (["did n't connect with me would require another viewing "], 0),
#  (['has intentionally left college or was killed '], 0),
#  (["rock 's stand-up magic wanes . "], 0),
#  (["the script , the gags , the characters are all direct-to-video stuff , and that 's where this film should have remained . "],
#   0),
#  (['the tone for a summer of good stuff '], 1),
#  (['mechanical you can smell the grease on the plot '], 0),
#  (["darned if your toes wo n't still be tapping "], 1),
#  (['no good inside dope , and no particular bite '], 0),
#  (["safe as a children 's film "], 1),
#  (["not counting a few gross-out comedies i 've been trying to forget , this is the first film in a long time that made me want to bolt the theater in the first 10 minutes . "],
#   0),
#  (['a ) soulless '], 0),
#  (['into a lyrical and celebratory vision '], 1),
#  (['a winning and wildly fascinating work . '], 1),
#  (['most poorly staged and lit '], 0),
#  (['an insultingly unbelievable final act '], 0),
#  (['loses its fire '], 0),
#  (["nicole holofcenter , the insightful writer/director responsible for this illuminating comedy does n't wrap the proceedings up neatly "],
#   1),
#  (['willingness to wander into the dark areas of parent-child relationships without flinching '],
#   1),
#  (['of kitsch hard going '], 1),
#  (['a subtle and richly internalized performance '], 1),
#  (['manages to find that real natural , even-flowing tone that few movies are able to accomplish . '],
#   1),
#  (['a thoughtful and surprisingly affecting portrait '], 1),
#  (['is the gabbiest giant-screen movie ever , bogging down in a barrage of hype . '],
#   0),
#  (['a gangster movie with the capacity '], 1),
#  (['sentimentalizing '], 1),
#  (['particularly joyless , and exceedingly dull , '], 0),
#  (['to its proper home '], 1),
#  (['afghan tragedies '], 0),
#  (['through this picture i was beginning to hate it '], 0),
#  (['... a solid , unassuming drama . '], 1),
#  (['offbeat humor '], 1),
#  (['offers little insight into the experience of being forty , female and single '],
#   0),
#  (['enough to sit through crap like this '], 0),
#  (['straightforward , emotionally honest '], 1),
#  (['stiff and schmaltzy and clumsily directed . '], 0),
#  (['imagine that a more confused , less interesting and more sloppily made film could possibly come down the road in 2002 '],
#   0),
#  (['moviegoers not already clad in basic black '], 0),
#  (['is a fascinating little tale '], 1),
#  (["'s an enjoyable trifle nonetheless "], 1),
#  (["only of one man 's quest to be president , but of how that man single-handedly turned a plane full of hard-bitten , cynical journalists into what was essentially , by campaign 's end , an extended publicity department "],
#   1),
#  (['and engaging examination '], 1),
#  (['goodness for this signpost '], 1),
#  (['a 60-second homage '], 1),
#  (["feeling like you 've completely lowered your entertainment standards "],
#   0),
#  (['the biggest problem '], 0),
#  (['nice piece of work '], 1),
#  (["is a purposefully reductive movie -- which may be why it 's so successful at lodging itself in the brain . "],
#   1),
#  (['a tearjerker '], 1),
#  (['a dreary , humorless soap opera '], 0),
#  (["a grand fart coming from a director beginning to resemble someone 's crazy french grandfather . "],
#   0),
#  (['a delightful surprise because despite all the backstage drama , this is a movie that tells stories that work -- is charming , is moving , is funny and looks professional . '],
#   1),
#  (['an inconclusive ending '], 0),
#  (['freedom the iranian people already possess , with or without access to the ballot box '],
#   1),
#  (['no way original '], 0),
#  (['see this piece of crap again '], 0),
#  (['might i suggest that the wayward wooden one end it all by stuffing himself into an electric pencil sharpener ? '],
#   0),
#  (['makes its message resonate '], 1),
#  (['shamelessly money-grubbing '], 0),
#  (['provides a very moving and revelatory footnote to the holocaust . '], 1),
#  (['though her fans will assuredly have their funny bones tickled , others will find their humor-seeking dollars best spent elsewhere . '],
#   0),
#  (['for nice evening out '], 1),
#  (['the most ravaging , '], 1),
#  (['over the end of cinema '], 1),
#  (['its and pieces of the hot chick are so hilarious , '], 1),
#  (['thoughtful dialogue elbowed aside by one-liners , and a visual style that incorporates rotoscope animation for no apparent reason except '],
#   0),
#  (['claustrophobic '], 0),
#  (['feeling embarrassed '], 0),
#  (["sarah 's dedication to finding her husband seems more psychotic than romantic , "],
#   0),
#  (['feel good about themselves '], 1),
#  (['think , zzzzzzzzz '], 0),
#  (["a `` snl '' has-been "], 0),
#  (['resist his pleas to spare wildlife and respect their environs '], 1),
#  (['feel-good movie '], 1),
#  (["the tuxedo was n't just bad ; it was , as my friend david cross would call it , ` hungry-man portions of bad ' "],
#   0),
#  (['if i could have looked into my future and saw how bad this movie was , i would go back and choose to skip it . '],
#   0),
#  (['to infuse the rocky path to sibling reconciliation with flashes of warmth and gentle humor '],
#   1),
#  (['a plethora of engaging diatribes on the meaning of ` home '], 1),
#  (['are presented in convincing way '], 1),
#  (['cutting and blurry '], 0),
#  (['may scream low budget '], 0),
#  (['been allowed to get wet , fuzzy and sticky '], 0),
#  (['is a gritty police thriller with all the dysfunctional family dynamics one could wish for '],
#   1),
#  (['eventually works its way up to merely bad rather than painfully awful . '],
#   0),
#  (["jiang wen 's devils on the doorstep is a wartime farce in the alternately comic and gut-wrenching style of joseph heller or kurt vonnegut . "],
#   1),
#  (['accompanied by the sketchiest of captions . '], 0),
#  (['to a woman whose passion for this region and its inhabitants still shines in her quiet blue eyes '],
#   1),
#  (['brave '], 1),
#  (['the rules of attraction gets us too drunk on the party favors to sober us up with the transparent attempts at moralizing . '],
#   0),
#  (['rarely have received such a sophisticated and unsentimental treatment on the big screen as they do in this marvelous film . '],
#   1),
#  (['( a ) satisfying niblet . '], 1),
#  (["silver bullets for director neil marshall 's intense freight "], 1),
#  (['each other so intensely , but with restraint '], 1),
#  (['the mark '], 1),
#  (["this ready-made midnight movie probably wo n't stand the cold light of day "],
#   0),
#  (['had a bad run in the market or a costly divorce , '], 0),
#  (['offensive and '], 0),
#  (['sing beautifully and act adequately '], 1),
#  (['blah '], 0),
#  (["ca n't disguise the fact that it 's inauthentic at its core and that its story just is n't worth telling "],
#   0),
#  (['300 years of russian history and culture '], 1),
#  (['paper-thin , and their personalities undergo radical changes when it suits the script '],
#   0),
#  (["in such a lousy way , complete with some of the year 's ( unintentionally ) funniest moments , that it 's impossible to care "],
#   0),
#  (['another shameless attempt '], 0),
#  (["`` being earnest '' overcome its weaknesses "], 1),
#  (['the master of disguise is awful . '], 0),
#  (['besides its terrific performances '], 1),
#  (["seemingly a vehicle to showcase the canadian 's inane ramblings , stealing harvard is a smorgasbord of soliloquies about nothing delivered by the former mr. drew barrymore . "],
#   0),
#  (['a delightful stimulus for the optic nerves '], 1),
#  (['teenage sex comedy '], 1),
#  (["one of recent memory 's most thoughtful films about art , ethics , and the cost of moral compromise . "],
#   1),
#  (['is something of a triumph '], 1),
#  (['is slow to those of us in middle age '], 0),
#  (['the mill sci-fi film with a flimsy ending and lots of hype '], 0),
#  (["is painfully foolish in trying to hold onto what 's left of his passe ' chopsocky glory . "],
#   0),
#  (['terrific date movie '], 1),
#  (['for once , a movie does not proclaim the truth about two love-struck somebodies , but permits them time and space to convince us of that all on their own . '],
#   1),
#  (['much more watchable '], 1),
#  (['backwater '], 1),
#  (["it 's a big idea , but the film itself is small and shriveled . "], 0),
#  (['most excruciating 86 minutes one '], 0),
#  (['dry wit and compassion '], 1),
#  (['spectacularly ugly-looking '], 0),
#  (["there 's always these rehashes to feed to the younger generations "], 0),
#  (['well-made but mush-hearted . '], 1),
#  (['good race '], 1),
#  (['a powerful and telling story '], 1),
#  (["broomfield 's style of journalism is hardly journalism at all , "], 0),
#  (['a documentary to make the stones weep -- as shameful as it is scary . '],
#   0),
#  (["olivier assayas ' elegantly appointed period drama seems , at times , padded with incident in the way of a too-conscientious adaptation "],
#   0),
#  (['does a film so graceless and devoid of merit as this one come along . '],
#   0),
#  (['memories of rollerball '], 1),
#  (['the queasy-stomached critic who staggered from the theater and blacked out in the lobby '],
#   0),
#  (["every moment crackles with tension , and by the end of the flick , you 're on the edge of your seat "],
#   1),
#  (['does a splendid job of racial profiling hollywood style -- casting excellent latin actors of all ages -- a trend long overdue '],
#   1),
#  (['flat as thinking man '], 0),
#  (['the right stuff for silly summer entertainment '], 1),
#  (['an inuit masterpiece that will give you goosebumps as its uncanny tale of love , communal discord , and justice unfolds . '],
#   1),
#  (['predictable and '], 0),
#  (["'ll enjoy this movie "], 1),
#  (['incapable of being boring '], 1),
#  (['live happily '], 1),
#  (['kids who are into this thornberry stuff will probably be in wedgie heaven . '],
#   1),
#  (['their consistently sensitive and often exciting treatment '], 1),
#  (["some of the characters die and others do n't , and the film pretends that those living have learned some sort of lesson "],
#   0),
#  (['fans will undoubtedly enjoy it , and '], 1),
#  (['move with grace and panache '], 1),
#  (['its beautiful women '], 1),
#  (['it other than its exploitive array of obligatory cheap '], 0),
#  (['snow white '], 1),
#  (["the best little `` horror '' movie i 've seen in years "], 1),
#  (['both sitcomishly predictable and cloying in its attempts '], 0),
#  (['rises '], 1),
#  (['comes out on video '], 1),
#  (['small , personal film '], 1),
#  (['a captivating coming-of-age story that may also be the first narrative film to be truly informed by the wireless '],
#   1),
#  (['the most unpleasant things the studio '], 0),
#  (['your interest , your imagination , your empathy '], 1),
#  (["has the uncanny ability to right itself precisely when you think it 's in danger of going wrong "],
#   1),
#  (["does n't leave you with much . "], 0),
#  (['is pretty damned funny '], 1),
#  (["the movie 's presentation , which is way too stagy "], 0),
#  (['integrating the characters in the foreground into the extraordinarily rich landscape '],
#   1),
#  (["it 's too loud to shout insults at the screen "], 0),
#  (['an engrossing portrait of uncompromising artists trying to create something original against the backdrop of a corporate music industry that only seems to care about the bottom line . '],
#   1),
#  (['a fascinating curiosity piece -- fascinating , that is , for about ten minutes . '],
#   0),
#  (['laughs '], 1),
#  (['cuba gooding jr. valiantly mugs his way through snow dogs , but even his boisterous energy fails to spark this leaden comedy '],
#   0),
#  (['happily '], 1),
#  (['erratic career '], 0),
#  (['in its lack of poetic frissons '], 0),
#  (['conjures up the intoxicating fumes and emotional ghosts of a freshly painted rembrandt '],
#   1),
#  (['those crass , contrived sequels '], 0),
#  (["pretend it 's a werewolf itself by avoiding eye contact and walking slowly away "],
#   0),
#  (['pulls off some deft ally mcbeal-style fantasy sequences '], 1),
#  (['be another shameless attempt by disney '], 0),
#  (['a mess '], 0),
#  (['nothing more than an amiable but unfocused bagatelle that plays like a loosely-connected string of acting-workshop exercises . '],
#   0),
# ...
#  (['monotonous '], 0),
#  (['the finest films '], 1),
#  (['the man '], 1),
#  (["carvey 's glory days "], 1),
#  (['gorgeous locales '], 1),
#  (['a film about female friendship that men can embrace and women will talk about for hours . '],
#   1),
#  (['rare drama that offers a thoughtful and rewarding glimpse into the sort of heartache everyone has felt , or will feel someday '],
#   1),
#  (['elaborate special effects take center screen , so that the human story is pushed to one side . '],
#   1),
#  (["you 'll love this movie . "], 1),
#  (['can you take before indigestion sets in '], 0),
#  (["'s at once laughable and compulsively watchable "], 1),
#  (["so that it certainly does n't feel like a film that strays past the two and a half mark "],
#   1),
#  (['an engrossing portrait of a man whose engaging manner and flamboyant style made him a truly larger-than-life character '],
#   1),
#  (['enough to sustain laughs '], 1),
#  (["proves a servicable world war ii drama that ca n't totally hide its contrivances "],
#   1),
#  (['retaining an integrity '], 1),
#  (['far less enjoyable '], 0),
#  (["by and large this is mr. kilmer 's movie , and it 's his strongest performance since the doors . "],
#   1),
#  (["is no denying the power of polanski 's film ... "], 1),
#  (['a bad movie '], 0),
#  (['you should see this movie '], 1),
#  (['quirky at moments '], 1),
#  (['to offend '], 0),
#  (["a leash -- far too polite to scale the lunatic heights of joe dante 's similarly styled gremlins "],
#   0),
#  (["it 's not much more watchable than a mexican soap opera "], 0),
#  (['digs into their very minds to find an unblinking , flawed humanity . '],
#   1),
#  (['refreshingly smart and newfangled '], 1),
#  (['downright transparent '], 0),
#  (['little action , almost no suspense or believable tension '], 0),
#  (['sweet gentle jesus '], 1),
#  (['driven by a fantastic dual performance from ian holm ... '], 1),
#  (['the hot topics of the plot are relegated to the background -- a welcome step forward from the sally jesse raphael atmosphere of films like philadelphia and american beauty . '],
#   1),
#  (["is better-focused than the incomprehensible anne rice novel it 's based upon "],
#   1),
#  (['could have yielded such a flat , plodding picture '], 0),
#  (['relieved that his latest feature , r xmas , marks a modest if encouraging return to form '],
#   1),
#  (['be one of those movies barely registering a blip on the radar screen of 2002 '],
#   0),
#  (['more outre aspects '], 1),
#  (['boring and meandering '], 0),
#  (['is impossible to find the film anything but appalling , shamelessly manipulative and contrived , and totally lacking in conviction '],
#   0),
#  (["his character 's abundant humanism makes him the film 's moral compass "],
#   1),
#  (['it is a whole lot of fun and '], 1),
#  (['a personal low for everyone '], 0),
#  (['hiding behind cutesy film references '], 0),
#  (['imagines '], 1),
#  (['defined '], 1),
#  (['eerily accurate depiction of depression . '], 0),
#  (['writings to perform '], 1),
#  (['is undoubtedly one of the finest films of the year '], 1),
#  (['quirky rip-off prison '], 0),
#  (['goofy , life-affirming moments '], 1),
#  (['not-so-funny gags '], 0),
#  (["ca n't help but get caught up in the thrill of the company 's astonishing growth "],
#   1),
#  (['perfect quiet pace '], 1),
#  (['a fun family movie '], 1),
#  (['female friendship , '], 1),
#  (['surprisingly decent flick '], 1),
#  (['with honesty that is tragically rare in the depiction of young women in film '],
#   1),
#  (['driven by a fantastic dual performance from ian holm ... the film is funny , insightfully human and a delightful lark for history buffs '],
#   1),
#  (['of the best films of the year '], 1),
#  (['understanding a unique culture that is presented with universal appeal '],
#   1),
#  (['hackneyed '], 0),
#  (['by a winning family story '], 1),
#  (["a cinematic disaster so inadvertently sidesplitting it 's worth the price of admission for the ridicule factor alone . "],
#   0),
#  (['joyous , turbulent self-discovery '], 1),
#  (['detailing '], 1),
#  (["'s quinn ( is ) a leather clad grunge-pirate with a hairdo like gandalf in a wind-tunnel and a simply astounding cor-blimey-luv-a-duck cockney accent . ' "],
#   1),
#  (['offers an exploration that is more accurate than anything i have seen in an american film '],
#   1),
#  (['makes it worth the trip to the theater '], 1),
#  (['the chops of a smart-aleck film school brat and the imagination of a big kid '],
#   1),
#  (['with the same sort of good-natured fun found in films like tremors '], 1),
#  (["'s a pleasure to have a film like the hours as an alternative . "], 1),
#  (['her material is not first-rate '], 0),
#  (['a lumbering , wheezy drag '], 0),
#  (['terrific casting and solid execution '], 1),
#  (["wait to see this terrific film with your kids -- if you do n't have kids borrow some "],
#   1),
#  (['a chilly , brooding but quietly '], 1),
#  (['well wrought '], 1),
#  (['that the highest power of all is the power of love '], 1),
#  (['off spookily enough '], 1),
#  (['of its characters , its protagonist , or of us '], 1),
#  (['been made by people to whom the idea of narrative logic or cohesion is an entirely foreign concept '],
#   0),
#  (['the sheer dumbness '], 0),
#  (['the comedy equivalent of saddam hussein '], 0),
#  (["plays like a powerful 1957 drama we 've somehow never seen before "], 1),
#  (['when all is said and done , she loves them to pieces '], 1),
#  (['literate material '], 1),
#  (['a sugar-coated rocky '], 0),
#  (['a work of deft and subtle poetry '], 1),
#  (['energy and excitement '], 1),
#  (['comedy ensemble '], 1),
#  (['to keep you at the edge of your seat with its shape-shifting perils , political intrigue and brushes with calamity '],
#   1),
#  (['a yawn-provoking little farm melodrama . '], 0),
#  (['include every top-notch british actor who did not appear in gosford park ( as well as one , ms. mirren , who did ) '],
#   1),
#  (['it should be done cinematically '], 1),
#  (['are uncomfortably strained . '], 0),
#  (['breathes life into a roll that could have otherwise been bland and run of the mill '],
#   1),
#  (['is every bit as fascinating '], 1),
#  (['a banal , virulently unpleasant excuse for a romantic comedy '], 0),
#  (["filmed the opera exactly as the libretto directs , ideally capturing the opera 's drama and lyricism "],
#   1),
#  (['is an enjoyable big movie primarily because australia is a weirdly beautiful place '],
#   1),
#  (['about hatred that offers no easy , comfortable resolution '], 0),
#  (['orchestrating a finale that is impenetrable and dull '], 0),
#  (['offers a glimpse of the solomonic decision facing jewish parents in those turbulent times : to save their children and yet to lose them . '],
#   1),
#  (['there are flaws , but also stretches of impact and moments of awe '], 1),
#  (["all things we 've seen before "], 0),
#  (['a florid biopic about mad queens , obsessive relationships , and rampant adultery '],
#   0),
#  (["'s a worthy entry in the french coming-of-age genre "], 1),
#  (['fascinate '], 1),
#  (['well-done supernatural thriller with keen insights into parapsychological phenomena and the soulful nuances '],
#   1),
#  (['his films so memorable '], 1),
#  (['a pointed , often tender , examination of the pros and cons of unconditional love and familial duties . '],
#   1),
#  (["bertrand tavernier 's oft-brilliant safe conduct ( `` laissez-passer '' ) wears its heart on its sleeve "],
#   1),
#  (['to be viewed and treasured for its extraordinary intelligence and originality as well as its lyrical variations on the game of love '],
#   1),
#  (['a stunningly unoriginal premise '], 0),
#  (['its unadorned view '], 0),
#  (['simple-minded '], 0),
#  (['nothing about this movie works . '], 0),
#  (['a mix of gritty realism , crisp storytelling and radiant compassion that effortlessly draws you in '],
#   1),
#  (['the poor acting '], 0),
#  (["it 's hard to stop watching "], 1),
#  (['the sword fighting is well done '], 1),
#  (['memories and one fantastic visual trope '], 1),
#  (["much like its easily dismissive take on the upscale lifestyle , there is n't much there here . "],
#   0),
#  (['the movie has no idea of it is serious '], 0),
#  (['every faltering half-step '], 0),
#  (["plummer steals the show without resorting to camp as nicholas ' wounded and wounding uncle ralph . "],
#   1),
#  (['lacks the spirit of the previous two , and '], 0),
#  (['is first-rate , especially sorvino '], 1),
#  (['funny scenes '], 1),
#  (['a work of outstanding originality '], 1),
#  (['4ever has the same sledgehammer appeal as pokemon videos , but '], 1),
#  (['really need a remake of `` charade '], 1),
#  (['the director is a magician '], 1),
#  (['a hallmark film '], 1),
#  (['the wonderful acting clinic put on by spader and gyllenhaal '], 1),
#  (["there 's never a dull moment in the giant spider invasion comic chiller "],
#   1),
#  (["which may be why it 's so successful at lodging itself in the brain "], 1),
#  (['recognizable and true '], 1),
#  (['the value and respect for the term epic cinema '], 1),
#  (['immensely ambitious , '], 1),
#  (["she lets her love depraved leads meet , ( denis ' ) story becomes a hopeless , unsatisfying muddle "],
#   0),
#  (['the problem with antwone fisher '], 1),
#  (['an often watchable , though goofy and lurid , blast of a costume drama set in the late 15th century . '],
#   1),
#  (['can certainly go the distance , '], 1),
#  (['a lousy one at that '], 0),
#  (['much funnier than anything '], 1),
#  (['is terrific , '], 1),
#  (['generic villains '], 0),
#  (['insult the intelligence of everyone '], 0),
#  (["coppola 's directorial debut is an incredibly layered and stylistic film that , despite a fairly slow paced , almost humdrum approach to character development , still manages at least a decent attempt at meaningful cinema . "],
#   1),
#  (['the performances are so overstated , the effect comes off as self-parody . '],
#   0),
#  (['i guarantee that no wise men will be following after it '], 0),
#  (['( hayek ) throws herself into this dream hispanic role with a teeth-clenching gusto , she strikes a potent chemistry with molina and she gradually makes us believe she is kahlo . '],
#   1),
#  (['at once visceral and spiritual , wonderfully vulgar and sublimely lofty -- and as emotionally grand '],
#   1),
#  (['the john wayne classics '], 1),
#  (['and crude storyline '], 0),
#  (["'s an interesting effort ( particularly for jfk conspiracy nuts ) "], 1),
#  (['a low-key , organic way '], 1),
#  (['greatly '], 1),
#  (['gentle , lapping rhythms '], 1),
#  (['the true impact '], 1),
#  (['find it diverting '], 0),
#  (['biggest names '], 1),
#  (['motivate '], 1),
#  (["i 'd take ( its ) earnest errors and hard-won rewards over the bombastic self-glorification of other feel-good fiascos like antwone fisher or the emperor 's club any time . "],
#   1),
#  (['no real sense '], 0),
#  (['bungle their way '], 0),
#  (['the scariest guy '], 0),
#  (['a single iota worse '], 0),
#  (['the bread , '], 1),
#  (['sure to give you a lot of laughs in this simple , sweet and romantic comedy '],
#   1),
#  (['is sentimental but feels free to offend , is analytical and then surrenders to the illogic of its characters , is about grief and yet permits laughter . '],
#   1),
#  (['falls flat '], 0),
#  (['an awful sour taste '], 0),
#  (['sexy , funny and touching . '], 1),
#  (['a lovely film for the holiday season . '], 1),
#  ([', it is twice as bestial but half as funny . '], 0),
#  (['77 minutes of pokemon may not last 4ever , it just seems like it does . '],
#   0),
#  (['sayles has a knack for casting , often resurrecting performers who rarely work in movies now ... and drawing flavorful performances from bland actors . '],
#   1),
#  (['narratively , trouble every day is a plodding mess . '], 0),
#  (['over every cheap trick in the book trying to make the outrage '], 0),
#  (["has a wooden delivery and encounters a substantial arc of change that does n't produce any real transformation . "],
#   0),
#  (['it seems impossible that an epic four-hour indian musical about a cricket game could be this good , but it is . '],
#   1),
#  (["be a film that is n't this painfully forced , false and fabricated "], 0),
#  ([', stupid and pointless '], 0),
#  (['little more than routine '], 0),
#  (['from the dull '], 0),
#  (['manages to find that real natural , even-flowing tone that few movies are able to accomplish '],
#   1),
#  (['nothing else happening '], 0),
#  (['not exaggerated enough to be a parody of gross-out flicks , college flicks , or even flicks in general . '],
#   0),
#  (['into such fresh territory '], 1),
#  (['best rock '], 1),
#  (['celebrates the hardy spirit of cuban music '], 1),
#  (["this too-long , spoofy update of shakespeare 's macbeth does n't sustain a high enough level of invention . "],
#   0),
#  (['what we get in feardotcom is more like something from a bad clive barker movie . '],
#   0),
#  (['feeling refreshed and hopeful '], 1),
#  (['been quashed by whatever obscenity is at hand '], 0),
#  (['cute alien creature '], 1),
#  (['opera-ish story '], 0),
#  (['the town has kind of an authentic feel , but each one of these people stand out and everybody else is in the background and it just seems manufactured to me and artificial . '],
#   0),
#  (['find it baffling '], 0),
#  (["a little uneven to be the cat 's meow , but it 's good enough to be the purr "],
#   1),
#  (['and narrative grace '], 1),
#  (["fabulously funny and over the top as a ` very sneaky ' butler who excels in the art of impossible disappearing/reappearing acts "],
#   1),
#  (['is reasonably entertaining , '], 1),
#  (["have seen before , but beneath the exotic surface ( and exotic dancing ) it 's surprisingly old-fashioned "],
#   1),
#  (['idol '], 1),
#  (['sufficiently '], 1),
#  (["it would n't exist without the precedent of yiddish theater , whose jolly , fun-for-fun 's - sake communal spirit goes to the essence of broadway "],
#   1),
#  (['recognize that there are few things in this world more complex -- and , as it turns out , more fragile '],
#   1),
#  (['the best straight-up '], 1),
#  (['victorious revolutionaries '], 1),
#  (['strong and convincing '], 1),
#  (["do well to check this one out because it 's straight up twin peaks action "],
#   1),
#  (['too many tried-and-true shenanigans '], 0),
#  (["if we 're to slap protagonist genevieve leplouff because she 's french , do we have that same option to slap her creators because they 're clueless and inept ? "],
#   0),
#  (["'s every bit as enlightening , insightful and entertaining as grant 's two best films "],
#   1),
#  (['been too many of these films '], 0),
#  (['and it is . '], 1),
#  (['a slight but sweet film '], 1),
#  (['aground after being snared in its own tangled plot '], 0),
#  (['and pasta-fagioli comedy '], 1),
#  (['an unendurable viewing experience '], 0),
#  (['is plenty of fun for all '], 1),
#  (['winds up mired in tear-drenched quicksand . '], 0),
#  (['an intimate feeling , a saga of the ups and downs of friendships '], 1),
#  (['an intelligent weepy '], 1),
#  (['where its recent predecessor miserably '], 0),
#  (["affirm love 's power to help people endure almost unimaginable horror "],
#   1),
#  (['thoroughly winning flight of revisionist fancy '], 1),
#  (['a serious contender '], 1),
#  (['a classic fairy tale that perfectly captures the wonders and worries of childhood '],
#   1),
#  (['oddly colorful '], 1),
#  (['laugh-out-loud lines '], 1),
#  (["its characters ' decisions only unsatisfactorily "], 0),
#  (['thoughtful and surprisingly affecting portrait '], 1),
#  (['ascends to a kinetic life so teeming that even cranky adults may rediscover the quivering kid inside '],
#   1),
#  (['disjointed '], 0),
#  (['if good-hearted '], 1),
#  (['humanly '], 1),
#  (['amuse or entertain them '], 1),
#  (['some writer dude , i think his name was , uh , michael zaidan , was supposed to have like written the screenplay or something , but , dude , the only thing that i ever saw that was written down were the zeroes on my paycheck . '],
#   0),
#  (['seems to elicit a chuckle '], 1),
#  (['timeless and unique perspective '], 1),
#  (['the places , and the people , '], 1),
#  (["the only entertainment you 'll derive from this choppy and sloppy affair will be from unintentional giggles -- several of them . "],
#   0),
#  ...]

# %%
# This is the test set, which is held out and never seen during training or demonstration sampling.
# After running the training or few-shot inference (e.g. via in-context learning),
# we evaluate the model's performance on this set.
splitted_sst2.test.get_dataset()
# Out:
# [(["despite juliet stevenon 's attempt to bring cohesion to pamela 's emotional roller coaster life "],
#   0),
#  (['the psychology 101 study of romantic obsession '], 1),
#  (['an entertaining mix of period drama and flat-out farce that should please history fans . '],
#   1),
#  (['intimate and panoramic . '], 1),
#  (['an overstylized , puréed mélange of sex , psychology , drugs and philosophy . '],
#   0),
#  (['there are some laughs in this movie , '], 1),
#  (['a moving tale '], 1),
#  (["it 's compelling "], 1),
#  (['triumphs '], 1),
#  (['despite its floating narrative '], 0),
#  (['8 crazy nights '], 1),
#  (['in a stunning fusion of music and images '], 1),
#  (['slow for a younger crowd '], 0),
#  (['marvelously twisted shapes history '], 1),
#  (['a strong dramatic and emotional pull '], 1),
#  (['to the perkiness of witherspoon ( who is always a joy to watch , even when her material is not first-rate ) '],
#   1),
#  (['is a great yarn '], 1),
#  (['behind cutesy film references '], 1),
#  (['byler is too savvy a filmmaker to let this morph into a typical romantic triangle . '],
#   1),
#  (['old-fashioned in all the best possible ways '], 1),
#  (["bryan adams , the world 's most generic rock star "], 1),
#  (["there 's no discernible feeling beneath the chest hair "], 0),
#  (['moderately successful but '], 1),
#  (["originality in ` life ' "], 1),
#  (["well , it probably wo n't have you swinging from the trees hooting it 's praises , "],
#   0),
#  (['a dark , gritty , sometimes funny little gem '], 1),
#  (["is that rare animal known as ' a perfect family film , ' because it 's about family "],
#   1),
#  (["turning leys ' fable into a listless climb down the social ladder "], 0),
#  (['that should please history fans '], 1),
#  (['my least favorite emotions , especially when i have to put up with 146 minutes of it '],
#   0),
#  (['a smart '], 1),
#  (["this a moving experience for people who have n't read the book "], 1),
#  (['in his role of observer of the scene , lawrence sounds whiny and defensive , as if his life-altering experiences made him bitter and less mature . '],
#   0),
#  (["that bears more than a whiff of exploitation , despite iwai 's vaunted empathy "],
#   0),
#  (['good chance '], 1),
#  (['a bit melodramatic and even a little dated '], 0),
#  (['sheer beauty '], 1),
#  (['stale plot and pornographic way '], 0),
#  (['too clever '], 1),
#  (['easy to love robin tunney '], 1),
#  (['of bad writing , bad direction and bad acting -- the trifecta of badness '],
#   0),
#  ([', this one is a sweet and modest and ultimately winning story . '], 1),
#  (['best movie work '], 1),
#  (['her petite frame and vulnerable persona emphasising her plight and isolation '],
#   1),
#  (['murphy and owen wilson '], 0),
#  (['a uniquely sensual metaphorical dramatization of sexual obsession '], 1),
#  (['good action , good acting , good dialogue , good pace '], 1),
#  (['informative , intriguing , observant , often touching ... '], 1),
#  (['told and retold '], 0),
#  (["if you 're going to subjugate truth to the tear-jerking demands of soap opera "],
#   0),
#  (['sensuality and a conniving wit '], 1),
#  (['nerds '], 1),
#  (['the movie is busy contriving false , sitcom-worthy solutions to their problems . '],
#   0),
#  (['that the movie has virtually nothing to show '], 0),
#  (['the third revenge of the nerds sequel '], 0),
#  (['to please audiences who like movies that demand four hankies '], 1),
#  (['real americans '], 1),
#  (['assurance worthy '], 1),
#  (['that watching it leaves you giddy '], 1),
#  (['has the scope and shape of an especially well-executed television movie '],
#   1),
#  (['essentially a collection of bits -- '], 0),
#  (["( clooney 's ) debut can be accused of being a bit undisciplined , but "],
#   0),
#  ([', shrek ) '], 1),
#  (['of a triumph '], 1),
#  (["is a general air of exuberance in all about the benjamins that 's hard to resist . "],
#   1),
#  (['sharp and '], 1),
#  (['rate as the most magical and most fun family fare of this or any recent holiday season '],
#   1),
#  (['gross-out college comedy '], 0),
#  (['the scariest movie '], 1),
#  (['warm the hearts of animation enthusiasts of all ages '], 1),
#  (['delicious , quirky movie '], 1),
#  (["assembles a fascinating profile of a deeply humanistic artist who , in spite of all that he 's witnessed , remains surprisingly idealistic , "],
#   1),
#  (['something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense '],
#   1),
#  (['most refreshing about real women have curves '], 1),
#  (['gem '], 1),
#  (['to narrative filmmaking with a visually masterful work of quiet power '],
#   1),
#  (['sometimes charming , sometimes infuriating '], 1),
#  (['plain lurid '], 0),
#  (['movie fun '], 1),
#  (['the action here is unusually tame , the characters are too simplistic to maintain interest , and the plot offers few surprises . '],
#   0),
#  (['waters '], 0),
#  (['seriously bad '], 0),
#  (['stylish and moody '], 1),
#  (['in a standard plot '], 0),
#  (["is actually a compelling look at a young woman 's tragic odyssey . "], 1),
#  (['has never made a more sheerly beautiful film than this unexpectedly moving meditation on love , history , memory , resistance and artistic transcendence . '],
#   1),
#  (['as nudity , profanity and violence '], 0),
#  (['stale copy '], 0),
#  (["a surprisingly charming and even witty match for the best of hollywood 's comic-book "],
#   1),
#  (['choosing his roles with the precision of the insurance actuary '], 1),
#  (['an adorably whimsical comedy '], 1),
#  (["resembles an outline for a '70s exploitation picture "], 0),
#  (['powerful direction '], 1),
#  (['a cast of competent performers from movies , television and the theater '],
#   1),
#  (['good news '], 1),
#  (['we all lose track of ourselves by trying '], 1),
#  (['penned by a man who has little clue about either the nature of women or of friendship . '],
#   0),
#  (['have a résumé loaded with credits like `` girl in bar # 3 '], 0),
#  (['yakusho , as always , is wonderful as the long-faced sad sack ... '], 1),
#  (['this beautifully animated epic is never dull . '], 1),
#  (['most original fantasy film '], 1),
#  (['roussillon providing comic relief '], 1),
#  (["williams ' anarchy gets tiresome "], 0),
#  (['miracles , '], 1),
#  (['the hot chick is pretty damned funny . '], 1),
#  (['between the fantastic and the believable '], 1),
#  (['its otherwise comic narrative '], 1),
#  (['that its visual imagination is breathtaking '], 1),
#  (["ca n't begin to tell you how tedious , how resolutely unamusing , how thoroughly unrewarding all of this is , and what a reckless squandering of four fine acting talents "],
#   0),
#  (['that verges on the amateurish '], 0),
#  (['fun of me '], 1),
#  (['surprisingly shoddy '], 0),
#  (['of the really bad blair witch project '], 0),
#  (['comprehend it '], 1),
#  (['obnoxious special effects '], 0),
#  (["anyone with a passion for cinema , and indeed sex , should see it as soon as possible . ' "],
#   1),
#  (['ascends to a kinetic life so teeming that even cranky adults may rediscover the quivering kid inside . '],
#   1),
#  (['the action scenes are poorly delivered '], 0),
#  (['to make a classic theater piece '], 1),
#  (['old garbage '], 0),
#  (['a throwback war movie '], 1),
#  (['are uncomfortably strained '], 0),
#  (['it unexpectedly rewarding '], 1),
#  (['characters are both overplayed and exaggerated '], 0),
#  (['is japanese and yet feels universal '], 1),
#  (['woo '], 1),
#  (['powerhouse '], 1),
#  (['a predictable , manipulative stinker '], 0),
#  (['turbulent self-discovery '], 1),
#  (['are especially fine '], 1),
#  (['obnoxious adults '], 0),
#  (['( but none of the sheer lust ) '], 0),
#  (["is a movie where the most notable observation is how long you 've been sitting still "],
#   0),
#  (['fresh good looks and '], 1),
#  (['a real film '], 1),
#  (['young talent '], 1),
#  (['that most frightening of all movies -- '], 1),
#  (['feel alive - '], 1),
#  (['fart '], 0),
#  (['imaginative and successful '], 1),
#  (['realistic , urgent '], 1),
#  (['rusted-out '], 0),
#  (['whiny and defensive '], 0),
#  (['uncommonly moving '], 1),
#  (['this trite , predictable rehash '], 0),
#  (['balanced or fair '], 1),
#  (['pretends to be passionate and truthful but is really frustratingly timid and soggy '],
#   0),
#  (['flourishes and '], 1),
#  (['an absolute delight for all audiences '], 1),
#  (['the chaos of an urban conflagration '], 0),
#  (['an extremely unpleasant film '], 0),
#  (['grant is certainly amusing '], 1),
#  (["if a horror movie 's primary goal is to frighten and disturb , then they works spectacularly well ... a shiver-inducing , nerve-rattling ride . "],
#   1),
#  (['is in many ways a conventional , even predictable remake '], 0),
#  (['a solid base '], 1),
#  (['ever see one of those comedies that just seem like a bad idea from frame one ? '],
#   0),
#  (['soulless and -- even more damning -- virtually joyless , '], 0),
#  (['pretty '], 1),
#  (['forget about it '], 0),
#  (['of any film more challenging or depressing '], 0),
#  (['the gorgeous piano and strings on the soundtrack '], 1),
#  (['what allows it to rank with its worthy predecessors '], 1),
#  (['a fascinating case study of flower-power liberation -- '], 1),
#  (['sexy and romantic . '], 1),
#  (['funny , sexy , devastating and incurably romantic . '], 1),
#  (["'s supposed to be post-feminist breezy but "], 0),
#  (['a compassionate , moving portrait of an american ( and an america ) always reaching for something just outside his grasp '],
#   1),
#  (['complaint '], 0),
#  (['a gentle and engrossing character '], 1),
#  (["had just typed ` chris rock , ' ` anthony hopkins ' and ` terrorists ' into some univac-like script machine "],
#   0),
#  (['come from seeing former nymphette juliette lewis playing a salt-of-the-earth mommy named minnie and watching slim travel incognito in a ridiculous wig no respectable halloween costume shop would ever try to sell '],
#   0),
#  (['leave it '], 0),
#  (['too convenient '], 0),
#  (['frequently pandering to fans of the gross-out comedy '], 0),
#  (['is a movie you can trust . '], 1),
#  (["is n't it a bit early in his career for director barry sonnenfeld to do a homage to himself ? "],
#   0),
#  (['should be served an eviction notice at every theater stuck with it . '],
#   0),
#  (['distasteful '], 0),
#  (['86 minutes too long '], 0),
#  (['loud , violent and mindless '], 0),
#  (["one of demme 's good films "], 1),
#  (['not quite as miraculous as its dreamworks makers '], 0),
#  (['laugh-out-loud '], 1),
#  (['having fun with it all '], 1),
#  (['worthless '], 0),
#  (['fine job '], 1),
#  (['there is simply no doubt that this film asks the right questions at the right time in the history of our country . '],
#   1),
#  (["it 's not particularly well made , but since i found myself howling more than cringing , i 'd say the film works . "],
#   1),
#  (['by a sloppy script '], 0),
#  (['running off '], 0),
#  (['visually ugly '], 0),
#  (['professional '], 1),
#  (['a high-end john hughes comedy , '], 1),
#  (["the power-lunchers do n't care to understand "], 0),
#  (['incompetent '], 0),
#  (['a calm , self-assured portrait '], 1),
#  (['usual whoopee-cushion effort '], 0),
#  (['give a taste of the burning man ethos , an appealing blend of counter-cultural idealism and hedonistic creativity '],
#   1),
#  (['everything about the quiet american is good , except its timing . '], 1),
#  (['nevertheless , it still seems endless . '], 0),
#  (['the charm of the first movie is still there , '], 1),
#  (['a retread story , bad writing , and the same old silliness '], 0),
#  (['tears welled up in my eyes both times '], 1),
#  (['somewhat defuses this provocative theme by submerging it in a hoary love triangle . '],
#   0),
#  (["that burn themselves upon the viewer 's memory "], 1),
#  (['the viewer wide-awake all the way through '], 1),
#  (["ca n't remember the last time i saw worse stunt editing or cheaper action movie production values than in extreme ops . "],
#   0),
#  (['emphasizes the well-wrought story and omits needless chase scenes and swordfights as the revenge unfolds . '],
#   1),
#  (['so many red herrings , so many false scares , '], 0),
#  (["it 's bright , pristine style and bold colors make it as much fun as reading an oversized picture book before bedtime . "],
#   1),
#  (['oddballs '], 0),
#  (['what a great way to spend 4 units of your day . '], 1),
#  (['mr. day-lewis roars with leonine power '], 1),
#  (['of mindless pace in collision '], 0),
#  (['to be that rarity among sequels '], 1),
#  (['another disjointed '], 0),
#  (['a satisfying complete picture of this particular , anciently demanding métier '],
#   1),
#  (['a giant step backward for a director i admire '], 0),
#  (["that 's fun for kids of any age . "], 1),
#  (['keeping themselves kicking '], 1),
#  (['casts attractive and talented actors '], 1),
#  (['speak for it while it forces you to ponder anew what a movie can be . '],
#   1),
#  (['for leonard '], 1),
#  (['failing , '], 0),
#  (['scummy ripoff '], 0),
#  (['will likely prefer to keep on watching '], 1),
#  (['as exciting to watch as two last-place basketball '], 0),
#  (['the pseudo-educational stuff '], 0),
#  (["it 's propelled by the acting "], 1),
#  (['vapid '], 0),
#  (['this wild welsh whimsy '], 1),
#  (["jaglom 's self-conscious and gratingly irritating films "], 0),
#  (['that is revelatory '], 1),
#  (['whatever '], 0),
#  (['worthwhile glimpse '], 1),
#  (['create and sustain '], 1),
#  (["a genial romance that maintains a surprisingly buoyant tone throughout , notwithstanding some of the writers ' sporadic dips into pop freudianism "],
#   1),
#  (['one of those unassuming films that sneaks up on you and stays with you long after you have left the theater '],
#   1),
#  (['begins as a conventional thriller evolves into a gorgeously atmospheric meditation on life-changing chance encounters . '],
#   1),
#  (['that you get when sitting around a campfire around midnight , telling creepy stories to give each other the willies '],
#   1),
#  (["their often heartbreaking testimony , spoken directly into director patricio guzman 's camera "],
#   1),
#  (['moving and '], 1),
#  (['distinctly sub-par ... '], 0),
#  (['i liked the movie , but i know i would have liked it more if it had just gone that one step further '],
#   1),
#  (['might i suggest that the wayward wooden one end it all by stuffing himself into an electric pencil sharpener '],
#   0),
#  (['a fresh and absorbing look '], 1),
#  (['like it was worth your seven bucks '], 1),
#  (['the suggested and the unknown '], 0),
#  (['this world more complex '], 1),
#  (['are such a companionable couple '], 1),
#  (['that are jarring and deeply out of place in what could have ( and probably should have ) been a lighthearted comedy '],
#   0),
#  (['most good-hearted yet sensual entertainment '], 1),
#  (['the filmmakers could dredge up '], 0),
#  (["'s a fun one . "], 1),
#  (['falling short as a whole '], 0),
#  (['fantasy pablum '], 0),
#  (['more plot '], 1),
#  (['had the balance shifted in favor of water-bound action over the land-based ` drama '],
#   0),
#  (['capable cast '], 1),
#  ([", she 's appealingly manic and energetic . "], 1),
#  (['lax and limp '], 0),
#  (['very lively dream '], 1),
#  (["'ll feel as the credits roll "], 1),
#  (['extra little something '], 1),
#  (['love , longing '], 1),
#  (['the grey zone attempts to be grandiloquent , but ends up merely pretentious -- in a grisly sort of way . '],
#   0),
#  (['dumbed-down tactics '], 0),
#  (['adam watstein with finishing it at all '], 1),
#  (['of piffle '], 0),
#  (["be placed in the pantheon of the best of the swashbucklers but it is a whole lot of fun and you get to see the one of the world 's best actors , daniel auteuil , "],
#   1),
#  ([', it offers much to absorb and even more to think about after the final frame . '],
#   1),
#  (["'s just tediously bad , "], 0),
#  (['banal and '], 0),
#  (['a whale of a good time for both children and parents seeking christian-themed fun '],
#   1),
#  (["does n't have a passion for the material . "], 0),
#  (["'' is a fun and funky look into an artificial creation in a world that thrives on artificiality . "],
#   1),
#  (['can impart an almost visceral sense of dislocation and change . '], 1),
#  (['damned funny '], 1),
#  (['innocent '], 1),
#  (['great sympathy and intelligence '], 1),
#  (['its characterization of hitler and the contrived nature of its provocative conclusion '],
#   1),
#  (['bits funnier '], 1),
#  (['medicine '], 1),
#  (['enough flourishes and freak-outs to make it entertaining '], 1),
#  (["bad the film 's story does not live up to its style "], 0),
#  (['not a good movie '], 0),
#  (['a century and a half ago '], 1),
#  ([', this retooled machine is ultimately effective enough at achieving the modest , crowd-pleasing goals it sets for itself . '],
#   1),
#  (["it 's too much syrup and not enough fizz "], 0),
#  (['have done in half an hour '], 0),
#  (["about the best thing you could say about narc is that it 's a rock-solid little genre picture . "],
#   1),
#  (["though this rude and crude film does deliver a few gut-busting laughs , its digs at modern society are all things we 've seen before . "],
#   0),
#  ([', pasty lumpen '], 0),
#  (['written and directed with brutal honesty and respect for its audience . '],
#   1),
#  (["it squanders chan 's uniqueness "], 0),
#  (["have seen before , but beneath the exotic surface ( and exotic dancing ) it 's surprisingly old-fashioned "],
#   1),
#  (["into an argentine retread of `` iris '' or `` american beauty "], 0),
#  (['an expert thriller '], 1),
#  (['always entertaining , and '], 1),
#  (['an astonishingly witless script '], 0),
#  (["you know it 's going to be a trip "], 1),
#  (['the worst kind of hubristic folly '], 0),
#  (['witty expose '], 1),
#  (['remind one of a really solid woody allen film , with its excellent use of new york locales and sharp writing '],
#   1),
#  (['created a masterful work of art of their own '], 1),
#  (['this film can only point the way -- but thank goodness for this signpost . '],
#   1),
#  (['this dog of a movie '], 0),
#  (['make this surprisingly decent flick worth a summertime look-see '], 1),
#  ([', good action , good acting , good dialogue , good pace , good cinematography . '],
#   1),
#  (['presents a frightening and compelling ` what if '], 1),
#  (['holm does his sly , intricate magic , '], 1),
#  (["here relies less on forced air than on petter næss ' delicate , clever direction ... and a wonderful , imaginative script by axel hellstenius . "],
#   1),
#  (['dead-undead genre '], 0),
#  (['the last kiss will probably never achieve the popularity of my big fat greek wedding '],
#   0),
#  (['engrossing and grim '], 1),
#  (['the best disney movie '], 1),
#  (['plotting '], 1),
#  (['the chills '], 0),
#  (['visible enthusiasm '], 1),
#  (['is suitably elegant '], 1),
#  (['horrid little propaganda film with fascinating connections not only to the serbs themselves but also to a network of american right-wing extremists . '],
#   1),
#  (['moving and weighty depiction '], 1),
#  (['but a great one '], 1),
#  (['deserves to be seen everywhere '], 1),
#  (['by characters so unsympathetic '], 0),
#  (['our reality tv obsession , '], 0),
#  (["although god is great addresses interesting matters of identity and heritage , it 's hard to shake the feeling that it was intended to be a different kind of film . "],
#   0),
#  (["you were n't invited to the party "], 0),
#  (['to seduce and conquer '], 1),
#  (["of his way to turn the legendary wit 's classic mistaken identity farce into brutally labored and unfunny hokum "],
#   0),
#  (['hopelessly out '], 0),
#  (['the heedless impetuousness of youth is on full , irritating display in ( this ) meandering and pointless french coming-of-age import from writer-director anne-sophie birot . '],
#   0),
#  (['difficult to imagine that a more confused , less interesting and more sloppily made film could possibly come down the road in 2002 '],
#   0),
#  (['one fantastic ( and educational ) documentary . '], 1),
#  (['poignant and wryly amusing '], 1),
#  (['is a very good viewing alternative for young women . '], 1),
#  (['by exceptional performances '], 1),
#  (['there , done that '], 1),
#  (['the ways in which extravagant chance can distort our perspective and throw us off the path of good sense '],
#   0),
#  (['as well-written as sexy beast , not as gloriously flippant as lock , stock and two smoking barrels , but stylish and moody and '],
#   1),
#  (['... irritating soul-searching garbage . '], 0),
#  (['feature to hit theaters since beauty and the beast 11 years ago . '], 1),
#  (['undistinguished rhythm '], 0),
#  (['becomes a fascinating study of isolation and frustration that successfully recreates both the physical setting and emotional tensions of the papin sisters '],
#   1),
#  (['loneliness and isolation '], 0),
#  (['film festival '], 1),
#  (['of those underrated professionals who deserve but rarely receive it '], 1),
#  (['consistently sensitive and often exciting treatment '], 1),
#  (['insult '], 0),
#  (['existential exploration '], 1),
#  (['offensive , puerile and '], 0),
#  (['an american '], 1),
#  (["on the whole , you 're gon na like this movie . "], 1),
#  ([', it misses a major opportunity to be truly revelatory about his psyche . '],
#   0),
#  (['ditched the artsy pretensions '], 1),
#  (['big fat pain . '], 0),
#  (['writing and slack direction '], 0),
#  (['winning shot '], 1),
#  (['mysterious '], 1),
#  (["sure , it 's contrived and predictable , but its performances are so well tuned that the film comes off winningly , even though it 's never as solid as you want it to be . "],
#   1),
#  (['gives the film its lingering tug '], 1),
#  (["a bored cage spent the duration of the film 's shooting schedule waiting to scream : `` got aids yet "],
#   0),
#  (['could make a person who has lived her life half-asleep suddenly wake up and take notice '],
#   1),
#  ([', but fun . '], 1),
#  (['airs just about every cliche in the war movie compendium across its indulgent two-hour-and-fifteen-minute length . '],
#   0),
#  (['lots of obvious political insights '], 1),
#  (['shame '], 0),
#  (['expands the horizons of boredom to the point of collapse , turning into a black hole of dullness , from which no interesting concept can escape '],
#   0),
#  (['see over and over again '], 1),
#  (['intelligent and moving '], 1),
#  (['that it can only encourage us to see samira makhmalbaf as a very distinctive sensibility , working to develop her own film language with conspicuous success '],
#   1),
#  (['curious to note that this film , like the similarly ill-timed antitrust , is easily as bad at a fraction the budget '],
#   0),
#  (['shoots and scores '], 1),
#  (['of dumbed-down exercise in stereotypes that gives the ( teen comedy ) '],
#   0),
#  (['cliched dialogue and perverse escapism a source of high hilarity '], 0),
#  (['jersey lowbrow accent uma '], 0),
#  (['less concerned with cultural and political issues than doting on its eccentric characters '],
#   0),
#  (['best actor '], 1),
#  (["it does n't work . "], 0),
#  (['about this love story '], 1),
#  ([', then you will probably have a reasonably good time with the salton sea . '],
#   1),
#  (['fuse at least three dull plots '], 0),
#  (["would n't make trouble every day any better "], 0),
#  (["by avary 's failure to construct a story with even a trace of dramatic interest "],
#   0),
#  (['is paper-thin and decidedly unoriginal '], 0),
#  (['a pitch-perfect holden '], 1),
#  (['the light of the exit sign '], 0),
#  (['dumb fart '], 0),
#  (["by numbers , and as easy to be bored by as your abc 's , "], 0),
#  (['a distinctly mixed bag , the occasional bursts of sharp writing alternating with lots of sloppiness and the obligatory moments of sentimental ooze . '],
#   0),
#  (['is not enough to give the film the substance it so desperately needs . '],
#   0),
#  (['were insulted '], 1),
#  (['slog '], 0),
#  (["some kid who ca n't act , only echoes of jordan , and weirdo actor crispin glover screwing things up old school "],
#   0),
#  (['that effortlessly draws you in '], 1),
#  (['people are innocent , childlike and inherently funny '], 1),
#  ([', treasure planet is truly gorgeous to behold . '], 1),
#  (['though it goes further than both , anyone who has seen the hunger or cat people will find little new here , '],
#   0),
#  (['crafted a solid formula for successful animated movies '], 1),
#  (['transparently hypocritical work '], 0),
#  (["the movie 's seams may show "], 0),
#  (['courageous scottish lady '], 1),
#  (['pleased '], 1),
#  (['by generic scripts that seek to remake sleepless in seattle again and again '],
#   0),
#  (["ca n't properly be called acting -- more accurately , it 's moving "], 0),
#  (['frustrated '], 0),
#  (['anyone who welcomes a dash of the avant-garde fused with their humor should take pleasure in this crazed '],
#   1),
#  (['spectacular '], 1),
#  (['brought to life on the big screen '], 1),
#  (['thinks-it-is joke '], 0),
#  (['if the film has a problem , its shortness disappoints : '], 0),
#  (['through recklessness and retaliation '], 0),
#  (["it 's the filmmakers ' post-camp comprehension of what made old-time b movies good-bad that makes eight legged freaks a perfectly entertaining summer diversion . "],
#   1),
#  (['there was ever a movie where the upbeat ending feels like a copout '], 0),
#  (['is hard to care '], 0),
#  (['the effort is sincere and '], 1),
#  (['that not only blockbusters pollute the summer movie pool '], 0),
#  (['lame and '], 0),
#  (['a kiss '], 1),
#  (['wittier '], 1),
#  (['the film is a very good viewing alternative for young women . '], 1),
#  (['may have made a great saturday night live sketch , but a great movie it is not . '],
#   0),
#  (['a young woman who knows how to hold the screen '], 1),
#  (['yields surprises '], 1),
#  (['to give you brain strain '], 0),
#  (['sobering cautionary tale '], 1),
#  (['the filmmakers want nothing else than to show us a good time '], 1),
#  ([', tedious '], 0),
#  (['some intriguing characters '], 1),
#  (['are becoming irritating '], 0),
#  (['tom tykwer , director of the resonant and sense-spinning run lola run '],
#   1),
#  (['in amazement over the fact '], 1),
#  (["it follows the blair witch formula for an hour , in which we 're told something creepy and vague is in the works , and then it goes awry in the final 30 minutes "],
#   0),
#  (["'s all bluster -- in the end it 's as sweet as greenfingers "], 1),
#  (["an astounding performance that deftly , gradually reveals a real human soul buried beneath a spellbinding serpent 's smirk . "],
#   1),
#  (['well-done film '], 1),
#  (['each one of these people stand out and '], 1),
#  (['reveals how important our special talents can be when put in service of of others '],
#   1),
#  (['that the idea of exploiting molestation for laughs is funny , not actually exploiting it yourself '],
#   0),
#  (['to be embraced '], 1),
#  (['as subtle and as enigmatic '], 1),
#  (["the director 's "], 1),
#  (['bland to be interesting '], 0),
#  (['skip this turd '], 0),
#  (['mckay shows crushingly little curiosity about , or is ill-equipped to examine , the interior lives of the characters in his film , much less incorporate them into his narrative . '],
#   0),
#  (['is familiar but enjoyable '], 1),
#  (['secretary takes the most unexpected material and handles it in the most unexpected way . '],
#   1),
#  (["of ` let 's get this thing over with "], 0),
#  (['a bad improvisation exercise , the superficially written characters ramble on tediously about their lives , loves and the art '],
#   0),
#  (['in too many conflicts '], 0),
#  (["'s something of the ultimate scorsese film , with all the stomach-turning violence , colorful new york gang lore and other hallmarks of his personal cinema painted on their largest-ever historical canvas . "],
#   1),
#  (['pack some serious suspense '], 1),
#  (['that the highest power of all is the power of love '], 1),
#  (["written , flatly , by david kendall and directed , barely , by there 's something about mary co-writer ed decter . "],
#   0),
#  (['off-puttingly cold '], 0),
#  (["what should have been a cutting hollywood satire is instead about as fresh as last week 's issue of variety . "],
#   0),
#  (['a distinctly minor effort '], 0),
#  (['spielberg flair '], 1),
#  (['enormous '], 1),
#  (['deeper and more engaging '], 1),
#  (['is masterful . '], 1),
#  (['the movie , shot on digital videotape rather than film '], 0),
#  (['it looks good , sonny , but you missed the point '], 0),
#  (["ride for the kiddies , with enough eye candy and cheeky wit to keep parents away from the concession stand . ' "],
#   1),
#  (['brisk hack job '], 0),
#  (['plot , characters , '], 1),
#  (['of their first full flush of testosterone '], 0),
#  (['an important , original talent in international cinema '], 1),
#  (['one of the best silly horror movies of recent memory '], 1),
#  (['determination to inject farcical raunch '], 0),
#  (["it 's just hard to believe that a life like this can sound so dull . "],
#   0),
#  (["'s a familiar story , but one that is presented with great sympathy and intelligence "],
#   1),
#  (['you can only love the players it brings to the fore for the gifted but no-nonsense human beings they are and for the still-inestimable contribution they have made to our shared history . '],
#   1),
#  (['this film is an act of spiritual faith -- an eloquent , deeply felt meditation on the nature of compassion . '],
#   1),
#  (["authentic account of a historical event that 's far too tragic to merit such superficial treatment "],
#   0),
#  (['chilling in its objective portrait of dreary , lost twenty-first century america . '],
#   1),
#  (['photographed and beautifully recorded '], 1),
#  (['foolish and shallow '], 0),
#  (['the immediate aftermath of the terrorist attacks '], 0),
#  (['chen films the resolutely downbeat smokers only with every indulgent , indie trick in the book . '],
#   0),
#  (["the modern remake of dumas 's story is long on narrative and ( too ) short on action . "],
#   0),
#  (['it would be nice to see what he could make with a decent budget '], 1),
#  (['left on a remote shelf '], 0),
#  (['of the impossibly long limbs and sweetly conspiratorial smile '], 1),
#  (['mostly believable , refreshingly low-key and quietly inspirational '], 1),
#  (['an impressive style '], 1),
#  ([", it 's a very very strong `` b + . '' "], 1),
#  (['chuckle '], 1),
#  (['the abiding impression , despite the mild hallucinogenic buzz , is of overwhelming waste -- '],
#   0),
#  (['merely very bad '], 0),
#  (['lousy script '], 0),
#  (['herzog simply runs out of ideas and '], 0),
#  (['indicative of how uncompelling the movie is unless it happens to cover your particular area of interest '],
#   0),
#  (['from new zealand whose boozy , languid air is balanced by a rich visual clarity and deeply '],
#   1),
#  (['is a mormon family movie , and a sappy , preachy one at that '], 0),
#  (['dumped '], 0),
#  (['as cleverly plotted as the usual suspects '], 1),
#  (['problematic characters '], 0),
#  (["be as subtle and touching as the son 's room "], 1),
#  (["sure which will take longer to heal : the welt on johnny knoxville 's stomach from a riot-control projectile or my own tortured psyche "],
#   0),
#  (["you 've got to admire ... the intensity with which he 's willing to express his convictions "],
#   1),
#  (['the era of the intelligent , well-made b movie is long gone '], 0),
#  (['becomes instead a grating endurance test '], 0),
#  (['there are some laughs in this movie '], 1),
#  (['a well-crafted film that is all the more remarkable because it achieves its emotional power and moments of revelation with restraint and a delicate ambiguity . '],
#   1),
#  (['the action clichés just pile up . '], 0),
#  (['compellingly '], 1),
#  (['acting that could be any flatter '], 0),
#  ([', another gross-out college comedy -- ugh . '], 0),
#  (["lee 's achievement extends to his supple understanding of the role that brown played in american culture as an athlete , a movie star , and an image of black indomitability . "],
#   1),
#  (['the theme with added depth and resonance '], 1),
#  (['the procession '], 1),
#  (['at heart is a sweet little girl '], 1),
#  (['clumsy '], 0),
#  (['research library dust '], 0),
#  (["writer-director david jacobson and his star , jeremy renner , have made a remarkable film that explores the monster 's psychology not in order to excuse him but rather to demonstrate that his pathology evolved from human impulses that grew hideously twisted . "],
#   1),
#  (['a wonderful tale '], 1),
#  (['i have always appreciated a smartly written motion picture , and '], 1),
#  (['it has fun with the quirks of family life , but '], 1),
#  (['rampant adultery '], 0),
#  (['made a point or two regarding life '], 1),
#  ([', it rises in its courageousness , and comedic employment . '], 1),
#  (['-- and far less crass '], 1),
#  (["if you liked the previous movies in the series , you 'll have a good time with this one too "],
#   1),
#  (['still rapturous after all these years '], 1),
#  (['a side of contemporary chinese life that many outsiders will be surprised to know exists , and does so with an artistry that also smacks of revelation . '],
#   1),
#  (['film buzz and whir '], 1),
#  (['meandering , norton has to recite bland police procedural details , fiennes wanders around in an attempt to seem weird and distanced , hopkins looks like a drag queen '],
#   0),
#  (['a total rehash '], 0),
#  (['as a conventional thriller evolves into a gorgeously atmospheric meditation on life-changing chance encounters '],
#   1),
#  (['of romantic obsession '], 1),
#  (["the film 's lack of personality permeates all its aspects -- from the tv movie-esque , affected child acting to the dullest irish pub scenes ever filmed . "],
#   0),
#  (['clever and unflinching in its comic barbs '], 1),
#  (['gorgeous visuals '], 1),
#  ([', interestingly told film . '], 1),
#  (['the laborious pacing and '], 0),
#  (['it is handled with intelligence and care '], 1),
#  (['winds up being both revelatory and narcissistic , achieving some honest insight into relationships that most high-concept films candy-coat with pat storylines , precious circumstances and beautiful stars . '],
#   1),
#  (['found it slow , predictable and not very amusing . '], 0),
#  (["it 's a setup so easy it borders on facile , but "], 0),
#  (['his life drew to a close '], 0),
#  (['can usually be traced back to the little things '], 1),
#  (['well shot '], 1),
#  (['is a thoughtful examination of faith , love and power . '], 1),
#  (['the movie is all portent and no content '], 0),
#  (['have a tendency to slip into hokum '], 0),
#  (['bit of piffle . '], 0),
#  (['choppy and sloppy '], 0),
#  (['glee '], 1),
#  (['ridiculousness '], 0),
#  (['through its otherwise comic narrative '], 1),
#  (['it succeeds in entertaining , despite playing out like a feature-length sitcom replete with stereotypical familial quandaries '],
#   1),
#  (['please the eye '], 1),
#  (['to keep grown-ups from squirming in their seats '], 1),
#  (["of what makes dover kosashvili 's outstanding feature debut so potent "],
#   1),
#  (['all the sibling rivalry and '], 0),
#  (['simple pleasures usurp the preaching message so that , by the time the credits roll across the pat ending , a warm , fuzzy feeling prevails '],
#   1),
#  (['big , fat , dumb '], 0),
#  (['bold colors '], 1),
#  (['most notable '], 1),
#  (['good-bad that makes eight legged freaks a perfectly entertaining summer diversion '],
#   1),
#  (['splendidly '], 1),
#  (['with results that are sometimes bracing , sometimes baffling and quite often , and in unexpected ways , touching '],
#   1),
#  (['finds its moviegoing pleasures '], 1),
#  (['computer-generated cold fish '], 0),
#  (['tepid and choppy recycling '], 0),
#  (['the unfulfilling , incongruous '], 0),
#  (['ending surprise '], 1),
#  (['fun and funny in the middle , though somewhat less '], 1),
#  (['of weird performances and direction '], 0),
#  (['deeply biased , and '], 0),
#  (['worked wonders with the material '], 1),
#  (["for all the charm of kevin kline and a story that puts old-fashioned values under the microscope , there 's something creepy about this movie . "],
#   1),
#  (['as a low-budget series on a uhf channel '], 0),
#  (['crematorium chimney fires and stacks of dead bodies '], 0),
#  (['remaining one of the most savagely hilarious social critics this side of jonathan swift '],
#   1),
#  (['the resourceful amnesiac '], 0),
#  (['of hell so shattering it '], 0),
#  (['a glib but bouncy bit '], 1),
#  (['an effective portrait of a life in stasis -- '], 1),
#  (['a rambling ensemble piece with loosely connected characters and plots that never quite gel . '],
#   0),
#  (['director ever making his wife look so bad in a major movie '], 0),
#  (["'re over 25 , have an iq over 90 , "], 0),
#  (['meditation ) '], 1),
#  (["it 's something of the ultimate scorsese film , with all the stomach-turning violence , colorful new york gang lore and other hallmarks of his personal cinema painted on their largest-ever historical canvas . "],
#   1),
#  (['full of grace '], 1),
#  (['an odd but ultimately satisfying blend '], 1),
#  (["have you swinging from the trees hooting it 's praises "], 1),
#  (['the proficient , dull sorvino has no light touch , and rodan is out of his league '],
#   0),
#  (['sparse '], 0),
#  (["we do n't get williams ' usual tear and a smile , just sneers and bile , "],
#   0),
#  (['the chateau belongs to rudd , whose portrait of a therapy-dependent flakeball spouting french malapropisms ... is a nonstop hoot '],
#   1),
#  (['a smile on your face '], 1),
#  (['poor editing , bad bluescreen , and ultra-cheesy dialogue highlight the radical action . '],
#   0),
#  (['the movie is certainly easy to watch . '], 1),
#  (['a hip comedy '], 1),
#  (['fanciful , grisly and engagingly quixotic '], 1),
#  (['steals so freely from other movies '], 0),
#  (["when it 's not wallowing in hormonal melodrama "], 0),
#  (['an absorbing look '], 1),
#  (['this pretty watchable '], 1),
#  (['a film neither bitter nor sweet , neither romantic nor comedic , neither warm nor fuzzy '],
#   0),
#  (['a rich tale of our times '], 1),
#  (['cry for your money back '], 0),
#  (["no one involved , save dash , shows the slightest aptitude for acting , and the script , credited to director abdul malik abbott and ernest ` tron ' anderson , seems entirely improvised . "],
#   0),
#  (['too-spectacular '], 0),
#  (['storytelling ability '], 1),
#  (['delightful cast '], 1),
#  (['written for no one '], 1),
#  (['a leap from pinnacle to pinnacle '], 1),
#  (['luminous interviews '], 1),
#  (['300 years of russian history and culture '], 1),
#  (['with no good inside dope , and no particular bite '], 0),
#  (['a classy , sprightly spin on film '], 1),
#  (["eventually resents having to inhale this gutter romancer 's secondhand material "],
#   0),
#  (['rambling incoherence '], 0),
#  (['retread , hobbled by half-baked setups and sluggish pacing '], 0),
#  (['trouble every day is a success in some sense '], 1),
#  (['would probably have worked better as a one-hour tv documentary . '], 0),
#  (['awfully entertaining '], 1),
#  (['that expands into a meditation on the deep deceptions of innocence '], 1),
#  (['at the right film '], 1),
#  (['change the fact that what we have here is a load of clams left in the broiling sun for a good three days '],
#   0),
#  (['evans is ) a fascinating character , and deserves a better vehicle than this facetious smirk of a movie . '],
#   0),
#  (['share their enthusiasm '], 1),
#  (["could n't care less "], 0),
#  (["'d be hard put to find a movie character more unattractive or odorous ( than leon ) "],
#   0),
#  (['gangster no. 1 is solid , satisfying fare for adults . '], 1),
#  (['a wickedly undramatic central theme '], 0),
#  (['... bibbidy-bobbidi-bland . '], 0),
#  (["although it tries to be much more , it 's really just another major league . "],
#   0),
#  (['the whole thing plays like a tired tyco ad . '], 0),
#  (['the visceral excitement of a sports extravaganza '], 1),
#  (["a sour taste in one 's mouth "], 0),
#  ([', dull procession '], 0),
#  (['with sharp ears and eyes '], 1),
#  (['thoroughly enjoyed themselves '], 1),
#  (['it works well enough , since the thrills pop up frequently , and '], 1),
#  (['feels like pieces a bunch of other , better movies slapped together . '],
#   0),
#  (['paper-thin characterizations '], 0),
#  (['alternates between deadpan comedy and heartbreaking '], 1),
#  (['be both hugely entertaining and uplifting '], 1),
#  (['with the gifted pearce on hand to keep things on semi-stable ground dramatically '],
#   1),
#  (['capability to soothe and break your heart with a single stroke '], 1),
#  (['a new , self-deprecating level '], 0),
#  (['a spark of new inspiration in it '], 1),
#  (['it all was , and started doing nothing but reacting to it - feeling a part of its grand locations , thinking urgently as the protagonists struggled , feeling at the mercy of its inventiveness , gasping at its visual delights '],
#   1),
#  (['inadequate '], 0),
#  (['kids will love its fantasy and adventure , '], 1),
#  (['cutting impressions '], 1),
#  (['truly excellent '], 1),
#  (['seen such self-amused trash '], 0),
#  (['meager weight '], 0),
#  (['film lapses '], 0),
#  (['the chelsea hotel today is populated by whiny , pathetic , starving and untalented artistes '],
#   0),
#  (['compelling motion '], 1),
#  (['the surprise ending is revealed '], 1),
#  (['much worth '], 1),
#  (['carries the day with impeccable comic timing , raffish charm and piercing intellect '],
#   1),
#  (["avary 's failure to construct a story with even a trace of dramatic interest "],
#   0),
#  (['top-heavy '], 0),
#  (['unfolds as one '], 1),
#  (['volatile '], 0),
#  (['introduces you to new , fervently held ideas and fanciful thinkers '], 1),
#  (['a lively and engaging examination '], 1),
#  (['kouyate elicits strong performances from his cast , and he delivers a powerful commentary on how governments lie , no matter who runs them . '],
#   1),
#  (['some weird relative trots out the video he took of the family vacation to stonehenge '],
#   0),
#  (['to face frightening late fees '], 0),
#  (['seems to want to be a character study , '], 0),
#  (['present an unflinching look '], 1),
#  (['the overall fabric is hypnotic , and mr. mattei fosters moments of spontaneous intimacy . '],
#   1),
#  (['one of those so-so films that could have been much better . '], 0),
#  (['the idea of narrative logic or cohesion is an entirely foreign concept '],
#   0),
#  ([', is of overwhelming waste '], 0),
#  (['is plenty of fun for all '], 1),
#  (['charm , generosity and diplomacy '], 1),
#  (['a part of us that can not help be entertained by the sight of someone getting away with something '],
#   1),
#  (['is a nicely handled affair , a film about human darkness but etched with a light ( yet unsentimental ) touch '],
#   1),
#  (['action - mechanical . '], 0),
#  (['washington demands and receives excellent performances '], 1),
#  (['squandering his opportunity to make absurdist observations '], 0),
#  (['insightful and entertaining '], 1),
#  (['vanity project '], 0),
#  (['this would have been better than the fiction it has concocted , and '], 0),
#  (['a movie that keeps throwing fastballs '], 1),
#  (['playful spirit '], 1),
#  ([', memories and one fantastic visual trope '], 1),
#  (['winds up feeling like a great missed opportunity '], 0),
#  (['expertly '], 1),
#  (['nearly terminal '], 0),
#  (["'s hard to resist "], 1),
#  (['creative interference '], 1),
#  (['in its understanding , often funny way , it tells a story whose restatement is validated by the changing composition of the nation . '],
#   1),
#  (['human experience -- drama , conflict , tears and surprise -- '], 1),
#  (['schiffer '], 1),
#  (["to shyamalan 's gifts , which are such that we 'll keep watching the skies for his next project "],
#   1),
#  (['with unlikable , spiteful idiots '], 0),
#  (['maladjusted teens in a downward narcotized spiral '], 0),
#  (['what should have been a painless time-killer '], 0),
#  (['could have guessed at the beginning '], 0),
#  (['gentle , touching story '], 1),
#  (['unrelentingly grim -- '], 0),
#  (['that there are more interesting ways of dealing with the subject '], 0),
#  (["plays it straight , turning leys ' fable into a listless climb down the social ladder "],
#   0),
#  (['part of the charm of satin rouge '], 1),
#  (['good '], 1),
#  (['a fairly impressive debut '], 1),
#  (['interpreting the play as a call for pity and sympathy '], 0),
#  (['cheery '], 1),
#  (['horrifyingly '], 0),
#  (['excitement in manufactured high drama '], 0),
#  (["by on angelina jolie 's surprising flair for self-deprecating comedy "],
#   1),
#  (['that haynes can both maintain and dismantle the facades that his genre and his character construct is a wonderous accomplishment of veracity and narrative grace . '],
#   1),
#  (['see one of those comedies that just seem like a bad idea from frame one '],
#   0),
#  (['decidedly flimsier with its many out-sized , out of character and logically porous action set pieces '],
#   0),
#  (['a low-rent retread of the alien pictures . '], 0),
#  (['with a bouncy score '], 1),
#  (['admirably '], 1),
#  (["i 've seen in a while , a meander through worn-out material "], 0),
#  (["he 's been in years "], 0),
#  (['despite downplaying her good looks '], 1),
#  (['plot lapses '], 0),
#  (["one of these days hollywood will come up with an original idea for a teen movie , but until then there 's always these rehashes to feed to the younger generations "],
#   0),
#  (['a low , smoky and inviting sizzle '], 1),
#  (['decrepit '], 0),
#  (['with all of this '], 1),
#  (['ride around a pretty tattered old carousel '], 0),
#  (['well-done supernatural thriller with keen insights into parapsychological phenomena and the soulful nuances '],
#   1),
#  (["was n't as bad as i thought it was going to be "], 1),
#  (['only a document of the worst possibilities of mankind '], 0),
#  (["it 's immensely ambitious , different than anything that 's been done before and amazingly successful in terms of what it 's trying to do . "],
#   1),
#  (['slightly naughty , just-above-average off - broadway play '], 1),
#  (["could be looking at his 12th oscar nomination by proving that he 's now , more than ever , choosing his roles with the precision of the insurance actuary "],
#   1),
#  (['as ` wayne '], 1),
#  (['is the distinct and very welcome sense of watching intelligent people making a movie '],
#   1),
#  (["looking at his 12th oscar nomination by proving that he 's now , more than ever , choosing his roles with the precision of the insurance actuary "],
#   1),
#  (['of visual flair '], 1),
#  (['the obligatory moments of sentimental ooze '], 0),
#  (['nostalgic comments '], 1),
#  ([', accessible to a chosen few , standoffish to everyone else , and smugly suggests a superior moral tone is more important than filmmaking skill '],
#   0),
#  (['christian '], 1),
#  (['get paid enough to sit through crap like this '], 0),
#  (['especially when i have to put up with 146 minutes of it '], 0),
#  (["'s not nearly enough that 's right "], 0),
#  (['is a pan-american movie , with moments of genuine insight into the urban heart '],
#   1),
#  (['the sometimes murky , always brooding look of i '], 0),
#  (['one of the most plain , unimaginative romantic comedies i '], 0),
#  (['unlikely to be appreciated by anyone outside the under-10 set '], 0),
#  (['dark , intelligent '], 1),
#  (['... quite endearing . '], 1),
#  (['forbidden love , racial tension , and other issues that are as valid today as they were in the 1950s '],
#   1),
#  (["were afraid to show this movie to reviewers before its opening , afraid of the bad reviews they thought they 'd earn "],
#   0),
#  (['one-trick pony '], 0),
#  (['oscar-worthy '], 1),
#  (['elegant and sly deadpan '], 1),
#  (['a small fortune in salaries and stunt cars might have been saved if the director , tom dey , had spliced together bits and pieces of midnight run and 48 hours ( and , for that matter , shrek ) . '],
#   0),
#  (['ballistic : '], 1),
#  (['this latest installment of the horror film franchise that is apparently as invulnerable as its trademark villain '],
#   1),
#  (['more enjoyable '], 1),
#  (['rooting against , '], 0),
#  (['of admission for the ridicule factor '], 0),
#  (['it seeks excitement in manufactured high drama '], 0),
#  (['the performances elicit more of a sense of deja vu than awe '], 0),
#  (["even though the film does n't manage to hit all of its marks "], 0),
#  (['too straight-faced '], 0),
#  (['weirdo actor crispin glover '], 0),
#  (["the film 's shortcomings "], 0),
#  (['holm does his sly , intricate magic , and iben hjelje is entirely appealing as pumpkin '],
#   1),
#  (['emotionally bruised characters '], 0),
#  (['a stylish but steady , and ultimately very satisfying , piece of character-driven storytelling . '],
#   1),
#  (['on all levels '], 1),
#  (['carrying '], 1),
#  (['the things this movie tries to get the audience to buy just '], 0),
#  (['is refreshingly undogmatic about its characters . '], 1),
#  (["the writing is indifferent , and jordan brady 's direction is prosaic "],
#   0),
#  (['look too deep into the story '], 0),
#  (['enough to let you bask in your own cleverness as you figure it out '], 1),
#  (['much like its easily dismissive '], 0),
#  (["the film 's crisp , unaffected style "], 1),
#  (["there 's apparently nothing left to work with , sort of like michael jackson 's nose . "],
#   0),
#  (['delicate treatment '], 1),
#  (['putting together any movies of particular value or merit '], 1),
#  (['does no justice to the story itself '], 0),
#  (['visually ravishing '], 1),
#  (['for people who make movies and watch them '], 1),
#  (['successful '], 1),
#  (["that 's lived too long "], 0),
#  (['cherished '], 1),
#  (['resulted in a smoother , more focused narrative '], 1),
#  (['is one of the best actors there is . '], 1),
#  (['laughs in this simple , sweet and romantic comedy '], 1),
#  (["that old familiar feeling of ` let 's get this thing over with ' "], 0),
#  (['probes in a light-hearted way the romantic problems of individuals for whom the yearning for passion spells discontent . '],
#   1),
#  (['too bad to be good '], 0),
#  (["mr. chabrol 's subtlest works "], 1),
#  (['odd movies '], 0),
#  (['to a higher level '], 1),
#  (['undeniably moving '], 1),
#  (['the film fearlessly gets under the skin of the people involved ... this makes it not only a detailed historical document , but an engaging and moving portrait of a subculture . '],
#   1),
#  (['is engaging enough to keep you from shifting in your chair too often '],
#   1),
#  (['patience '], 1),
#  (['the full monty was a freshman fluke '], 0),
#  (['makes sex with strangers , which opens today in the new york metropolitan area , so distasteful '],
#   0),
#  (['warm and '], 1),
#  (['the real-life story is genuinely inspirational '], 1),
#  (["a film really has to be exceptional to justify a three hour running time , and this is n't . "],
#   0),
#  (['this kind of hands-on storytelling '], 1),
#  (['as stiff , ponderous and charmless as a mechanical apparatus '], 0),
#  (['traditional layers of awakening and ripening and '], 1),
#  (['hope the movie is widely seen and debated with appropriate ferocity and thoughtfulness '],
#   1),
#  (['the notion of deleting emotion from people , even in an advanced prozac nation '],
#   0),
#  (['belongs in the too-hot-for-tv direct-to-video/dvd category , and this is why i have given it a one-star rating . '],
#   0),
#  (['of its spirit '], 1),
#  (['a live-action cartoon , a fast-moving and cheerfully simplistic 88 minutes of exaggerated action '],
#   1),
#  (['the story has its redundancies , and the young actors , not very experienced , are sometimes inexpressive . '],
#   0),
#  (['good natured '], 1),
#  (['a shock-you-into-laughter intensity '], 1),
#  (['entertainingly presented '], 1),
#  (['little fuss or noise '], 0),
#  (['mr. wollter and ms. seldhal give strong and convincing performances , but neither reaches into the deepest recesses of the character to unearth the quaking essence of passion , grief and fear . '],
#   0),
#  (['literary detective story '], 1),
#  (["'s the cute frissons of discovery and humor between chaplin and kidman that keep this nicely wound clock not just ticking , but humming . "],
#   1),
#  (['while the highly predictable narrative falls short , treasure planet is truly gorgeous to behold . '],
#   1),
#  (["uninspired , and peopled mainly by characters so unsympathetic that you 're left with a sour taste in your mouth "],
#   0),
#  (["plays out ... like a high-end john hughes comedy , a kind of elder bueller 's time out . "],
#   1),
#  (["` synthetic ' is the best description of this well-meaning , beautifully produced film that sacrifices its promise for a high-powered star pedigree . "],
#   0),
#  (['the story has some nice twists but the ending and '], 1),
#  (['about cleverness , wit or any other kind of intelligent humor '], 1),
#  (['its inescapable absurdities '], 0),
#  (["is that i ca n't remember a single name responsible for it "], 0),
#  (['admirable energy '], 1),
#  (['what is almost certainly going to go down as the worst -- and only -- killer website movie of this or any other year '],
#   0),
#  (['in the feet with cop flick cliches like an oily arms dealer , squad car pile-ups and the requisite screaming captain '],
#   0),
#  (['dismember '], 0),
#  (['its bold presentation '], 1),
#  (["the film 's unhurried pace is actually one of its strengths . "], 1),
#  (['dying and going '], 0),
#  (['has already appeared in one forum or another '], 0),
#  (['delightfully charming -- and totally american '], 1),
#  (["stuck in heaven because he 's afraid of his best-known creation ? "], 0),
#  (['very moving and revelatory footnote '], 1),
#  (['lost '], 0),
#  (['clean '], 1),
#  (['consider the film a celluloid litmus test for the intellectual and emotional pedigree of your date and a giant step backward for a director i admire '],
#   0),
#  (['the most creative mayhem '], 1),
#  (['executed with such gentle but insistent sincerity , with such good humor and '],
#   1),
#  (['with amazing finesse '], 1),
#  (["it 's a treat -- a delightful , witty , improbable romantic comedy with a zippy jazzy score ... grant and bullock make it look as though they are having so much fun "],
#   1),
#  (['starts out with tremendous promise , '], 1),
#  (['a convincing one '], 1),
#  (['saddled with an unwieldy cast of characters and angles , but the payoff is powerful and revelatory '],
#   1),
#  (["this sad , occasionally horrifying but often inspiring film is among wiseman 's warmest . "],
#   1),
#  (['a feature film that is wickedly fun to watch '], 1),
#  (['ultimate demise '], 0),
#  (['yes , i have given this movie a rating of zero . '], 0),
#  (['con '], 0),
#  (['of impact and moments '], 1),
#  (['is an extraordinary film , not least because it is japanese and yet feels universal '],
#   1),
#  (['provide the funniest moments in this oddly sweet comedy about jokester highway patrolmen '],
#   1),
#  (['a handful '], 1),
#  (['philosophers , not filmmakers '], 0),
#  (["huppert 's show to steal "], 1),
#  (['an average b-movie '], 0),
#  (['another unoriginal run '], 0),
#  ([', proves simultaneously harrowing and uplifting '], 1),
#  (['insultingly inept and artificial '], 0),
#  (['like the wanderers and a bronx tale '], 1),
#  (['a stirring visual sequence like a surge through swirling rapids or a leap from pinnacle to pinnacle rouses us . '],
#   1),
#  (['encumbers itself '], 0),
#  (['rambles '], 0),
#  (['hunk '], 1),
#  (['five hours long '], 0),
#  (['a rollicking '], 1),
#  (['the flat dialogue '], 0),
#  (['posing as a serious drama about spousal abuse '], 0),
#  (['be an unendurable viewing experience for this ultra-provincial new yorker if 26-year-old reese witherspoon were not on hand to inject her pure fantasy character , melanie carmichael , with a massive infusion of old-fashioned hollywood magic '],
#   1),
#  (['floundering way '], 0),
#  (['gradually sneaks up on the audience '], 1),
#  (["naqoyqatsi ' is banal in its message and the choice of material to convey it . "],
#   0),
#  (["too much of storytelling moves away from solondz 's social critique , casting its audience as that of intellectual lector in contemplation of the auteur 's professional injuries . "],
#   0),
#  (['enough to give the film the substance it so desperately needs '], 0),
#  ([', occasionally horrifying but often inspiring film '], 1),
#  (['seen this exact same movie a hundred times '], 0),
#  (['in other words , about as bad a film '], 0),
#  (['authentic to the core of his being '], 1),
#  (['to be somebody , and '], 1),
#  (['is so contrived , nonsensical and formulaic that , come to think of it , the day-old shelf would be a more appropriate location to store it '],
#   0),
#  (['puts on airs of a hal hartley wannabe film -- without the vital comic ingredient of the hilarious writer-director himself . '],
#   0),
#  (['crafted but ultimately hollow mockumentary '], 0),
#  (['such a horrible movie '], 0),
#  (['a fragile framework upon which to hang broad , mildly fleshed-out characters that seem to have been conjured up only 10 minutes prior to filming . '],
#   0),
#  (['wise and powerful tale '], 1),
#  (['the story that emerges has elements of romance , tragedy and even silent-movie comedy . '],
#   1),
#  (['stumbles '], 0),
#  (['inject farcical raunch '], 0),
#  (['to enjoy its own transparency '], 1),
#  (['into the art film pantheon '], 1),
#  (['because the cast is so engagingly messing around like slob city reductions of damon runyon crooks '],
#   0),
#  (['we feel that we truly know what makes holly and marina tick '], 1),
#  (['giggling at the absurdities and inconsistencies '], 0),
#  (["the emperor 's club , "], 1),
#  (['amusing study '], 1),
#  (['knew what the hell was coming next '], 0),
#  (['he can outgag any of those young whippersnappers making moving pictures today '],
#   1),
#  (["take any 12-year-old boy to see this picture , and he 'll be your slave for a year . "],
#   1),
#  (['it desperately wants to be a wacky , screwball comedy '], 0),
#  (['the film works as well as it does because of the performances . '], 1),
#  (['the , yes , snail-like pacing and '], 0),
#  (['was utterly charming '], 1),
#  (['distances you by throwing out so many red herrings , so many false scares , '],
#   0),
#  (['idealism '], 1),
#  (['worth catching '], 1),
#  (['willing to have fun with it '], 1),
#  (['fails because it demands that you suffer the dreadfulness of war from both sides . '],
#   0),
#  (['a majestic achievement , an epic of astonishing grandeur and '], 1),
#  (['its one-sidedness ... flirts with propaganda . '], 0),
#  (["bloodwork is n't a terrible movie , just a stultifyingly obvious one -- an unrewarding collar for a murder mystery . "],
#   0),
#  (['spy has all the same problems the majority of action comedies have . '],
#   0),
#  (['about the people who live in them , who have carved their own comfortable niche in the world and have been kind enough to share it '],
#   1),
#  (['helm a more traditionally plotted popcorn thriller while surrendering little of his intellectual rigor or creative composure '],
#   1),
#  (['disappointing in comparison to other recent war movies ... '], 0),
#  (['to the edge of their seats '], 1),
#  (['know a star '], 1),
#  (["it 's a spectacular performance - ahem , we hope it 's only acting . "],
#   1),
#  (['of the most entertaining bonds in years '], 1),
#  (['gets an exhilarating new interpretation in morvern callar . '], 1),
#  (["its inescapable absurdities are tantamount to insulting the intelligence of anyone who has n't been living under a rock ( since sept. 11 ) . "],
#   0),
#  (["like mike is n't going to make box office money that makes michael jordan jealous , but it has some cute moments , funny scenes , and hits the target audience ( young bow wow fans ) - with nothing but net . "],
#   1),
#  (['unwavering and arresting '], 1),
#  (['yet overflows with wisdom and emotion . '], 1),
#  (["in ( the characters ' ) misery "], 0),
#  (['you reach the finale '], 1),
#  (['of temptation , salvation and good intentions '], 1),
#  (['can make people act weird '], 0),
#  (['as deep as a petri dish '], 0),
#  ([', lawrence unleashes his trademark misogyny -- er , comedy -- like a human volcano or an overflowing septic tank , '],
#   0),
#  (['in sorrow '], 0),
#  (['even on its own ludicrous terms , the sum of all fears generates little narrative momentum , and invites unflattering comparisons to other installments in the ryan series . '],
#   0),
#  (["are tantamount to insulting the intelligence of anyone who has n't been living under a rock "],
#   0),
#  (["a little weak -- and it is n't that funny . "], 0),
#  (['when all is said and done , she loves them to pieces -- and so , i trust , will you . '],
#   1),
#  (['spielberg presents a fascinating but flawed look at the near future . '],
#   1),
#  (['surprisingly well '], 1),
#  (['sinks into by-the-numbers territory '], 0),
#  (['the historical , philosophical '], 1),
#  (['befuddling '], 0),
#  (['its essential problem '], 0),
#  (['depressing , ruthlessly pained and depraved '], 0),
#  (['all the usual spielberg flair '], 1),
#  (['nor truly edgy -- merely crassly flamboyant and comedically labored . '],
#   0),
#  (['respect and affection '], 1),
#  (['friends '], 1),
#  (['critics be damned . '], 1),
#  (['cleverly constructed scenario '], 1),
#  (['stupidity '], 0),
#  (['their computer-animated faces are very expressive . '], 1),
#  (['sharp edges and a deep vein of sadness run through its otherwise comic narrative . '],
#   1),
#  (['are nearly impossible to care about '], 0),
#  (['of genuine insight into the urban heart '], 1),
#  (['the evocative imagery and gentle , lapping rhythms of this film are infectious '],
#   1),
#  (["it looks like woo 's a p.o.w. "], 0),
#  (['has made a film of intoxicating atmosphere and little else . '], 0),
#  (['of high hilarity '], 1),
#  (['it has a bigger-name cast '], 1),
#  (['that maybe she , janine and molly -- an all-woman dysfunctional family -- deserve one another '],
#   0),
#  (['the screenplay never lets us forget that bourne was once an amoral assassin just like the ones who are pursuing him '],
#   1),
#  (['a positively thrilling combination of ethnography and all the intrigue , betrayal , deceit and murder of a shakespearean tragedy or a juicy soap opera '],
#   1),
#  (['creepiness '], 0),
#  (["the script , credited to director abdul malik abbott and ernest ` tron ' anderson , seems entirely improvised "],
#   0),
#  (["replacing john carpenter 's stylish tracking shots "], 0),
#  (['ignore the reputation , and ignore the film . '], 0),
#  (['frailty will turn bill paxton into an a-list director '], 1),
#  (['simply put , there should have been a more compelling excuse to pair susan sarandon and goldie hawn . '],
#   0),
#  (['dramatic punch and depth '], 1),
#  (["his ( nelson 's ) screenplay needs some serious re-working to show more of the dilemma , rather than have his characters stage shouting "],
#   0),
#  (['a huge action sequence '], 1),
#  (['hates its characters '], 0),
#  (['a smile on your face and a grumble in your stomach '], 1),
#  (['the nifty premise '], 1),
#  (['does hold up pretty well . '], 1),
#  (["is just too bad the film 's story does not live up to its style "], 0),
#  (['it becomes a chore to sit through -- despite some first-rate performances by its lead '],
#   0),
#  (['of its lurid fiction '], 1),
#  (['every moment crackles with tension , and '], 1),
#  (["bestowed star hoffman 's brother gordy with the waldo salt screenwriting award at 2002 's sundance festival "],
#   1),
#  (['their lives , loves and the art '], 1),
#  (['seems as funny '], 1),
#  (['good fight '], 1),
#  (['suited neither '], 0),
#  (['a core of flimsy -- or , worse yet , nonexistent -- ideas '], 0),
#  (['this wretchedly unfunny wannabe comedy is inane and awful '], 0),
#  (['hate to tear your eyes away from the images '], 1),
#  (["in kicking around a raison d'etre that 's as fresh-faced as its young-guns cast "],
#   1),
#  (['a vibrant whirlwind of love , family and all that goes with it , my big fat greek wedding is a non-stop funny feast of warmth , color and cringe . '],
#   1),
#  (['gunfight '], 0),
#  (['this new jangle of noise , mayhem and stupidity must be a serious contender for the title . '],
#   0),
#  (['a decided lack of spontaneity in its execution and a dearth of real poignancy in its epiphanies . '],
#   0),
#  (['makes us watch as his character awakens to the notion that to be human is eventually to have to choose '],
#   1),
#  (['in the screenplay to keep the film entertaining '], 1),
#  (['donovan ... squanders his main asset , '], 0)]

# %%
# Get the text label ('positive' or 'negative') of the 1st sample in the test and demonstration set
splitted_sst2.test.get_label(0), splitted_sst2.demonstration.get_label(0)
# Out:
# ('negative', 'positive')

# %%
# Get the *ground truth label* of a specific sample.
# You can choose whether to fetch from the test set or the training set using test_set=True/False.

# Label of the 1st sample in the test set
splitted_sst2.get_ground_truth_label(0, test_set=True),

# Label of the 1st sample in the training set
splitted_sst2.get_ground_truth_label(0, test_set=False)
# Out:
# ('negative', 'positive')

# %%
# This cell constructs a prompt string for k-shot in-context learning (ICL)
# using the `prompt_writter()` method.

# What is this for?
# The resulting prompt is used to guide a language model in predicting the sentiment
# of a test sentence by showing it a few labeled examples beforehand.

# Explanation of what's happening:
# The first argument to `prompt_writter()` is a list of demonstration examples in the format:
#     ([input_text], label_text)
# Each demonstration example consists of:
#   - input_text: the sentence as a list of tokens/words
#   - label_text: the corresponding sentiment label ('positive' or 'negative')

# This list comprehension:
#     [ (splitted_sst2.demonstration.get_input_text(i), splitted_sst2.demonstration.get_label(i)) for i in [2019, 4761, 3483, 3952] ]
# does the following:
#   - It selects 4 specific examples from the demonstration set, using their indices.
#   - These indices [2019, 4761, 3483, 3952] were  chosen randomly in experiments
#     and represent the k=4 examples we want to show the model.
#   - For each index `i`, it gets the sentence and its label.

# The second argument to `prompt_writter()`:
#     splitted_sst2.test.get_input_text(0)
# fetches the input text (as a list) of the first test sample — the sentence we want the model to label.

# Output format:
# The resulting prompt will look like:
#     sentence: demo1_text    sentiment: label1
#     sentence: demo2_text    sentiment: label2
#     ...
#     sentence: test_text     sentiment:
#
# The model is expected to complete the last line with a predicted sentiment.

splitted_sst2.prompt_writter([(splitted_sst2.demonstration.get_input_text(i),splitted_sst2.demonstration.get_label(i)) for i in [2019, 4761, 3483, 3952]],
                             splitted_sst2.test.get_input_text(0))
# Out:
# "sentence: in this fascinating portrait of a modern lothario  sentiment: positive\nsentence: on this frozen tundra soap opera that breathes extraordinary life into the private existence of the inuit people  sentiment: positive\nsentence: been part of for the most part wilde 's droll whimsy helps `` being earnest '' overcome its weaknesses and parker 's creative interference  sentiment: positive\nsentence: so compellingly  sentiment: positive\nsentence: designed to fill time ,  sentiment:  "

# %%
# Create an Experiment object for SST-2 using the previously split dataset
# and the desired k-shot configuration.
#
# `Experiment` is a utility class designed to:
# - Manage the overall experiment setup
# - Automatically handle prompt construction
# - Interface with test samples
#
# Arguments:
#   splitted_sst2 : the dataset wrapper that holds train/test/demonstration splits
#   k             : the number of in-context examples to use in each prompt
#
# This object will make it easier to run multiple test samples systematically.

sst2_experiment = experiment_basics.Experiment(splitted_sst2, k=k, seed=seed)

# %%
# 👇 Generate a prompt for a specific test sample (in this case, index 0)
#
# This method:
# - Samples k demonstration examples automatically (no need to manually specify indices)
# - Retrieves the input sentence at test index 0
# - Constructs a full ICL prompt of the form:
#
#     sentence: demo1_text  sentiment: label1
#     sentence: demo2_text  sentiment: label2
#     ...
#     sentence: test_input_text  sentiment:
#
# This prompt can now be sent to a language model to predict the sentiment
# of the final test sentence.
#
# Note: This abstracts away the manual pairing and formatting from earlier cells.

sst2_experiment.get_prompts_for_test_sample(0)
# Out:
# "sentence: the film does n't have enough innovation or pizazz to attract teenagers  sentiment: negative\nsentence: intelligent jazz-playing exterminator  sentiment: positive\nsentence: limitations  sentiment: negative\nsentence: of international acclaim  sentiment: positive\nsentence: designed to fill time ,  sentiment:  "
